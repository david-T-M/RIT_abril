# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV

# %%
for i in range(45):
    if i==0:
        train = pd.read_pickle('salida/nuevo4h/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4h/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
            train=pd.concat([train,temp])
        except:
            print(i+1)

# %%
train=train.reset_index(drop=True)
train
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       0.000000        2.096701   0.000000  0.000000  0.000000  0.000000
# 1       0.000000        1.912939   0.000000  0.000000  0.000000  0.000000
# 2       0.000000        2.176234   0.000000  0.000000  0.000000  0.000000
# 3       1.309895        1.909126   1.399581  3.811703  0.006280  0.140442
# 4       1.299021        2.183393   1.441167  3.821563  0.005581  0.155224
# ...          ...             ...        ...       ...       ...       ...
# 4434    1.352706        1.052941   0.811278  3.786475  0.006455  0.084316
# 4435    1.373320        1.384432   1.384432  3.779084  0.008525  0.056842
# 4436    1.263298        1.687640   1.370951  3.787387  0.006522  0.202038
# 4437    1.298727        1.410848   1.459148  3.685267  0.004270  0.156616
# 4438    1.380951        1.298795   1.061278  3.788780  0.005101  0.046050
#
#          sumas  mutinf_t  mearts_t  max_info_t  ...  list_m  list_T  \
# 0     0.000000  4.584342  0.000561    0.959007  ...       0       8
# 1     0.000000  4.385955  0.001464    0.787925  ...       0       7
# 2     0.000000  4.551917  0.000832    0.942610  ...       0       7
# 3     0.072331  4.168479  0.002797    0.478862  ...       3       5
# 4     0.066714  4.060155  0.003064    0.465865  ...       3       7
# ...        ...       ...       ...         ...  ...     ...     ...
# 4434  0.020937  3.924434  0.003752    0.224118  ...       4       3
# 4435  0.024570  3.779084  0.006149    0.056842  ...       4       3
# 4436  0.054981  3.742518  0.004020    0.195824  ...       2       5
# 4437  0.059745  4.094972  0.002200    0.435175  ...       1       6
# 4438  0.008490  3.797957  0.004454    0.074068  ...       2       4
#
#       Jaro-Winkler_rit  KL_divergence  negT  verbT  negH  verbH  overlap_ent  \
# 0             0.857143       0.000000     0            0            0.800000
# 1             0.875000       0.000000     0            0            0.333333
# 2             1.000000       0.000000     0            0            0.400000
# 3             0.375000       0.181220     0            0            0.333333
# 4             0.375000       0.265583     0            0            0.166667
# ...                ...            ...   ...    ...   ...    ...          ...
# 4434          0.166667       0.083317     0            0            0.200000
# 4435          0.250000       0.000000     0            1   play     0.000000
# 4436          0.000000       0.210428     0            0            0.000000
# 4437          0.333333       0.207085     0            0            0.333333
# 4438          0.000000       0.072276     0            0            0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2        ENTAILMENT
# 3     CONTRADICTION
# 4     CONTRADICTION
# ...             ...
# 4434  CONTRADICTION
# 4435  CONTRADICTION
# 4436  CONTRADICTION
# 4437  CONTRADICTION
# 4438  CONTRADICTION
#
# [4439 rows x 31 columns]

# %%
temp1 = pd.read_csv("../OPENAI/data/SICK/original/SICK_TRAIN.csv")
temp1
# Out:
#                                              sentence_A  \
# 0     A group of kids is playing in a yard and an ol...
# 1     A group of children is playing in the house an...
# 2     The young boys are playing outdoors and the ma...
# 3     The kids are playing outdoors near a man with ...
# 4     The young boys are playing outdoors and the ma...
# ...                                                 ...
# 4434                    A door is being opened by a man
# 4435                   Someone is boiling okra in a pot
# 4436  The man is singing heartily and playing the gu...
# 4437        A man in blue has a yellow ball in the mitt
# 4438               Three dogs are resting on a sidewalk
#
#                                              sentence_B entailment_label
# 0     A group of boys in a yard is playing and a man...          NEUTRAL
# 1     A group of kids is playing in a yard and an ol...          NEUTRAL
# 2     The kids are playing outdoors near a man with ...       ENTAILMENT
# 3     A group of kids is playing in a yard and an ol...          NEUTRAL
# 4     A group of kids is playing in a yard and an ol...          NEUTRAL
# ...                                                 ...              ...
# 4434  A bald man in a band is playing guitar in the ...          NEUTRAL
# 4435                   The man is not playing the drums          NEUTRAL
# 4436  A bicyclist is holding a bike over his head in...          NEUTRAL
# 4437                      A man is jumping rope outside          NEUTRAL
# 4438         The woman with a knife is slicing a pepper          NEUTRAL
#
# [4439 rows x 3 columns]

# %%
train["clases"]=temp1["entailment_label"]
train
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       0.000000        2.096701   0.000000  0.000000  0.000000  0.000000
# 1       0.000000        1.912939   0.000000  0.000000  0.000000  0.000000
# 2       0.000000        2.176234   0.000000  0.000000  0.000000  0.000000
# 3       1.309895        1.909126   1.399581  3.811703  0.006280  0.140442
# 4       1.299021        2.183393   1.441167  3.821563  0.005581  0.155224
# ...          ...             ...        ...       ...       ...       ...
# 4434    1.352706        1.052941   0.811278  3.786475  0.006455  0.084316
# 4435    1.373320        1.384432   1.384432  3.779084  0.008525  0.056842
# 4436    1.263298        1.687640   1.370951  3.787387  0.006522  0.202038
# 4437    1.298727        1.410848   1.459148  3.685267  0.004270  0.156616
# 4438    1.380951        1.298795   1.061278  3.788780  0.005101  0.046050
#
#          sumas  mutinf_t  mearts_t  max_info_t  ...  list_m  list_T  \
# 0     0.000000  4.584342  0.000561    0.959007  ...       0       8
# 1     0.000000  4.385955  0.001464    0.787925  ...       0       7
# 2     0.000000  4.551917  0.000832    0.942610  ...       0       7
# 3     0.072331  4.168479  0.002797    0.478862  ...       3       5
# 4     0.066714  4.060155  0.003064    0.465865  ...       3       7
# ...        ...       ...       ...         ...  ...     ...     ...
# 4434  0.020937  3.924434  0.003752    0.224118  ...       4       3
# 4435  0.024570  3.779084  0.006149    0.056842  ...       4       3
# 4436  0.054981  3.742518  0.004020    0.195824  ...       2       5
# 4437  0.059745  4.094972  0.002200    0.435175  ...       1       6
# 4438  0.008490  3.797957  0.004454    0.074068  ...       2       4
#
#       Jaro-Winkler_rit  KL_divergence  negT  verbT  negH  verbH  overlap_ent  \
# 0             0.857143       0.000000     0            0            0.800000
# 1             0.875000       0.000000     0            0            0.333333
# 2             1.000000       0.000000     0            0            0.400000
# 3             0.375000       0.181220     0            0            0.333333
# 4             0.375000       0.265583     0            0            0.166667
# ...                ...            ...   ...    ...   ...    ...          ...
# 4434          0.166667       0.083317     0            0            0.200000
# 4435          0.250000       0.000000     0            1   play     0.000000
# 4436          0.000000       0.210428     0            0            0.000000
# 4437          0.333333       0.207085     0            0            0.333333
# 4438          0.000000       0.072276     0            0            0.000000
#
#           clases
# 0        NEUTRAL
# 1        NEUTRAL
# 2     ENTAILMENT
# 3        NEUTRAL
# 4        NEUTRAL
# ...          ...
# 4434     NEUTRAL
# 4435     NEUTRAL
# 4436     NEUTRAL
# 4437     NEUTRAL
# 4438     NEUTRAL
#
# [4439 rows x 31 columns]

# %%
train.boxplot(by="clases",column="KL_divergence")
# Out:
# <Axes: title={'center': 'KL_divergence'}, xlabel='clases'>

# %% [markdown]
# ## Eliminar características

# %%
# Diferencia entre entropia total - entropias y dejar la columna
# Quitar max_info_p
# revisar scaler y/o normalización de shape con total
#
train=train.drop(["verbH","verbT"],axis=1)
#train=train.drop(["Match"],axis=1)
train
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0

#        'list_comp', 'diferencias', 'list_incomp', 'entropia_relaciones',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'KL_divergence',
#        'negT', 'negH', 'overlap_ent', 'clases'],
#       dtype='object')

# %%
#train=train[['list_comp', 'list_incomp','list_m','negT', 'negH',"clases"]]

# %%
X = train.drop(['clases'],axis=1)
y_ = train['clases']

# %%
# Guardar un nuevo dataframe para la correlación de variables
train_m=train.drop(['clases'],axis=1).corr(method='pearson')

# %%
train_m
# Out:
#                      distancias  entropia_total  entropias    mutinf  \
# distancias             1.000000       -0.084946   0.834181  0.988270
# entropia_total        -0.084946        1.000000   0.124438 -0.048026
# entropias              0.834181        0.124438   1.000000  0.877670
# mutinf                 0.988270       -0.048026   0.877670  1.000000
# mearts                 0.849918       -0.083371   0.682817  0.812225
# max_info               0.596092        0.175141   0.802828  0.698777
# sumas                  0.525452        0.182954   0.718797  0.621272
# mutinf_t              -0.621540        0.058768  -0.544028 -0.605496
# mearts_t               0.597992       -0.070217   0.499179  0.572050
# max_info_t            -0.720116        0.183881  -0.583171 -0.692370
# sumas_t               -0.557999        0.089804  -0.487360 -0.537793
# entail                -0.748050        0.149975  -0.667705 -0.738339
# contra                -0.025064        0.009330  -0.031651 -0.027587
# neutral                0.104510        0.061763   0.065561  0.095300
# no_match               0.822310       -0.206715   0.750263  0.816308
# rel_conceptuales       0.163815        0.095369   0.142141  0.156101
# list_comp              0.166412        0.173774   0.168250  0.167845
# diferencias            0.717065       -0.177897   0.636266  0.702276
# list_incomp           -0.015816        0.037442  -0.016684 -0.017240
# entropia_relaciones    0.773620        0.043184   0.690919  0.778547
# list_M                 0.198022        0.251732   0.246674  0.197419
# list_m                 0.754652       -0.109100   0.735994  0.748843
# list_T                 0.021932        0.254451   0.126850  0.039476
# Jaro-Winkler_rit      -0.574617        0.131078  -0.508010 -0.566701
# KL_divergence          0.683179        0.171235   0.500830  0.692796
# negT                  -0.070801       -0.024776  -0.049378 -0.068853
# negH                   0.225640       -0.043282   0.092618  0.208989
# overlap_ent           -0.553416        0.050068  -0.495477 -0.547644
#
#                        mearts  max_info     sumas  mutinf_t  mearts_t  \
# distancias           0.849918  0.596092  0.525452 -0.621540  0.597992
# entropia_total      -0.083371  0.175141  0.182954  0.058768 -0.070217
# entropias            0.682817  0.802828  0.718797 -0.544028  0.499179
# mutinf               0.812225  0.698777  0.621272 -0.605496  0.572050
# mearts               1.000000  0.485572  0.428545 -0.606620  0.688170
# max_info             0.485572  1.000000  0.924994 -0.365842  0.324168
# sumas                0.428545  0.924994  1.000000 -0.322341  0.289705
# mutinf_t            -0.606620 -0.365842 -0.322341  1.000000 -0.917468
# mearts_t             0.688170  0.324168  0.289705 -0.917468  1.000000
# max_info_t          -0.638789 -0.309864 -0.259634  0.913332 -0.889605
# sumas_t             -0.476080 -0.239612 -0.120913  0.612282 -0.584371
# entail              -0.667920 -0.443661 -0.399158  0.791764 -0.775247
# contra              -0.021634 -0.020900 -0.016133 -0.131740  0.136565
# neutral              0.119895  0.023795 -0.003094 -0.354321  0.354469
# no_match             0.720960  0.508187  0.468477 -0.705320  0.684733
# rel_conceptuales     0.154927  0.066217  0.023430 -0.359292  0.340834
# negH                 0.081634  0.118972 -0.030675         -0.032978
# overlap_ent         -0.015454 -0.578905  0.076854          0.667018
#
#                      KL_divergence      negT      negH  overlap_ent
# distancias                0.683179 -0.070801  0.225640    -0.553416
# entropia_total            0.171235 -0.024776 -0.043282     0.050068
# entropias                 0.500830 -0.049378  0.092618    -0.495477
# mutinf                    0.692796 -0.068853  0.208989    -0.547644
# mearts                    0.608076 -0.069855  0.135550    -0.489920
# max_info                  0.537741 -0.035372  0.040057    -0.330192
# sumas                     0.529049 -0.044677  0.009790    -0.287704
# mutinf_t                 -0.249587  0.071584 -0.030792     0.836804
# mearts_t                  0.252969 -0.081598  0.000140    -0.809497
# max_info_t               -0.251028  0.073673 -0.061371     0.825274
# sumas_t                  -0.106277 -0.009996 -0.036007     0.534315
# entail                   -0.306940  0.057672 -0.072842     0.716601
# contra                   -0.024583 -0.035759 -0.030204    -0.117813
# neutral                   0.036436 -0.021320 -0.031087    -0.335819
# no_match                  0.344674 -0.046079  0.108295    -0.631339
# rel_conceptuales          0.051025 -0.019898 -0.016555    -0.343267
# list_comp                 0.028939 -0.054993 -0.049447    -0.503235
# diferencias               0.287798 -0.054035  0.122370    -0.560889
# list_incomp              -0.027564 -0.041169 -0.026639    -0.092344
# entropia_relaciones       0.512346 -0.078740  0.114264    -0.612128
# list_M                    0.038943 -0.040202  0.081634    -0.015454
# list_m                    0.258603 -0.043790  0.118972    -0.578905
# list_T                   -0.085361  0.048223 -0.030675     0.076854
# Jaro-Winkler_rit         -0.218490  0.081562 -0.032978     0.667018
# KL_divergence             1.000000 -0.072405  0.259489    -0.195182
# negT                     -0.072405  1.000000 -0.047197     0.106775
# negH                      0.259489 -0.047197  1.000000     0.003750
# overlap_ent              -0.195182  0.106775  0.003750     1.000000
#
# [28 rows x 28 columns]

# %%
# Checar variables colineales
#sns.relplot(data=train_m, x="list_bigram", y="bi_ent_trip_rel")

# %%
#X_dev = np.array(dev.drop(['CLASS'],axis=1))
#y_d = np.array(dev['CLASS'])

# %%
# SICK
y_train=[]
for i in y_:
    if i == "ENTAILMENT":
        y_train.append(1)
    elif i == "NEUTRAL":
        y_train.append(2)
    else:
        y_train.append(0)

# %%
y_train.count(2)
# Out:
# 2524

# %%
scaler = preprocessing.MaxAbsScaler().fit(X)
X_scaled = scaler.transform(X)
X = X_scaled
X_train=X

# %%
train.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# # TEST

# %%
for i in range(50):
    if i==0:
        test = pd.read_pickle('salida/nuevo4h/SICK/TEST_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4h/SICK/TEST_'+str(i+1)+'.csv_.pickle')
            test=pd.concat([test,temp])
        except:
            print(i+1)

# %%
test = test.reset_index(drop=True)
test
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       1.269651        2.089354   1.685475  3.811686  0.005501  0.190288
# 1       1.327605        2.017728   1.263809  3.855514  0.005729  0.118164
# 2       1.344318        1.950857   1.094914  3.814045  0.005747  0.096256
# 3       0.000000        1.881168   0.000000  0.000000  0.000000  0.000000
# 4       1.360140        1.610893   0.985228  3.978109  0.006914  0.074974
# ...          ...             ...        ...       ...       ...       ...
# 4901    1.313888        1.919241   1.295462  3.715960  0.006520  0.136501
# 4902    1.400464        1.578898   0.721928  3.681429  0.005584  0.019384
# 4903    1.324844        0.747585   0.413817  3.687710  0.006140  0.116333
# 4904    1.307751        1.392618   1.198892  3.814937  0.006552  0.144823
# 4905    1.298070        1.609470   1.530515  3.756346  0.005486  0.156842
#
#          sumas  mutinf_t  mearts_t  max_info_t  ...  list_m  list_T  \
# 0     0.084758  4.041253  0.003165    0.448079  ...       4       5
# 1     0.051589  4.217714  0.002422    0.578176  ...       2       7
# 2     0.052614  4.088408  0.002828    0.490766  ...       2       7
# 3     0.000000  4.683008  0.000000    1.000000  ...       0       8
# 4     0.029070  4.574526  0.000698    0.867853  ...       1       7
# ...        ...       ...       ...         ...  ...     ...     ...
# 4901  0.049228  4.076415  0.003201    0.335569  ...       2       5
# 4902 -0.027277  3.770053  0.004144    0.122140  ...       1       5
# 4903  0.025144  3.697886  0.004207    0.101417  ...       3       4
# 4904  0.081047  3.848196  0.004763    0.146788  ...       5       6
# 4905  0.032010  3.770119  0.004242    0.156880  ...       4       7
#
#       Jaro-Winkler_rit  KL_divergence  negT  verbT  negH  verbH  overlap_ent  \
# 0             0.375000       0.232775     0            0            0.000000
# 1             0.571429       0.249111     0            0            0.666667
# 2             0.428571       0.412795     0            0            0.333333
# 3             1.000000       0.000000     0            0            1.000000
# 4             0.857143       0.277387     0            0            0.833333
# ...                ...            ...   ...    ...   ...    ...          ...
# 4901          0.250000       0.350807     0            0            0.250000
# 4902          0.250000       0.439648     0            0            0.000000
# 4903          0.000000       0.161270     0            0            0.000000
# 4904          0.125000       0.080018     0            0            0.000000
# 4905          0.200000       0.004386     0            0            0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2     CONTRADICTION
# 3        ENTAILMENT
# 4     CONTRADICTION
# ...             ...
# 4901  CONTRADICTION
# 4902  CONTRADICTION
# 4903  CONTRADICTION
# 4904  CONTRADICTION
# 4905  CONTRADICTION
#
# [4906 rows x 31 columns]

# %%
temp1 = pd.read_csv("../OPENAI/data/SICK/original/SICK_TEST.csv")
temp1
# Out:
#                                              sentence_A  \
# 0     There is no boy playing outdoors and there is ...
# 1     A group of boys in a yard is playing and a man...
# 2     A group of children is playing in the house an...
# 3     A brown dog is attacking another animal in fro...
# 4     A brown dog is attacking another animal in fro...
# ...                                                 ...
# 4901    The young girl is blowing a bubble that is huge
# 4902  A dog in a colored coat is running across the ...
# 4903                 A boy is happily playing the piano
# 4904  The girl, who is little, is combing her hair i...
# 4905  A man is in a parking lot and is playing tenni...
#
#                                              sentence_B entailment_label
# 0     A group of kids is playing in a yard and an ol...          NEUTRAL
# 1     The young boys are playing outdoors and the ma...          NEUTRAL
# 2     The young boys are playing outdoors and the ma...          NEUTRAL
# 3     A brown dog is attacking another animal in fro...       ENTAILMENT
# 4     A brown dog is helping another animal in front...          NEUTRAL
# ...                                                 ...              ...
# 4901         There is no girl in pink twirling a ribbon          NEUTRAL
# 4902               The flute is being played by one man          NEUTRAL
# 4903       A white bird is landing swiftly in the water          NEUTRAL
# 4904  Two people wearing helmets are driving over th...          NEUTRAL
# 4905  The snowboarder is leaping fearlessly over whi...          NEUTRAL
#
# [4906 rows x 3 columns]

# %%
test["clases"]=temp1["entailment_label"]
test
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       1.269651        2.089354   1.685475  3.811686  0.005501  0.190288
# 1       1.327605        2.017728   1.263809  3.855514  0.005729  0.118164
# 2       1.344318        1.950857   1.094914  3.814045  0.005747  0.096256
# 3       0.000000        1.881168   0.000000  0.000000  0.000000  0.000000
# 4       1.360140        1.610893   0.985228  3.978109  0.006914  0.074974
# ...          ...             ...        ...       ...       ...       ...
# 4901    1.313888        1.919241   1.295462  3.715960  0.006520  0.136501
# 4902    1.400464        1.578898   0.721928  3.681429  0.005584  0.019384
# 4903    1.324844        0.747585   0.413817  3.687710  0.006140  0.116333
# 4904    1.307751        1.392618   1.198892  3.814937  0.006552  0.144823
# 4905    1.298070        1.609470   1.530515  3.756346  0.005486  0.156842
#
#          sumas  mutinf_t  mearts_t  max_info_t  ...  list_m  list_T  \
# 0     0.084758  4.041253  0.003165    0.448079  ...       4       5
# 1     0.051589  4.217714  0.002422    0.578176  ...       2       7
# 2     0.052614  4.088408  0.002828    0.490766  ...       2       7
# 3     0.000000  4.683008  0.000000    1.000000  ...       0       8
# 4     0.029070  4.574526  0.000698    0.867853  ...       1       7
# ...        ...       ...       ...         ...  ...     ...     ...
# 4901  0.049228  4.076415  0.003201    0.335569  ...       2       5
# 4902 -0.027277  3.770053  0.004144    0.122140  ...       1       5
# 4903  0.025144  3.697886  0.004207    0.101417  ...       3       4
# 4904  0.081047  3.848196  0.004763    0.146788  ...       5       6
# 4905  0.032010  3.770119  0.004242    0.156880  ...       4       7
#
#       Jaro-Winkler_rit  KL_divergence  negT  verbT  negH  verbH  overlap_ent  \
# 0             0.375000       0.232775     0            0            0.000000
# 1             0.571429       0.249111     0            0            0.666667
# 2             0.428571       0.412795     0            0            0.333333
# 3             1.000000       0.000000     0            0            1.000000
# 4             0.857143       0.277387     0            0            0.833333
# ...                ...            ...   ...    ...   ...    ...          ...
# 4901          0.250000       0.350807     0            0            0.250000
# 4902          0.250000       0.439648     0            0            0.000000
# 4903          0.000000       0.161270     0            0            0.000000
# 4904          0.125000       0.080018     0            0            0.000000
# 4905          0.200000       0.004386     0            0            0.000000
#
#           clases
# 0        NEUTRAL
# 1        NEUTRAL
# 2        NEUTRAL
# 3     ENTAILMENT
# 4        NEUTRAL
# ...          ...
# 4901     NEUTRAL
# 4902     NEUTRAL
# 4903     NEUTRAL
# 4904     NEUTRAL
# 4905     NEUTRAL
#
# [4906 rows x 31 columns]

# %%
test=test.drop(["verbH","verbT"],axis=1)
test
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       1.269651        2.089354   1.685475  3.811686  0.005501  0.190288
# 1       1.327605        2.017728   1.263809  3.855514  0.005729  0.118164
# 2       1.344318        1.950857   1.094914  3.814045  0.005747  0.096256
# 3       0.000000        1.881168   0.000000  0.000000  0.000000  0.000000
# 4       1.360140        1.610893   0.985228  3.978109  0.006914  0.074974
# ...          ...             ...        ...       ...       ...       ...
# 4901    1.313888        1.919241   1.295462  3.715960  0.006520  0.136501
# 4902    1.400464        1.578898   0.721928  3.681429  0.005584  0.019384
# 4903    1.324844        0.747585   0.413817  3.687710  0.006140  0.116333
# 4904    1.307751        1.392618   1.198892  3.814937  0.006552  0.144823
# 4905    1.298070        1.609470   1.530515  3.756346  0.005486  0.156842
#
#          sumas  mutinf_t  mearts_t  max_info_t  ...  entropia_relaciones  \
# 0     0.084758  4.041253  0.003165    0.448079  ...             1.000000
# 1     0.051589  4.217714  0.002422    0.578176  ...             0.863121
# 2     0.052614  4.088408  0.002828    0.490766  ...             0.863121
# 3     0.000000  4.683008  0.000000    1.000000  ...             0.000000
# 4     0.029070  4.574526  0.000698    0.867853  ...             0.591673
# ...        ...       ...       ...         ...  ...                  ...
# 4901  0.049228  4.076415  0.003201    0.335569  ...             1.500000
# 4902 -0.027277  3.770053  0.004144    0.122140  ...             1.500000
# 4903  0.025144  3.697886  0.004207    0.101417  ...             1.370951
# 4904  0.081047  3.848196  0.004763    0.146788  ...             1.298795
# 4905  0.032010  3.770119  0.004242    0.156880  ...             0.721928
#
#       list_M  list_m  list_T  Jaro-Winkler_rit  KL_divergence  negT  negH  \
# 0          8       4       5          0.375000       0.232775     0     0
# 1          7       2       7          0.571429       0.249111     0     0
# 2          7       2       7          0.428571       0.412795     0     0
# 3          7       0       8          1.000000       0.000000     0     0
# 4          7       1       7          0.857143       0.277387     0     0
# ...      ...     ...     ...               ...            ...   ...   ...
# 4901       4       2       5          0.250000       0.350807     0     0
# 4902       4       1       5          0.250000       0.439648     0     0
# 4903       5       3       4          0.000000       0.161270     0     0
# 4904       8       5       6          0.125000       0.080018     0     0
# 4905       5       4       7          0.200000       0.004386     0     0
#
#       overlap_ent      clases
# 0        0.000000     NEUTRAL
# 1        0.666667     NEUTRAL
# 2        0.333333     NEUTRAL
# 3        1.000000  ENTAILMENT
# 4        0.833333     NEUTRAL
# ...           ...         ...
# 4901     0.250000     NEUTRAL
# 4902     0.000000     NEUTRAL
# 4903     0.000000     NEUTRAL
# 4904     0.000000     NEUTRAL
# 4905     0.000000     NEUTRAL
#
# [4906 rows x 29 columns]

# %%
#test=test.drop(["sumas","mutinf","list_comp","list_incomp","entidades","entropia_total","list_rel_con",'mearts', 'max_info', 'similitud_faltantes','list_rel_con', 'list_M', 'list_m', 'list_T', 'list_bigram','diferencias'],axis=1)
#test = test[['list_incomp','Jaro-Winkler_rit','overlap_ent','mutinf','list_m','clases']]
test
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       1.269651        2.089354   1.685475  3.811686  0.005501  0.190288
# 1       1.327605        2.017728   1.263809  3.855514  0.005729  0.118164
# 2       1.344318        1.950857   1.094914  3.814045  0.005747  0.096256
# 3       0.000000        1.881168   0.000000  0.000000  0.000000  0.000000
# 4       1.360140        1.610893   0.985228  3.978109  0.006914  0.074974
# ...          ...             ...        ...       ...       ...       ...
# 4901    1.313888        1.919241   1.295462  3.715960  0.006520  0.136501
# 4902    1.400464        1.578898   0.721928  3.681429  0.005584  0.019384
# 4903    1.324844        0.747585   0.413817  3.687710  0.006140  0.116333
# 4904    1.307751        1.392618   1.198892  3.814937  0.006552  0.144823
# 4905    1.298070        1.609470   1.530515  3.756346  0.005486  0.156842
#
#          sumas  mutinf_t  mearts_t  max_info_t  ...  entropia_relaciones  \
# 0     0.084758  4.041253  0.003165    0.448079  ...             1.000000
# 1     0.051589  4.217714  0.002422    0.578176  ...             0.863121
# 2     0.052614  4.088408  0.002828    0.490766  ...             0.863121
# 3     0.000000  4.683008  0.000000    1.000000  ...             0.000000
# 4     0.029070  4.574526  0.000698    0.867853  ...             0.591673
# ...        ...       ...       ...         ...  ...                  ...
# 4901  0.049228  4.076415  0.003201    0.335569  
# 4902     0.000000     NEUTRAL
# 4903     0.000000     NEUTRAL
# 4904     0.000000     NEUTRAL
# 4905     0.000000     NEUTRAL
#
# [4906 rows x 29 columns]

# %%
X_t = test.drop(['clases'],axis=1)
y_t = test['clases']

# %%
# SICK
y_test=[]
for i in y_t:
    if i == "ENTAILMENT":
        y_test.append(1)
    elif i == "NEUTRAL":
        y_test.append(2)
    else:
        y_test.append(0)

# %%
y_test.count(1)
# Out:
# 1404

# %%
y_test.count(0)
# Out:
# 712

# %%
scaler = preprocessing.MaxAbsScaler().fit(X_t)
X_scaled = scaler.transform(X_t)
X_test = X_scaled

# %% [markdown]
# # MODELO DE REGRESIÓN LÓGISTICA

# %%
# grid={"C":np.logspace(-3,3,7), "penalty":["l2"]}# l1 lasso l2 ridge
# logreg=linear_model.LogisticRegression()
# logreg_cv=GridSearchCV(logreg,grid,cv=20)
# logreg_cv.fit(X_train,y_train)

# %%
# print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
# print("accuracy :",logreg_cv.best_score_)

# %%
#X_train = np.where(np.isnan(X_train), 0, X_train)
#X_train

# %%
X_train.shape
# Out:
# (4439, 28)

# %%
model = LogisticRegression(penalty="l2", C=1,max_iter=500)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1, max_iter=500)

# %%
model.get_params()
# Out:
# {'C': 1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 500,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.decision_function(X)
# Out:
# array([[-1.35061611,  1.13642091,  0.2141952 ],
#        [-1.15447326,  0.04949202,  1.10498124],
#        [-0.31922893,  0.25047643,  0.06875251],
#        ...,
#        [-4.50378271, -0.07469179,  4.5784745 ],
#        [-2.75170041, -0.14184187,  2.89354228],
#        [-3.07254916, -1.34537351,  4.41792267]])

# %%
labels=train.columns[:-1]
labels
# Out:
# Index(['distancias', 'entropia_total', 'entropias', 'mutinf', 'mearts',
#        'max_info', 'sumas', 'mutinf_t', 'mearts_t', 'max_info_t', 'sumas_t',
#        'entail', 'contra', 'neutral', 'no_match', 'rel_conceptuales',
#        'list_comp', 'diferencias', 'list_incomp', 'entropia_relaciones',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'KL_divergence',
#        'negT', 'negH', 'overlap_ent'],
#       dtype='object')

# %%
model.classes_
# Out:
# array([0, 1, 2])

# %%
model.coef_[0]
# Out:
# array([ 0.57071993, -0.59161125, -0.18817949,  0.05798925,  0.78401952,
#        -1.08916534, -0.42334067,  1.17032314, -1.61073408,  1.13921991,
#         1.69014897,  0.74433284,  0.32385168, -0.39575088, -0.58131265,
#         0.14430336, -4.26183723,  1.26939547, -0.1312072 , -0.5364292 ,
#         2.77115767, -0.0798176 , -2.59614911,  1.69851344,  0.36963373,
#         2.4066599 ,  2.09630472, -2.46150392])

# %%
coeficientes=model.coef_[0]

# %%
coeficientes
# Out:
# array([ 0.57071993, -0.59161125, -0.18817949,  0.05798925,  0.78401952,
#        -1.08916534, -0.42334067,  1.17032314, -1.61073408,  1.13921991,
#         1.69014897,  0.74433284,  0.32385168, -0.39575088, -0.58131265,
#         0.14430336, -4.26183723,  1.26939547, -0.1312072 , -0.5364292 ,
#         2.77115767, -0.0798176 , -2.59614911,  1.69851344,  0.36963373,
#         2.4066599 ,  2.09630472, -2.46150392])

# %%
print("Maximo,minimo ",np.argmax(coeficientes),labels[np.argmax(coeficientes)],np.argmin(coeficientes),labels[np.argmin(coeficientes)])
# Out:
# Maximo,minimo  20 list_M 16 list_comp

# %%
n_columns=train.shape[1]-1

# %%
n_columns
# Out:
# 28

# %%
import matplotlib.pyplot as plt
import numpy as np

x_v = np.arange(0,n_columns,1)
y_v = coeficientes

plt.bar(x_v,y_v)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Coeficientes')
plt.show()

# %%
#X_test = np.where(np.isnan(X_test), 0, X_test)
#X_test

# %%
X_test.shape
# Out:
# (4906, 28)

# %%
predictions = model.predict(X_test)

# %%
test["predictions"]=predictions
test
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
#
# 2418    0.000000        1.500000        0.0  0.000000  0.000000  0.000000
# 2523    0.000000        1.459148        0.0  0.000000  0.000000  0.000000
# 2554    0.000000        1.974938        0.0  0.000000  0.000000  0.000000
# 2566    0.000000        1.959148        0.0  0.000000  0.000000  0.000000
# 3476    1.380908        1.729135        0.0  3.788694  0.004377  0.046539
# 3786    0.000000        2.103597        0.0  0.000000  0.000000  0.000000
#
#          sumas  mutinf_t  mearts_t  max_info_t  ...  list_M  list_m  list_T  \
# 509   0.000000  4.735449  0.000000    1.000000  ...      11       0      11
# 653   0.000000  4.790041  0.000000    1.000000  ...       5       0       5
# 815   0.000000  4.769319  0.000000    1.000000  ...       4       0       4
# 1006  0.000000  4.643583  0.000000    1.000000  ...       3       0       4
# 1079  0.000000  4.676461  0.000000    1.000000  ...       7       0       7
# 1653  0.000000  4.719374  0.000000    1.000000  ...       4       0       4
# 1678  0.000000  4.768594  0.000000    1.000000  ...       2       0       2
# 1679  0.000000  4.818056  0.000000    1.000000  ...       1       0       2
# 1695  0.000000  4.699422  0.000000    1.000000  ...       2       0       2
# 1790  0.000000  4.639007  0.000000    1.000000  ...       3       0       4
# 2418  0.000000  4.041102  0.002059    0.818802  ...       2       0       2
# 2523  0.000000  4.747314  0.000000    1.000000  ...       2       0       3
# 2554  0.000000  4.731779  0.000000    1.000000  ...       3       0       3
# 2566  0.000000  4.664286  0.000000    1.000000  ...       3       0       4
# 3476  0.017536  4.353841  0.001444    0.709408  ...       5       1       5
# 3786  0.000000  4.720053  0.000000    1.000000  ...       4       0       7
#
#       Jaro-Winkler_rit  KL_divergence  negT  negH  overlap_ent      clases  \
# 509           1.000000       0.000000     0     0     0.666667  ENTAILMENT
# 653           0.800000       0.000000     0     0     0.500000  ENTAILMENT
# 815           1.000000       0.000000     0     0     0.666667  ENTAILMENT
# 1006          1.000000       0.000000     0     0     0.333333  ENTAILMENT
# 1079          0.714286       0.000000     0     0     0.500000  ENTAILMENT
# 1653          1.000000       0.000000     0     0     0.600000  ENTAILMENT
# 1678          1.000000       0.000000     0     0     0.666667  ENTAILMENT
# 1679          1.000000       0.000000     0     0     0.500000  ENTAILMENT
# 1695          1.000000       0.000000     0     0     0.666667  ENTAILMENT
# 1790          1.000000       0.000000     0     0     0.333333  ENTAILMENT
# 2418          1.000000       0.000000     0     0     0.000000  ENTAILMENT
# 2523          1.000000       0.000000     0     0     0.666667  ENTAILMENT
# 2554          1.000000       0.000000     0     0     0.666667  ENTAILMENT
# 2566          1.000000       0.000000     0     0     0.666667  ENTAILMENT
# 3476          0.800000       0.736966     0     1     0.600000  ENTAILMENT
# 3786          0.750000       0.000000     0     0     0.333333  ENTAILMENT
#
#       predictions
# 509             0
# 653             0
# 815             0
# 1006            0
# 1079            0
# 1653            0
# 1678            0
# 1679            0
# 1695            0
# 1790            0
# 2418            0
# 2523            0
# 2554            0
# 2566            0
# 3476            0
# 3786            0
#
# [16 rows x 30 columns]

# %%
#test.to_csv("predictions_SICK_DEV.csv")

# %%
print(confusion_matrix(y_test, predictions,labels=[1,2,0]))
# Out:
# [[1109  279   16]
#  [ 382 2371   37]
#  [ 184  153  375]]

# %%
# [[1055  311   38]
#  [ 357 2341   92]
#  [ 132  216  364]]
# [[1016  369   19]
#  [ 277 2475   38]
#  [ 173  159  380]]
#  acccuracy:  0.79
# precision:  0.79
# recall 0.79
# f1_score:  0.78
# matthews_score:  0.62

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions,average="weighted"),2))
print("recall",round(recall_score(y_test,predictions,average="weighted"),2))
print("f1_score: ",round(f1_score(y_test,predictions,average="weighted"),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.79
# precision:  0.8
# recall 0.79
# f1_score:  0.78
# matthews_score:  0.62

# %%
X_train.shape
# Out:
# (4439, 28)

# %%
X_test.shape
# Out:
# (4906, 28)

# %%
X_cv=np.concatenate((X_train, X_test), axis=0)
Y_cv=np.concatenate((y_train, y_test), axis=0)

# %%
#validation_size = 0.20
#X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)
X_train_cv=X_cv
Y_train_cv=Y_cv

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name + " Acurracy:" , round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_weighted')
msg += "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_weighted')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_weighted')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Acurracy:: 0.780000 (0.025850)
# Logistic Regression Precision:: 0.790000 (0.028826)
# Logistic Regression Recall:: 0.780000 (0.025850)
# Logistic Regression F1-score:: 0.780000 (0.026110)

# %%
# Logistic Regression Acurracy:: 0.770000 (0.032756)
# Logistic Regression Precision:: 0.780000 (0.034664)
# Logistic Regression Recall:: 0.770000 (0.032756)
# Logistic Regression F1-score:: 0.770000 (0.032888)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_macro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_macro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_macro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.770000 (0.036984)
# Logistic Regression Recall:: 0.720000 (0.045565)
# Logistic Regression F1-score:: 0.730000 (0.041682)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_micro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_micro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_micro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.780000 (0.025850)
# Logistic Regression Recall:: 0.780000 (0.025850)
# Logistic Regression F1-score:: 0.780000 (0.025850)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='matthews_corrcoef')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.610000 (0.063474)

# %%
import shap
import pandas as pd
import numpy as np
shap.initjs()
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
#linear_model

# %%
# model = LogisticRegression()
# model.fit(X_train,y_train)

# %%
y_predict = model.predict(X_test)
print(classification_report( y_test,y_predict))
print(confusion_matrix( y_test,y_predict,labels=[0,1,2]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.53      0.66       712
#            1       0.66      0.79      0.72      1404
#            2       0.85      0.85      0.85      2790
#
#     accuracy                           0.79      4906
#    macro avg       0.79      0.72      0.74      4906
# weighted avg       0.80      0.79      0.78      4906
#
# [[ 375  184  153]
#  [  16 1109  279]
#  [  37  382 2371]]

# %%
#   precision    recall  f1-score   support

#            0       0.87      0.53      0.66       712
#            1       0.67      0.79      0.72      1404
#            2       0.85      0.85      0.85      2790

#     accuracy                           0.79      4906
#    macro avg       0.79      0.72      0.74      4906
# weighted avg       0.80      0.79      0.79      4906

# [[ 379  182  151]
#  [  19 1105  280]
#  [  39  372 2379]]

# %%
#   precision    recall  f1-score   support

#            0       0.87      0.53      0.66       712
#            1       0.69      0.72      0.71      1404
#            2       0.82      0.89      0.85      2790

#     accuracy                           0.79      4906
#    macro avg       0.80      0.71      0.74      4906
# weighted avg       0.79      0.79      0.78      4906

# [[ 380  173  159]
#  [  19 1016  369]
#  [  38  277 2475]]

# %%
#            0       0.87      0.53      0.66       712
#            1       0.68      0.73      0.70      1404
#            2       0.82      0.87      0.85      2790

#     accuracy                           0.78      4906
#    macro avg       0.79      0.71      0.74      4906
# weighted avg       0.79      0.78      0.78      4906

# %%
explainer = shap.Explainer(model,X_train,feature_names=test.columns[:-2])
shap_values = explainer(X_test)

# %%
test.columns
# Out:
# Index(['distancias', 'entropia_total', 'entropias', 'mutinf', 'mearts',
#        'max_info', 'sumas', 'mutinf_t', 'mearts_t', 'max_info_t', 'sumas_t',
#        'list_comp', 'diferencias', 'list_incomp', 'entropia_relaciones',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'KL_divergence',
#        'negT', 'negH', 'overlap_ent', 'clases', 'predictions'],
#       dtype='object')

# %%
test.columns[:-2]
# Out:
# Index(['distancias', 'entropia_total', 'entropias', 'mutinf', 'mearts',
#        'max_info', 'sumas', 'mutinf_t', 'mearts_t', 'max_info_t', 'sumas_t',
#        'list_comp', 'diferencias', 'list_incomp', 'entropia_relaciones',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'KL_divergence',
#        'negT', 'negH', 'overlap_ent'],
#       dtype='object')

# %%
explainer.expected_value
# Out:
# array([-1.10106342,  0.06391734,  1.03714608])

# %%
X_test
# Out:
# array([[0.87330036, 0.68306189, 0.579461  , ..., 0.        , 0.        ,
#         0.        ],
#        [0.91316265, 0.65964568, 0.43449354, ..., 0.        , 0.        ,
#         0.66666667],
#        [0.9246584 , 0.63778378, 0.37642803, ..., 0.        , 0.        ,
#         0.33333333],
#        ...,
#        [0.91400573, 0.24440408, 0.22985031, ..., 0.        , 0.        ,
#         0.        ],
#        [0.90080125, 0.45528147, 0.42378464, ..., 0.        , 0.        ,
#         0.        ],
#        [0.89284748, 0.52617594, 0.52618599, ..., 0.        , 0.        ,
#         0.        ]])

# %%
shap.plots.beeswarm(shap_values[:,:,1])

# %%
shap.plots.beeswarm(shap_values[:,:,0])

# %%
shap.plots.beeswarm(shap_values[:,:,2])

# %%
ind = 21
print(X_test[ind],y_test[ind],y_predict[ind])
shap.plots.force(shap_values[ind])
shap.plots.waterfall(shap_values[ind])
# Out:
# [0.4751967  0.24555819 0.87544949 0.78537126 0.93112685 0.10731264
#  0.47481402 0.25       0.0952381  0.         0.375      0.25
#  0.4        0.83333333 0.         0.         0.25      ] 2 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 3
#       1 ind = 21
#       2 print(X_test[ind],y_test[ind],y_predict[ind])
# ----> 3 shap.plots.force(shap_values[ind])
#       4 shap.plots.waterfall(shap_values[ind])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:129, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     122     if not isinstance(shap_values, list) or len(shap_values) != len(base_value):
#     123         emsg = (
#     124             "In v0.20, force plot now requires the base value as the first parameter! "
#     125             "Try shap.plots.force(explainer.expected_value, shap_values) or "
#     126             "for multi-output models try "
#     127             "shap.plots.force(explainer.expected_value[0], shap_values[0])."
#     128         )
# --> 129         raise TypeError(emsg)
#     131 if isinstance(shap_values, list):
#     132     emsg = "The shap_values arg looks multi output, try `shap_values[i]` instead."
#
# TypeError: In v0.20, force plot now requires the base value as the first parameter! Try shap.plots.force(explainer.expected_value, shap_values) or for multi-output models try shap.plots.force(explainer.expected_value[0], shap_values[0]).

# %%
ind = 6
print(X_test[ind])
# This amazing documentary gives us a glimpse into the lives of the brave
# women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
# tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
# languages and multiple legal precedents depending on the region of the country and
# the religious/ethnic background of the plaintiffs and defendants-- these brave,
# strong women are making a difference. [...]

shap.plots.waterfall(shap_values[ind,:,1])
# Out:
# [0.         0.         0.         0.         0.         0.
#  0.25925926 0.         0.31428571 0.33333333 0.         0.66666667]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[122], line 10
#       2 print(X_test[ind])
#       3 # This amazing documentary gives us a glimpse into the lives of the brave
#       4 # women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
#       5 # tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
#       6 # languages and multiple legal precedents depending on the region of the country and
#       7 # the religious/ethnic background of the plaintiffs and defendants-- these brave,
#       8 # strong women are making a difference. [...]
# ---> 10 shap.plots.waterfall(shap_values[ind,:,1])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/_explanation.py:422, in Explanation.__getitem__(self, item)
#     420 if new_self is None:
#     421     new_self = copy.copy(self)
# --> 422 new_self._s = new_self._s.__getitem__(item)
#     423 new_self.op_history.append({
#     424     "name": "__getitem__",
#     425     "args": (item,),
#     426     "prev_shape": self.shape
#     427 })
#     429 return new_self
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer.py:112, in Slicer.__getitem__(self, item)
#     110 index_slicer = AtomicSlicer(index_tup, max_dim=1)
#     111 slicer_index = index_slicer[tracked.dim]
# --> 112 sliced_o = tracked[slicer_index]
#     113 sliced_dim = resolve_dim(index_tup, tracked.dim)
#     115 new_tracked = tracked.__class__(sliced_o, sliced_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:582, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     579 head_slice = cls.type_map[o_type].head_slice
#     580 tail_slice = cls.type_map[o_type].tail_slice
# --> 582 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
#     583 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     584 return out
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:418, in ArrayHandler.head_slice(cls, o, index_tup, max_dim)
#     416 cut_index = index_tup[:cut]
#     417 is_element = any([True if isinstance(x, int) else False for x in cut_index])
# --> 418 sliced_o = o[cut_index]
#     420 return is_element, sliced_o, cut
#
# IndexError: index 1 is out of bounds for axis 2 with size 1

# %%
shap.summary_plot(shap_values[:,:,1], X_test,plot_type="bar")

# %%
shap.summary_plot(shap_values[:,:,2], X_test,plot_type="bar")

# %%
X_test
# Out:
# array([[0.87330036, 0.68306189, 0.579461  , ..., 0.        , 0.        ,
#         0.        ],
#        [0.91316265, 0.65964568, 0.43449354, ..., 0.        , 0.        ,
#         0.66666667],
#        [0.9246584 , 0.63778378, 0.37642803, ..., 0.        , 0.        ,
#         0.33333333],
#        ...,
#        [0.91400573, 0.24440408, 0.22985031, ..., 0.        , 0.        ,
#         0.        ],
#        [0.90080125, 0.45528147, 0.42378464, ..., 0.        , 0.        ,
#         0.        ],
#        [0.89284748, 0.52617594, 0.52618599, ..., 0.        , 0.        ,
#         0.        ]])

# %%
shap.summary_plot(shap_values[:,:,0], X_test,plot_type="bar")

# %%
shap.summary_plot(shap_values[1:,], X_test[1:,])

# %%
shap.summary_plot(shap_values, X_test,feature_names=test.columns[:-1])

# %%
shap_values[2:,]
# Out:
# .values =
# array([[ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [-0.01299836, -0.11268555, -0.4045574 ,  0.04382668,  0.21114683],
#        ...,
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683]])
#
# .base_values =
# array([-0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388])
#
# .data =
# array([[-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [ 1.23549291,  0.39218921,  0.29047164,  0.24312215, -0.67101221],
#        ...,
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221]])

# %%
shap.summary_plot(shap_values[0:,], X_test,feature_names=test.columns[:-1])

# %%
explainer.expected_value
# Out:
# -0.7454438806409415

# %%
shap_values.shape
# Out:
# (800, 5)

# %% [markdown]
# # Árbol de decisión

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
clf = DecisionTreeClassifier(splitter="random")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print("acccuracy: ",round(accuracy_score(y_test,y_pred),2))
print("precision: ",round(precision_score(y_test,y_pred),2))
print("recall",round(recall_score(y_test,y_pred),2))
print("f1_score: ",round(f1_score(y_test,y_pred),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,y_pred),2))
# Out:
# acccuracy:  0.67
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 2
#       1 print("acccuracy: ",round(accuracy_score(y_test,y_pred),2))
# ----> 2 print("precision: ",round(precision_score(y_test,y_pred),2))
#       3 print("recall",round(recall_score(y_test,y_pred),2))
#       4 print("f1_score: ",round(f1_score(y_test,y_pred),2))
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2131, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1973 @validate_params(
#    1974     {
#    1975         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2000     zero_division="warn",
#    2001 ):
#    2002     """Compute the precision.
#    2003
#    2004     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2129     array([0.5, 1. , 1. ])
#    2130     """
# -> 2131     p, _, _, _ = precision_recall_fscore_support(
#    2132         y_true,
#    2133         y_pred,
#    2134         labels=labels,
#    2135         pos_label=pos_label,
#    2136         average=average,
#    2137         warn_for=("precision",),
#    2138         sample_weight=sample_weight,
#    2139         zero_division=zero_division,
#    2140     )
#    2141     return p
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1518, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1516         if y_type == "multiclass":
#    1517             average_options.remove("samples")
# -> 1518         raise ValueError(
#    1519             "Target is %s but average='binary'. Please "
#    1520             "choose another average setting, one of %r." % (y_type, average_options)
#    1521         )
#    1522 elif pos_label not in (None, 1):
#    1523     warnings.warn(
#    1524         "Note that pos_label (set to %r) is ignored when "
#    1525         "average != 'binary' (got %r). You may use "
#    (...)
#    1528         UserWarning,
#    1529     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
validation_size = 0.01
X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)

# %%
name='DecisionTree'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_weighted')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_weighted')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_weighted')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# DecisionTree: 0.680000 (0.014004)
# DecisionTree: 0.680000 (0.010178)
# DecisionTree: 0.680000 (0.013535)
# DecisionTree: 0.680000 (0.011671)

# %%
name='DecisionTree'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_macro')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_macro')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_macro')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# DecisionTree: 0.680000 (0.015553)
# DecisionTree: 0.580000 (0.018540)
# DecisionTree: 0.580000 (0.016293)
# DecisionTree: 0.580000 (0.019133)

# %%
c=train.columns[:-1]
confusion_matrix(y_test,y_pred,labels=[1,2,0])
# Out:
# array([[ 860,  303,  241],
#        [ 455, 2150,  185],
#        [ 288,  158,  266]])

# %%
# Estructura del árbol creado
import matplotlib.pyplot as plt
# ------------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(20, 10))

print(f"Profundidad del árbol: {clf.get_depth()}")
print(f"Número de nodos terminales: {clf.get_n_leaves()}")

plot = plot_tree(
            decision_tree = clf,
            feature_names = c,
            class_names   = True,
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 23
# Número de nodos terminales: 152
