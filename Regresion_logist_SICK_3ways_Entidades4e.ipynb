# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV

# %%
for i in range(45):
    if i==0:
        train = pd.read_pickle('salida/nuevo4e/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4e/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
            train=pd.concat([train,temp])
        except:
            print(i+1)

# %%
train=train.reset_index(drop=True)
train
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.000000    0.000000           2.097      0.000  0.000000  0.000000
# 1     0.516922    1.424649           1.913      1.379  3.886845  0.005261
# 2     0.000000    0.000000           2.176      0.000  0.000000  0.000000
# 3     0.389672    5.665914           1.909      1.684  3.834346  0.006025
# 4     0.832495    8.487221           2.183      2.056  3.847619  0.005217
# ...        ...         ...             ...        ...       ...       ...
# 4434  0.062812    5.751723           1.053      0.811  3.786475  0.006455
# 4435  0.073710    5.698565           1.384      1.384  3.779084  0.008525
# 4436  0.298256    8.566221           1.688      1.688  3.742518  0.005599
# 4437  0.358468    1.437292           1.411      1.459  3.685267  0.004270
# 4438  0.050495    4.331006           1.299      1.252  3.837828  0.005040
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.000000          1     0.000000            0       7       0       8
# 1     0.299131          2     0.142857            0       8       1       7
# 2     0.000000          1     0.000000            0       5       0       7
# 3     0.180114          1     0.800000            0       8       4       5
# 4     0.287820          2     0.857143            1       8       6       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4434  0.084316          1     1.333333            0       6       4       3
# 4435  0.056842          0     1.333333            0       4       4       3
# 4436  0.195824          3     1.200000            1       6       6       5
# 4437  0.156616          1     0.166667            0       3       1       6
# 4438  0.068946          1     0.750000            0       4       3       4
#
#       Jaro-Winkler_rit  negT verbT  negH verbH  overlap_ent         clases
# 0             0.857143     0           0           0.800000  CONTRADICTION
# 1             0.875000     0           0           0.333333  CONTRADICTION
# 2             1.000000     0           0           0.400000     ENTAILMENT
# 3             0.375000     0           0           0.333333  CONTRADICTION
# 4             0.500000     0           0           0.166667  CONTRADICTION
# ...                ...   ...   ...   ...   ...          ...            ...
# 4434          0.333333     0           0           0.200000  CONTRADICTION
# 4435          0.250000     0           1  play     0.000000  CONTRADICTION
# 4436          0.000000     0           0           0.000000  CONTRADICTION
# 4437          0.333333     0           0           0.333333  CONTRADICTION
# 4438          0.000000     0           0           0.000000  CONTRADICTION
#
# [4439 rows x 20 columns]

# %%
temp1 = pd.read_csv("../OPENAI/data/SICK/original/SICK_TRAIN.csv")
temp1
# Out:
#                                              sentence_A  \
# 0     A group of kids is playing in a yard and an ol...
# 1     A group of children is playing in the house an...
# 2     The young boys are playing outdoors and the ma...
# 3     The kids are playing outdoors near a man with ...
# 4     The young boys are playing outdoors and the ma...
# ...                                                 ...
# 4434                    A door is being opened by a man
# 4435                   Someone is boiling okra in a pot
# 4436  The man is singing heartily and playing the gu...
# 4437        A man in blue has a yellow ball in the mitt
# 4438               Three dogs are resting on a sidewalk
#
#                                              sentence_B entailment_label
# 0     A group of boys in a yard is playing and a man...          NEUTRAL
# 1     A group of kids is playing in a yard and an ol...          NEUTRAL
# 2     The kids are playing outdoors near a man with ...       ENTAILMENT
# 3     A group of kids is playing in a yard and an ol...          NEUTRAL
# 4     A group of kids is playing in a yard and an ol...          NEUTRAL
# ...                                                 ...              ...
# 4434  A bald man in a band is playing guitar in the ...          NEUTRAL
# 4435                   The man is not playing the drums          NEUTRAL
# 4436  A bicyclist is holding a bike over his head in...          NEUTRAL
# 4437                      A man is jumping rope outside          NEUTRAL
# 4438         The woman with a knife is slicing a pepper          NEUTRAL
#
# [4439 rows x 3 columns]

# %%
train["clases"]=temp1["entailment_label"]
train
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.000000    0.000000           2.097      0.000  0.000000  0.000000
# 1     0.516922    1.424649           1.913      1.379  3.886845  0.005261
# 2     0.000000    0.000000           2.176      0.000  0.000000  0.000000
# 3     0.389672    5.665914           1.909      1.684  3.834346  0.006025
# 4     0.832495    8.487221           2.183      2.056  3.847619  0.005217
# ...        ...         ...             ...        ...       ...       ...
# 4434  0.062812    5.751723           1.053      0.811  3.786475  0.006455
# 4435  0.073710    5.698565           1.384      1.384  3.779084  0.008525
# 4436  0.298256    8.566221           1.688      1.688  3.742518  0.005599
# 4437  0.358468    1.437292           1.411      1.459  3.685267  0.004270
# 4438  0.050495    4.331006           1.299      1.252  3.837828  0.005040
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.000000          1     0.000000            0       7       0       8
# 1     0.299131          2     0.142857            0       8       1       7
# 2     0.000000          1     0.000000            0       5       0       7
# 3     0.180114          1     0.800000            0       8       4       5
# 4     0.287820          2     0.857143            1       8       6       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4434  0.084316          1     1.333333            0       6       4       3
# 4435  0.056842          0     1.333333            0       4       4       3
# 4436  0.195824          3     1.200000            1       6       6       5
# 4437  0.156616          1     0.166667            0       3       1       6
# 4438  0.068946          1     0.750000            0       4       3       4
#
#       Jaro-Winkler_rit  negT verbT  negH verbH  overlap_ent      clases
# 0             0.857143     0           0           0.800000     NEUTRAL
# 1             0.875000     0           0           0.333333     NEUTRAL
# 2             1.000000     0           0           0.400000  ENTAILMENT
# 3             0.375000     0           0           0.333333     NEUTRAL
# 4             0.500000     0           0           0.166667     NEUTRAL
# ...                ...   ...   ...   ...   ...          ...         ...
# 4434          0.333333     0           0           0.200000     NEUTRAL
# 4435          0.250000     0           1  play     0.000000     NEUTRAL
# 4436          0.000000     0           0           0.000000     NEUTRAL
# 4437          0.333333     0           0           0.333333     NEUTRAL
# 4438          0.000000     0           0           0.000000     NEUTRAL
#
# [4439 rows x 20 columns]

# %%
train.boxplot(by="clases",column="list_incomp")
# Out:
# <Axes: title={'center': 'list_incomp'}, xlabel='clases'>

# %% [markdown]
# ## Eliminar características

# %%
# Diferencia entre entropia total - entropias y dejar la columna
# Quitar max_info_p
# revisar scaler y/o normalización de shape con total
#
train=train.drop(["verbH","verbT"],axis=1)
#train=train.drop(["Match"],axis=1)
train
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.000000    0.000000           2.097      0.000  0.000000  0.000000
# 1     0.516922    1.424649           1.913      1.379  3.886845  0.005261
# 2     0.000000    0.000000           2.176      0.000  0.000000  0.000000
# 3     0.389672    5.665914           1.909      1.684  3.834346  0.006025
# 4     0.832495    8.487221           2.183      2.056  3.847619  0.005217
# ...        ...         ...             ...        ...       ...       ...
# 4434  0.062812    5.751723           1.053      0.811  3.786475  0.006455
# 4435  0.073710    5.698565           1.384      1.384  3.779084  0.008525
# 4436  0.298256    8.566221           1.688      1.688  3.742518  0.005599
# 4437  0.358468    1.437292           1.411      1.459  3.685267  0.004270
# 4438  0.050495    4.331006           1.299      1.252  3.837828  0.005040
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.000000          1     0.000000            0       7       0       8
# 1     0.299131          2     0.142857            0       8       1       7
# 2     0.000000          1     0.000000            0       5       0       7
# 3     0.180114          1     0.800000            0       8       4       5
# 4     0.287820          2     0.857143            1       8       6       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4434  0.084316          1     1.333333            0       6       4       3
# 4435  0.056842          0     1.333333            0       4       4       3
# 4436  0.195824          3     1.200000            1       6       6       5
# 4437  0.156616          1     0.166667            0       3       1       6
# 4438  0.068946          1     0.750000            0       4       3       4
#
#       Jaro-Winkler_rit  negT  negH  overlap_ent      clases
# 0             0.857143     0     0     0.800000     NEUTRAL
# 1             0.875000     0     0     0.333333     NEUTRAL
# 2             1.000000     0     0     0.400000  ENTAILMENT
# 3             0.375000     0     0     0.333333     NEUTRAL
# 4             0.500000     0     0     0.166667     NEUTRAL
# ...                ...   ...   ...          ...         ...
# 4434          0.333333     0     0     0.200000     NEUTRAL
# 4435          0.250000     0     1     0.000000     NEUTRAL
# 4436          0.000000     0     0     0.000000     NEUTRAL
# 4437          0.333333     0     0     0.333333     NEUTRAL
# 4438          0.000000     0     0     0.000000     NEUTRAL
#
# [4439 rows x 18 columns]

# %%
#train = train[['list_incomp','Jaro-Winkler_rit','overlap_ent','mutinf','list_m','clases']]

# %%
train.columns
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'negT', 'negH',
#        'overlap_ent', 'clases'],
#       dtype='object')

# %%
#train=train[['list_comp', 'list_incomp','list_m','negT', 'negH',"clases"]]

# %%
X = train.drop(['clases'],axis=1)
y_ = train['clases']

# %%
# Guardar un nuevo dataframe para la correlación de variables
train_m=train.drop(['clases'],axis=1).corr(method='pearson')

# %%
train_m
# Out:
#                      sumas  distancias  entropia_total  entropias    mutinf  \
# sumas             1.000000    0.363547        0.341465   0.762844  0.648115
# distancias        0.363547    1.000000       -0.012883   0.691539  0.654614
# entropia_total    0.341465   -0.012883        1.000000   0.277554  0.072564
# entropias         0.762844    0.691539        0.277554   1.000000  0.874748
# mutinf            0.648115    0.654614        0.072564   0.874748  1.000000
# mearts            0.400556    0.566832       -0.006661   0.681901  0.822951
# max_info          0.892786    0.372621        0.287666   0.774868  0.701428
# list_comp         0.005026    0.127920        0.135736   0.070813  0.079013
# diferencias       0.238546    0.884405       -0.096237   0.613360  0.630939
# list_incomp       0.386175    0.370696        0.088263   0.399911  0.344516
# list_M            0.216374    0.428857        0.251743   0.248072  0.186650
# list_m            0.366102    0.999796       -0.012878   0.691596  0.655295
# list_T            0.308164    0.120993        0.254476   0.162282  0.066845
# Jaro-Winkler_rit -0.185410   -0.621364        0.130767  -0.486982 -0.522950
# negT             -0.055860   -0.051368       -0.024774  -0.071500 -0.094795
# negH             -0.044131    0.073344       -0.043260   0.033075  0.144442
# overlap_ent      -0.262928   -0.662355        0.050032  -0.540978 -0.549448
#
#                     mearts  max_info  list_comp  diferencias  list_incomp  \
# sumas             0.400556  0.892786   0.005026     0.238546     0.386175
# distancias        0.566832  0.372621   0.127920     0.884405     0.370696
# entropia_total   -0.006661  0.287666   0.135736    -0.096237     0.088263
# entropias         0.681901  0.774868   0.070813     0.613360     0.399911
# mutinf            0.822951  0.701428   0.079013     0.630939     0.344516
# mearts            1.000000  0.461606   0.070462     0.598329     0.255767
# max_info          0.461606  1.000000  -0.045217     0.321641     0.522675
# list_comp         0.070462 -0.045217   1.000000     0.063959    -0.200556
# diferencias       0.598329  0.321641   0.063959     1.000000     0.333982
# list_incomp       0.255767  0.522675  -0.200556     0.333982     1.000000
# list_M            0.109963  0.098723   0.213119     0.222542     0.070888
# list_m            0.570738  0.374065   0.126807     0.887679     0.370209
# list_T           -0.035139  0.125558   0.100918    -0.196375     0.056491
# Jaro-Winkler_rit -0.489665 -0.225216  -0.179155    -0.662950    -0.104629
# negT             -0.087811 -0.055487  -0.052357    -0.066649    -0.036201
# negH              0.095024 -0.034390  -0.043872     0.080445    -0.029641
# overlap_ent      -0.509680 -0.295742  -0.398323    -0.665597    -0.209268
#
#                     list_M    list_m    list_T  Jaro-Winkler_rit      negT  \
# sumas             0.216374  0.366102  0.308164         -0.185410 -0.055860
# distancias        0.428857  0.999796  0.120993         -0.621364 -0.051368
# entropia_total    0.251743 -0.012878  0.254476          0.130767 -0.024774
# entropias         0.248072  0.691596  0.162282         -0.486982 -0.071500
# mutinf            0.186650  0.655295  0.066845         -0.522950 -0.094795
# mearts            0.109963  0.570738 -0.035139         -0.489665 -0.087811
# max_info          0.098723  0.374065  0.125558         -0.225216 -0.055487
# list_comp         0.213119  0.126807  0.100918         -0.179155 -0.052357
# diferencias       0.222542  0.887679 -0.196375         -0.662950 -0.066649
# list_incomp       0.070888  0.370209  0.056491         -0.104629 -0.036201
# list_M            1.000000  0.427229  0.667383         -0.006067 -0.040202
# list_m            0.427229  1.000000  0.116332         -0.622335 -0.051921
# list_T            0.667383  0.116332  1.000000          0.151661  0.048223
# Jaro-Winkler_rit -0.006067 -0.622335  0.151661          1.000000  0.077208
# negT             -0.040202 -0.051921  0.048223          0.077208  1.000000
# negH              0.081634  0.073466 -0.030675         -0.031086 -0.047197
# overlap_ent      -0.015454 -0.663229  0.076854          0.654934  0.106775
#
#                       negH  overlap_ent
# sumas            -0.044131    -0.262928
# distancias        0.073344    -0.662355
# entropia_total   -0.043260     0.050032
# entropias         0.033075    -0.540978
# mutinf            0.144442    -0.549448
# mearts            0.095024    -0.509680
# max_info         -0.034390    -0.295742
# list_comp        -0.043872    -0.398323
# diferencias       0.080445    -0.665597
# list_incomp      -0.029641    -0.209268
# list_M            0.081634    -0.015454
# list_m            0.073466    -0.663229
# list_T           -0.030675     0.076854
# Jaro-Winkler_rit -0.031086     0.654934
# negT             -0.047197     0.106775
# negH              1.000000     0.003750
# overlap_ent       0.003750     1.000000

# %%
sns.heatmap(train_m,vmin=-1,vmax=1)
# Out:
# <Axes: >

# %%
train_m
# Out:
#                      sumas  distancias  entropia_total  entropias    mutinf  \
# sumas             1.000000    0.363547        0.341465   0.762844  0.648115
# distancias        0.363547    1.000000       -0.012883   0.691539  0.654614
# entropia_total    0.341465   -0.012883        1.000000   0.277554  0.072564
# entropias         0.762844    0.691539        0.277554   1.000000  0.874748
# mutinf            0.648115    0.654614        0.072564   0.874748  1.000000
# mearts            0.400556    0.566832       -0.006661   0.681901  0.822951
# max_info          0.892786    0.372621        0.287666   0.774868  0.701428
# list_comp         0.005026    0.127920        0.135736   0.070813  0.079013
# diferencias       0.238546    0.884405       -0.096237   0.613360  0.630939
# list_incomp       0.386175    0.370696        0.088263   0.399911  0.344516
# list_M            0.216374    0.428857        0.251743   0.248072  0.186650
# list_m            0.366102    0.999796       -0.012878   0.691596  0.655295
# list_T            0.308164    0.120993        0.254476   0.162282  0.066845
# Jaro-Winkler_rit -0.185410   -0.621364        0.130767  -0.486982 -0.522950
# negT             -0.055860   -0.051368       -0.024774  -0.071500 -0.094795
# negH             -0.044131    0.073344       -0.043260   0.033075  0.144442
# overlap_ent      -0.262928   -0.662355        0.050032  -0.540978 -0.549448
#
#                     mearts  max_info  list_comp  diferencias  list_incomp  \
# sumas             0.400556  0.892786   0.005026     0.238546     0.386175
# distancias        0.566832  0.372621   0.127920     0.884405     0.370696
# entropia_total   -0.006661  0.287666   0.135736    -0.096237     0.088263
# entropias         0.681901  0.774868   0.070813     0.613360     0.399911
# mutinf            0.822951  0.701428   0.079013     0.630939     0.344516
# mearts            1.000000  0.461606   0.070462     0.598329     0.255767
# max_info          0.461606  1.000000  -0.045217     0.321641     0.522675
# list_comp         0.070462 -0.045217   1.000000     0.063959    -0.200556
# diferencias       0.598329  0.321641   0.063959     1.000000     0.333982
# list_incomp       0.255767  0.522675  -0.200556     0.333982     1.000000
# list_M            0.109963  0.098723   0.213119     0.222542     0.070888
# list_m            0.570738  0.374065   0.126807     0.887679     0.370209
# list_T           -0.035139  0.125558   0.100918    -0.196375     0.056491
# Jaro-Winkler_rit -0.489665 -0.225216  -0.179155    -0.662950    -0.104629
# negT             -0.087811 -0.055487  -0.052357    -0.066649    -0.036201
# negH              0.095024 -0.034390  -0.043872     0.080445    -0.029641
# overlap_ent      -0.509680 -0.295742  -0.398323    -0.665597    -0.209268
#
#                     list_M    list_m    list_T  Jaro-Winkler_rit      negT  \
# sumas             0.216374  0.366102  0.308164         -0.185410 -0.055860
# distancias        0.428857  0.999796  0.120993         -0.621364 -0.051368
# entropia_total    0.251743 -0.012878  0.254476          0.130767 -0.024774
# entropias         0.248072  0.691596  0.162282         -0.486982 -0.071500
# mutinf            0.186650  0.655295  0.066845         -0.522950 -0.094795
# mearts            0.109963  0.570738 -0.035139         -0.489665 -0.087811
# max_info          0.098723  0.374065  0.125558         -0.225216 -0.055487
# list_comp         0.213119  0.126807  0.100918         -0.179155 -0.052357
# diferencias       0.222542  0.887679 -0.196375         -0.662950 -0.066649
# list_incomp       0.070888  0.370209  0.056491         -0.104629 -0.036201
# list_M            1.000000  0.427229  0.667383         -0.006067 -0.040202
# list_m            0.427229  1.000000  0.116332         -0.622335 -0.051921
# list_T            0.667383  0.116332  1.000000          0.151661  0.048223
# Jaro-Winkler_rit -0.006067 -0.622335  0.151661          1.000000  0.077208
# negT             -0.040202 -0.051921  0.048223          0.077208  1.000000
# negH              0.081634  0.073466 -0.030675         -0.031086 -0.047197
# overlap_ent      -0.015454 -0.663229  0.076854          0.654934  0.106775
#
#                       negH  overlap_ent
# sumas            -0.044131    -0.262928
# distancias        0.073344    -0.662355
# entropia_total   -0.043260     0.050032
# entropias         0.033075    -0.540978
# mutinf            0.144442    -0.549448
# mearts            0.095024    -0.509680
# max_info         -0.034390    -0.295742
# list_comp        -0.043872    -0.398323
# diferencias       0.080445    -0.665597
# list_incomp      -0.029641    -0.209268
# list_M            0.081634    -0.015454
# list_m            0.073466    -0.663229
# list_T           -0.030675     0.076854
# Jaro-Winkler_rit -0.031086     0.654934
# negT             -0.047197     0.106775
# negH              1.000000     0.003750
# overlap_ent       0.003750     1.000000

# %%
# Checar variables colineales
#sns.relplot(data=train_m, x="list_bigram", y="bi_ent_trip_rel")

# %%
#X_dev = np.array(dev.drop(['CLASS'],axis=1))
#y_d = np.array(dev['CLASS'])

# %%
# SICK
y_train=[]
for i in y_:
    if i == "ENTAILMENT":
        y_train.append(1)
    elif i == "NEUTRAL":
        y_train.append(2)
    else:
        y_train.append(0)

# %%
y_train.count(2)
# Out:
# 2524

# %%
scaler = preprocessing.MaxAbsScaler().fit(X)
X_scaled = scaler.transform(X)
X = X_scaled
X_train=X

# %%
train.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# # TEST

# %%
for i in range(50):
    if i==0:
        test = pd.read_pickle('salida/nuevo4e/SICK/TEST_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4e/SICK/TEST_'+str(i+1)+'.csv_.pickle')
            test=pd.concat([test,temp])
        except:
            print(i+1)

# %%
test = test.reset_index(drop=True)
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.096561    5.746273           0.748      0.669  3.698120  0.005845
# 4904  0.431280    8.434960           1.393      1.233  3.809083  0.006834
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.112530          1     1.000000            0       5       4       4
# 4904  0.142375          2     1.000000            0       8       6       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  negT verbT  negH verbH  overlap_ent         clases
# 0             0.375000     0           0           0.000000  CONTRADICTION
# 1             0.714286     0           0           0.666667  CONTRADICTION
# 2             0.428571     0           0           0.333333  CONTRADICTION
# 3             1.000000     0           0           1.000000     ENTAILMENT
# 4             0.857143     0           0           0.833333  CONTRADICTION
# ...                ...   ...   ...   ...   ...          ...            ...
# 4901          0.250000     0           0           0.250000  CONTRADICTION
# 4902          0.250000     0           0           0.000000  CONTRADICTION
# 4903          0.000000     0           0           0.000000  CONTRADICTION
# 4904          0.375000     0           0           0.000000  CONTRADICTION
# 4905          0.200000     0           0           0.000000  CONTRADICTION
#
# [4906 rows x 20 columns]

# %%
temp1 = pd.read_csv("../OPENAI/data/SICK/original/SICK_TEST.csv")
temp1
# Out:
#                                              sentence_A  \
# 0     There is no boy playing outdoors and there is ...
# 1     A group of boys in a yard is playing and a man...
# 2     A group of children is playing in the house an...
# 3     A brown dog is attacking another animal in fro...
# 4     A brown dog is attacking another animal in fro...
# ...                                                 ...
# 4901    The young girl is blowing a bubble that is huge
# 4902  A dog in a colored coat is running across the ...
# 4903                 A boy is happily playing the piano
# 4904  The girl, who is little, is combing her hair i...
# 4905  A man is in a parking lot and is playing tenni...
#
#                                              sentence_B entailment_label
# 0     A group of kids is playing in a yard and an ol...          NEUTRAL
# 1     The young boys are playing outdoors and the ma...          NEUTRAL
# 2     The young boys are playing outdoors and the ma...          NEUTRAL
# 3     A brown dog is attacking another animal in fro...       ENTAILMENT
# 4     A brown dog is helping another animal in front...          NEUTRAL
# ...                                                 ...              ...
# 4901         There is no girl in pink twirling a ribbon          NEUTRAL
# 4902               The flute is being played by one man          NEUTRAL
# 4903       A white bird is landing swiftly in the water          NEUTRAL
# 4904  Two people wearing helmets are driving over th...          NEUTRAL
# 4905  The snowboarder is leaping fearlessly over whi...          NEUTRAL
#
# [4906 rows x 3 columns]

# %%
test["clases"]=temp1["entailment_label"]
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.096561    5.746273           0.748      0.669  3.698120  0.005845
# 4904  0.431280    8.434960           1.393      1.233  3.809083  0.006834
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.112530          1     1.000000            0       5       4       4
# 4904  0.142375          2     1.000000            0       8       6       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  negT verbT  negH verbH  overlap_ent      clases
# 0             0.375000     0           0           0.000000     NEUTRAL
# 1             0.714286     0           0           0.666667     NEUTRAL
# 2             0.428571     0           0           0.333333     NEUTRAL
# 3             1.000000     0           0           1.000000  ENTAILMENT
# 4             0.857143     0           0           0.833333     NEUTRAL
# ...                ...   ...   ...   ...   ...          ...         ...
# 4901          0.250000     0           0           0.250000     NEUTRAL
# 4902          0.250000     0           0           0.000000     NEUTRAL
# 4903          0.000000     0           0           0.000000     NEUTRAL
# 4904          0.375000     0           0           0.000000     NEUTRAL
# 4905          0.200000     0           0           0.000000     NEUTRAL
#
# [4906 rows x 20 columns]

# %%
test=test.drop(["verbH","verbT"],axis=1)
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.096561    5.746273           0.748      0.669  3.698120  0.005845
# 4904  0.431280    8.434960           1.393      1.233  3.809083  0.006834
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.112530          1     1.000000            0       5       4       4
# 4904  0.142375          2     1.000000            0       8       6       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  negT  negH  overlap_ent      clases
# 0             0.375000     0     0     0.000000     NEUTRAL
# 1             0.714286     0     0     0.666667     NEUTRAL
# 2             0.428571     0     0     0.333333     NEUTRAL
# 3             1.000000     0     0     1.000000  ENTAILMENT
# 4             0.857143     0     0     0.833333     NEUTRAL
# ...                ...   ...   ...          ...         ...
# 4901          0.250000     0     0     0.250000     NEUTRAL
# 4902          0.250000     0     0     0.000000     NEUTRAL
# 4903          0.000000     0     0     0.000000     NEUTRAL
# 4904          0.375000     0     0     0.000000     NEUTRAL
# 4905          0.200000     0     0     0.000000     NEUTRAL
#
# [4906 rows x 18 columns]

# %%
#test=test.drop(["sumas","mutinf","list_comp","list_incomp","entidades","entropia_total","list_rel_con",'mearts', 'max_info', 'similitud_faltantes','list_rel_con', 'list_M', 'list_m', 'list_T', 'list_bigram','diferencias'],axis=1)
#test = test[['list_incomp','Jaro-Winkler_rit','overlap_ent','mutinf','list_m','clases']]
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.096561    5.746273           0.748      0.669  3.698120  0.005845
# 4904  0.431280    8.434960           1.393      1.233  3.809083  0.006834
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.112530          1     1.000000            0       5       4       4
# 4904  0.142375          2     1.000000            0       8       6       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  negT  negH  overlap_ent      clases
# 0             0.375000     0     0     0.000000     NEUTRAL
# 1             0.714286     0     0     0.666667     NEUTRAL
# 2             0.428571     0     0     0.333333     NEUTRAL
# 3             1.000000     0     0     1.000000  ENTAILMENT
# 4             0.857143     0     0     0.833333     NEUTRAL
# ...                ...   ...   ...          ...         ...
# 4901          0.250000     0     0     0.250000     NEUTRAL
# 4902          0.250000     0     0     0.000000     NEUTRAL
# 4903          0.000000     0     0     0.000000     NEUTRAL
# 4904          0.375000     0     0     0.000000     NEUTRAL
# 4905          0.200000     0     0     0.000000     NEUTRAL
#
# [4906 rows x 18 columns]

# %%
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.096561    5.746273           0.748      0.669  3.698120  0.005845
# 4904  0.431280    8.434960           1.393      1.233  3.809083  0.006834
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.112530          1     1.000000            0       5       4       4
# 4904  0.142375          2     1.000000            0       8       6       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  negT  negH  overlap_ent      clases
# 0             0.375000     0     0     0.000000     NEUTRAL
# 1             0.714286     0     0     0.666667     NEUTRAL
# 2             0.428571     0     0     0.333333     NEUTRAL
# 3             1.000000     0     0     1.000000  ENTAILMENT
# 4             0.857143     0     0     0.833333     NEUTRAL
# ...                ...   ...   ...          ...         ...
# 4901          0.250000     0     0     0.250000     NEUTRAL
# 4902          0.250000     0     0     0.000000     NEUTRAL
# 4903          0.000000     0     0     0.000000     NEUTRAL
# 4904          0.375000     0     0     0.000000     NEUTRAL
# 4905          0.200000     0     0     0.000000     NEUTRAL
#
# [4906 rows x 18 columns]

# %%
X_t = test.drop(['clases'],axis=1)
y_t = test['clases']

# %%
# SICK
y_test=[]
for i in y_t:
    if i == "ENTAILMENT":
        y_test.append(1)
    elif i == "NEUTRAL":
        y_test.append(2)
    else:
        y_test.append(0)

# %%
y_test.count(1)
# Out:
# 1404

# %%
y_test.count(0)
# Out:
# 712

# %%
scaler = preprocessing.MaxAbsScaler().fit(X_t)
X_scaled = scaler.transform(X_t)
X_test = X_scaled

# %% [markdown]
# # MODELO DE REGRESIÓN LÓGISTICA

# %%
# grid={"C":np.logspace(-3,3,7), "penalty":["l2"]}# l1 lasso l2 ridge
# logreg=linear_model.LogisticRegression()
# logreg_cv=GridSearchCV(logreg,grid,cv=20)
# logreg_cv.fit(X_train,y_train)

# %%
# print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
# print("accuracy :",logreg_cv.best_score_)

# %%
#X_train = np.where(np.isnan(X_train), 0, X_train)
#X_train

# %%
X_train.shape
# Out:
# (4439, 17)

# %%
model = LogisticRegression(penalty="l2", C=1,max_iter=500)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1, max_iter=500)

# %%
model.get_params()
# Out:
# {'C': 1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 500,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.decision_function(X)
# Out:
# array([[-1.18937364,  1.1075109 ,  0.08186274],
#        [-1.53589442, -0.31836621,  1.85426063],
#        [-0.31695908,  0.27227859,  0.04468049],
#        ...,
#        [-5.01321697, -0.07938594,  5.09260291],
#        [-2.27764083, -0.02450724,  2.30214806],
#        [-1.90544129, -1.39688339,  3.30232468]])

# %%
labels=train.columns[:-1]
labels
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'negT', 'negH',
#        'overlap_ent'],
#       dtype='object')

# %%
model.classes_
# Out:
# array([0, 1, 2])

# %%
model.coef_[0]
# Out:
# array([-0.47308177, -1.02130701,  0.00688719, -0.79445449,  0.25729505,
#        -0.26342081, -1.09464214, -4.53291772, -0.79684953, -0.47568313,
#         3.28369514, -1.01846599, -3.6092813 ,  1.85837296,  2.25944861,
#         2.1347168 , -1.97909766])

# %%
coeficientes=model.coef_[0]

# %%
coeficientes
# Out:
# array([-0.47308177, -1.02130701,  0.00688719, -0.79445449,  0.25729505,
#        -0.26342081, -1.09464214, -4.53291772, -0.79684953, -0.47568313,
#         3.28369514, -1.01846599, -3.6092813 ,  1.85837296,  2.25944861,
#         2.1347168 , -1.97909766])

# %%
print("Maximo,minimo ",np.argmax(coeficientes),labels[np.argmax(coeficientes)],np.argmin(coeficientes),labels[np.argmin(coeficientes)])
# Out:
# Maximo,minimo  10 list_M 7 list_comp

# %%
n_columns=train.shape[1]-1

# %%
n_columns
# Out:
# 17

# %%
import matplotlib.pyplot as plt
import numpy as np

x_v = np.arange(0,n_columns,1)
y_v = coeficientes

plt.bar(x_v,y_v)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Coeficientes')
plt.show()

# %%
#X_test = np.where(np.isnan(X_test), 0, X_test)
#X_test

# %%
X_test.shape
# Out:
# (4906, 17)

# %%
predictions = model.predict(X_test)

# %%
test["predictions"]=predictions
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.096561    5.746273           0.748      0.669  3.698120  0.005845
# 4904  0.431280    8.434960           1.393      1.233  3.809083  0.006834
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.112530          1     1.000000            0       5       4       4
# 4904  0.142375          2     1.000000            0       8       6       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  negT  negH  overlap_ent      clases  predictions
# 0             0.375000     0     0     0.000000     NEUTRAL            2
# 1             0.714286     0     0     0.666667     NEUTRAL            2
# 2             0.428571     0     0     0.333333     NEUTRAL            2
# 3             1.000000     0     0     1.000000  ENTAILMENT            1
# 4             0.857143     0     0     0.833333     NEUTRAL            2
# ...                ...   ...   ...          ...         ...          ...
# 4901          0.250000     0     0     0.250000     NEUTRAL            2
# 4902          0.250000     0     0     0.000000     NEUTRAL            2
# 4903          0.000000     0     0     0.000000     NEUTRAL            2
# 4904          0.375000     0     0     0.000000     NEUTRAL            2
# 4905          0.200000     0     0     0.000000     NEUTRAL            2
#
# [4906 rows x 19 columns]

# %%
test[(test["clases"]=="ENTAILMENT") & (test["predictions"]==0)]
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 74    0.000000    0.000000           2.035      0.000  0.000000  0.000000
# 509   0.000000    0.000000           1.821      0.000  0.000000  0.000000
# 653   0.000000    0.000000           1.939      0.000  0.000000  0.000000
# 815   0.000000    0.000000           1.906      0.000  0.000000  0.000000
# 1006  0.000000    0.000000           1.555      0.000  0.000000  0.000000
# 1078  0.000000    0.000000           2.007      0.000  0.000000  0.000000
# 1079  0.000000    0.000000           2.007      0.000  0.000000  0.000000
# 1567  0.000000    0.000000           1.502      0.000  0.000000  0.000000
# 1653  0.000000    0.000000           1.750      0.000  0.000000  0.000000
# 1678  0.000000    0.000000           1.000      0.000  0.000000  0.000000
# 1679  0.000000    0.000000           1.000      0.000  0.000000  0.000000
# 1695  0.000000    0.000000           1.000      0.000  0.000000  0.000000
# 1790  0.000000    0.000000           1.730      0.000  0.000000  0.000000
# 2034  0.317978    2.854359           1.959      1.792  3.744285  0.005664
# 2418  0.000000    0.000000           1.500      0.000  0.000000  0.000000
# 2554  0.000000    0.000000           1.975      0.000  0.000000  0.000000
# 3476  0.377073    2.832556           1.729      0.922  3.831174  0.004435
# 3762  0.000000    0.000000           2.248      0.000  0.000000  0.000000
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 74    0.000000          0     0.000000            0       7       0       7
# 509   0.000000          0     0.000000            0      11       0      11
# 653   0.000000          0     0.000000            0       5       0       5
# 815   0.000000          0     0.000000            0       4       0       4
# 1006  0.000000          0     0.000000            0       3       0       4
# 1078  0.000000          0     0.000000            0       7       0       7
# 1079  0.000000          0     0.000000            0       7       0       7
# 1567  0.000000          1     0.000000            0       4       0       4
# 1653  0.000000          0     0.000000            0       4       0       4
# 1678  0.000000          0     0.000000            0       2       0       2
# 1679  0.000000          0     0.000000            0       1       0       2
# 1695  0.000000          0     0.000000            0       2       0       2
# 1790  0.000000          0     0.000000            0       3       0       4
# 2034  0.226786          0     0.666667            0       4       2       3
# 2418  0.000000          1     0.000000            0       2       0       2
# 2554  0.000000          0     0.000000            0       3       0       3
# 3476  0.273521          0     0.400000            1       5       2       5
# 3762  0.000000          0     0.000000            0       8       0       8
#
#       Jaro-Winkler_rit  negT  negH  overlap_ent      clases  predictions
# 74            0.714286     0     0     0.500000  ENTAILMENT            0
# 509           1.000000     0     0     0.666667  ENTAILMENT            0
# 653           0.800000     0     0     0.500000  ENTAILMENT            0
# 815           1.000000     0     0     0.666667  ENTAILMENT            0
# 1006          1.000000     0     0     0.333333  ENTAILMENT            0
# 1078          1.000000     0     0     0.666667  ENTAILMENT            0
# 1079          0.714286     0     0     0.500000  ENTAILMENT            0
# 1567          1.000000     0     0     0.333333  ENTAILMENT            0
# 1653          1.000000     0     0     0.600000  ENTAILMENT            0
# 1678          1.000000     0     0     0.666667  ENTAILMENT            0
# 1679          1.000000     0     0     0.500000  ENTAILMENT            0
# 1695          1.000000     0     0     0.666667  ENTAILMENT            0
# 1790          1.000000     0     0     0.333333  ENTAILMENT            0
# 2034          0.500000     0     1     0.500000  ENTAILMENT            0
# 2418          1.000000     0     0     0.000000  ENTAILMENT            0
# 2554          1.000000     0     0     0.666667  ENTAILMENT            0
# 3476          0.800000     0     1     0.600000  ENTAILMENT            0
# 3762          1.000000     0     0     0.666667  ENTAILMENT            0

# %%
#test.to_csv("predictions_SICK_DEV.csv")

# %%
print(confusion_matrix(y_test, predictions,labels=[1,2,0]))
# Out:
# [[1026  360   18]
#  [ 310 2441   39]
#  [ 172  161  379]]

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions,average="weighted"),2))
print("recall",round(recall_score(y_test,predictions,average="weighted"),2))
print("f1_score: ",round(f1_score(y_test,predictions,average="weighted"),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.78
# precision:  0.79
# recall 0.78
# f1_score:  0.78
# matthews_score:  0.61

# %%
X_train.shape
# Out:
# (4439, 17)

# %%
X_test.shape
# Out:
# (4906, 17)

# %%
X_cv=np.concatenate((X_train, X_test), axis=0)
Y_cv=np.concatenate((y_train, y_test), axis=0)

# %%
#validation_size = 0.20
#X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)
X_train_cv=X_cv
Y_train_cv=Y_cv

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name + " Acurracy:" , round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_weighted')
msg += "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_weighted')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_weighted')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Acurracy:: 0.770000 (0.031536)
# Logistic Regression Precision:: 0.780000 (0.033673)
# Logistic Regression Recall:: 0.770000 (0.031536)
# Logistic Regression F1-score:: 0.770000 (0.031717)

# %%
# Logistic Regression Acurracy:: 0.770000 (0.032756)
# Logistic Regression Precision:: 0.780000 (0.034664)
# Logistic Regression Recall:: 0.770000 (0.032756)
# Logistic Regression F1-score:: 0.770000 (0.032888)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_macro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_macro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_macro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.770000 (0.042249)
# Logistic Regression Recall:: 0.700000 (0.051050)
# Logistic Regression F1-score:: 0.720000 (0.047160)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_micro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_micro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_micro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.770000 (0.032756)
# Logistic Regression Recall:: 0.770000 (0.032756)
# Logistic Regression F1-score:: 0.770000 (0.032756)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='matthews_corrcoef')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.590000 (0.075726)

# %%
import shap
import pandas as pd
import numpy as np
shap.initjs()
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
#linear_model

# %%
# model = LogisticRegression()
# model.fit(X_train,y_train)

# %%
y_predict = model.predict(X_test)
print(classification_report( y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.53      0.66       712
#            1       0.68      0.73      0.70      1404
#            2       0.82      0.87      0.85      2790
#
#     accuracy                           0.78      4906
#    macro avg       0.79      0.71      0.74      4906
# weighted avg       0.79      0.78      0.78      4906

# %%
explainer = shap.Explainer(model,X_train,feature_names=test.columns[:-2])
shap_values = explainer(X_test)

# %%
test.columns
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'negT', 'negH',
#        'overlap_ent', 'clases', 'predictions'],
#       dtype='object')

# %%
test.columns[:-2]
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'negT', 'negH',
#        'overlap_ent'],
#       dtype='object')

# %%
explainer.expected_value
# Out:
# array([-1.05296489, -0.01670971,  1.0696746 ])

# %%
X_test
# Out:
# array([[0.13135032, 0.24632658, 0.68290291, ..., 0.        , 0.        ,
#         0.        ],
#        [0.15260756, 0.24806094, 0.65969271, ..., 0.        , 0.        ,
#         0.66666667],
#        [0.15563953, 0.24685911, 0.63779013, ..., 0.        , 0.        ,
#         0.33333333],
#        ...,
#        [0.04250252, 0.3761828 , 0.24452435, ..., 0.        , 0.        ,
#         0.        ],
#        [0.20882912, 0.36514151, 0.45537757, ..., 0.        , 0.        ,
#         0.        ],
#        [0.09468945, 0.50557974, 0.52598889, ..., 0.        , 0.        ,
#         0.        ]])

# %%
shap.plots.beeswarm(shap_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 shap.plots.beeswarm(shap_values)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_beeswarm.py:85, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, show, log_scale, color_bar, plot_size, color_bar_label)
#      80 elif len(sv_shape) > 2:
#      81     emsg = (
#      82         "The beeswarm plot does not support plotting explanations with instances that have more "
#      83         "than one dimension!"
#      84     )
# ---> 85     raise ValueError(emsg)
#      87 shap_exp = shap_values
#      88 # we make a copy here, because later there are places that might modify this array
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
ind = 21
print(X_test[ind],y_test[ind],y_predict[ind])
shap.plots.force(shap_values[ind])
shap.plots.waterfall(shap_values[ind])
# Out:
# [0.4751967  0.24555819 0.87544949 0.78537126 0.93112685 0.10731264
#  0.47481402 0.25       0.0952381  0.         0.375      0.25
#  0.4        0.83333333 0.         0.         0.25      ] 2 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 3
#       1 ind = 21
#       2 print(X_test[ind],y_test[ind],y_predict[ind])
# ----> 3 shap.plots.force(shap_values[ind])
#       4 shap.plots.waterfall(shap_values[ind])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:129, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     122     if not isinstance(shap_values, list) or len(shap_values) != len(base_value):
#     123         emsg = (
#     124             "In v0.20, force plot now requires the base value as the first parameter! "
#     125             "Try shap.plots.force(explainer.expected_value, shap_values) or "
#     126             "for multi-output models try "
#     127             "shap.plots.force(explainer.expected_value[0], shap_values[0])."
#     128         )
# --> 129         raise TypeError(emsg)
#     131 if isinstance(shap_values, list):
#     132     emsg = "The shap_values arg looks multi output, try `shap_values[i]` instead."
#
# TypeError: In v0.20, force plot now requires the base value as the first parameter! Try shap.plots.force(explainer.expected_value, shap_values) or for multi-output models try shap.plots.force(explainer.expected_value[0], shap_values[0]).

# %%
ind = 6
print(X_test[ind])
# This amazing documentary gives us a glimpse into the lives of the brave
# women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
# tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
# languages and multiple legal precedents depending on the region of the country and
# the religious/ethnic background of the plaintiffs and defendants-- these brave,
# strong women are making a difference. [...]

shap.plots.waterfall(shap_values[ind,:,1])
# Out:
# [0.         0.         0.         0.         0.         0.
#  0.25925926 0.         0.31428571 0.33333333 0.         0.66666667]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[122], line 10
#       2 print(X_test[ind])
#       3 # This amazing documentary gives us a glimpse into the lives of the brave
#       4 # women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
#       5 # tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
#       6 # languages and multiple legal precedents depending on the region of the country and
#       7 # the religious/ethnic background of the plaintiffs and defendants-- these brave,
#       8 # strong women are making a difference. [...]
# ---> 10 shap.plots.waterfall(shap_values[ind,:,1])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/_explanation.py:422, in Explanation.__getitem__(self, item)
#     420 if new_self is None:
#     421     new_self = copy.copy(self)
# --> 422 new_self._s = new_self._s.__getitem__(item)
#     423 new_self.op_history.append({
#     424     "name": "__getitem__",
#     425     "args": (item,),
#     426     "prev_shape": self.shape
#     427 })
#     429 return new_self
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer.py:112, in Slicer.__getitem__(self, item)
#     110 index_slicer = AtomicSlicer(index_tup, max_dim=1)
#     111 slicer_index = index_slicer[tracked.dim]
# --> 112 sliced_o = tracked[slicer_index]
#     113 sliced_dim = resolve_dim(index_tup, tracked.dim)
#     115 new_tracked = tracked.__class__(sliced_o, sliced_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:582, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     579 head_slice = cls.type_map[o_type].head_slice
#     580 tail_slice = cls.type_map[o_type].tail_slice
# --> 582 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
#     583 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     584 return out
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:418, in ArrayHandler.head_slice(cls, o, index_tup, max_dim)
#     416 cut_index = index_tup[:cut]
#     417 is_element = any([True if isinstance(x, int) else False for x in cut_index])
# --> 418 sliced_o = o[cut_index]
#     420 return is_element, sliced_o, cut
#
# IndexError: index 1 is out of bounds for axis 2 with size 1

# %%
shap.summary_plot(shap_values[:,:,1], X_test,plot_type="bar")

# %%
shap.summary_plot(shap_values[:,:,2], X_test,plot_type="bar")

# %%
X_test
# Out:
# array([[0.13135032, 0.24632658, 0.68290291, ..., 0.        , 0.        ,
#         0.        ],
#        [0.15260756, 0.24806094, 0.65969271, ..., 0.        , 0.        ,
#         0.66666667],
#        [0.15563953, 0.24685911, 0.63779013, ..., 0.        , 0.        ,
#         0.33333333],
#        ...,
#        [0.04250252, 0.3761828 , 0.24452435, ..., 0.        , 0.        ,
#         0.        ],
#        [0.20882912, 0.36514151, 0.45537757, ..., 0.        , 0.        ,
#         0.        ],
#        [0.09468945, 0.50557974, 0.52598889, ..., 0.        , 0.        ,
#         0.        ]])

# %%
shap.summary_plot(shap_values[:,:,0], X_test,plot_type="bar")

# %%
shap.summary_plot(shap_values[1:,], X_test[1:,])

# %%
shap.summary_plot(shap_values, X_test,feature_names=test.columns[:-1])

# %%
shap_values[2:,]
# Out:
# .values =
# array([[ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [-0.01299836, -0.11268555, -0.4045574 ,  0.04382668,  0.21114683],
#        ...,
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683]])
#
# .base_values =
# array([-0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388])
#
# .data =
# array([[-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [ 1.23549291,  0.39218921,  0.29047164,  0.24312215, -0.67101221],
#        ...,
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221]])

# %%
shap.summary_plot(shap_values[0:,], X_test,feature_names=test.columns[:-1])

# %%
explainer.expected_value
# Out:
# -0.7454438806409415

# %%
shap_values.shape
# Out:
# (800, 5)

# %% [markdown]
# # Árbol de decisión

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
clf = DecisionTreeClassifier(splitter="random")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print("acccuracy: ",round(accuracy_score(y_test,y_pred),2))
print("precision: ",round(precision_score(y_test,y_pred),2))
print("recall",round(recall_score(y_test,y_pred),2))
print("f1_score: ",round(f1_score(y_test,y_pred),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,y_pred),2))
# Out:
# acccuracy:  0.67
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 2
#       1 print("acccuracy: ",round(accuracy_score(y_test,y_pred),2))
# ----> 2 print("precision: ",round(precision_score(y_test,y_pred),2))
#       3 print("recall",round(recall_score(y_test,y_pred),2))
#       4 print("f1_score: ",round(f1_score(y_test,y_pred),2))
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2131, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1973 @validate_params(
#    1974     {
#    1975         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2000     zero_division="warn",
#    2001 ):
#    2002     """Compute the precision.
#    2003
#    2004     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2129     array([0.5, 1. , 1. ])
#    2130     """
# -> 2131     p, _, _, _ = precision_recall_fscore_support(
#    2132         y_true,
#    2133         y_pred,
#    2134         labels=labels,
#    2135         pos_label=pos_label,
#    2136         average=average,
#    2137         warn_for=("precision",),
#    2138         sample_weight=sample_weight,
#    2139         zero_division=zero_division,
#    2140     )
#    2141     return p
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1518, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1516         if y_type == "multiclass":
#    1517             average_options.remove("samples")
# -> 1518         raise ValueError(
#    1519             "Target is %s but average='binary'. Please "
#    1520             "choose another average setting, one of %r." % (y_type, average_options)
#    1521         )
#    1522 elif pos_label not in (None, 1):
#    1523     warnings.warn(
#    1524         "Note that pos_label (set to %r) is ignored when "
#    1525         "average != 'binary' (got %r). You may use "
#    (...)
#    1528         UserWarning,
#    1529     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
validation_size = 0.01
X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)

# %%
name='DecisionTree'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_weighted')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_weighted')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_weighted')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# DecisionTree: 0.680000 (0.014004)
# DecisionTree: 0.680000 (0.010178)
# DecisionTree: 0.680000 (0.013535)
# DecisionTree: 0.680000 (0.011671)

# %%
name='DecisionTree'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_macro')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_macro')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_macro')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# DecisionTree: 0.680000 (0.015553)
# DecisionTree: 0.580000 (0.018540)
# DecisionTree: 0.580000 (0.016293)
# DecisionTree: 0.580000 (0.019133)

# %%
c=train.columns[:-1]
confusion_matrix(y_test,y_pred,labels=[1,2,0])
# Out:
# array([[ 860,  303,  241],
#        [ 455, 2150,  185],
#        [ 288,  158,  266]])

# %%
# Estructura del árbol creado
import matplotlib.pyplot as plt
# ------------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(20, 10))

print(f"Profundidad del árbol: {clf.get_depth()}")
print(f"Número de nodos terminales: {clf.get_n_leaves()}")

plot = plot_tree(
            decision_tree = clf,
            feature_names = c,
            class_names   = True,
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 23
# Número de nodos terminales: 152
