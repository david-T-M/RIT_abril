# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV

# %%
for i in range(45):
    if i==0:
        train = pd.read_pickle('salida/nuevo4i/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4i/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
            train=pd.concat([train,temp])
        except:
            pass

# %%
train=train.reset_index(drop=True)
train
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       0.000000        2.096701   0.000000  0.000000  0.000000  0.000000
# 1       0.000000        1.912939   0.000000  0.000000  0.000000  0.000000
# 2       0.000000        2.176234   0.000000  0.000000  0.000000  0.000000
# 3       1.346348        1.909126   0.881291  3.841058  0.006909  0.093184
# 4       1.330037        2.183393   0.985228  3.850918  0.005862  0.115356
# ...          ...             ...        ...       ...       ...       ...
# 4434    1.352706        1.052941   0.811278  3.786475  0.006455  0.084316
# 4435    1.373320        1.384432   1.384432  3.779084  0.008525  0.056842
# 4436    1.263298        1.687640   1.370951  3.787387  0.006522  0.202038
# 4437    1.298727        1.410848   1.459148  3.685267  0.004270  0.156616
# 4438    1.380951        1.298795   1.061278  3.788780  0.005101  0.046050
#
#          sumas  semantics  nlp_semantics  mutinf_t  ...  list_m  list_T  \
# 0     0.000000   1.000000       1.000000  4.584342  ...       0       8
# 1     0.000000   1.000000       0.500000  4.385955  ...       0       7
# 2     0.000000   1.000000       1.000000  4.551917  ...       0       7
# 3     0.059185   0.346177       0.346177  4.168479  ...       2       5
# 4     0.057777   0.444897       0.555103  4.060155  ...       2       7
# ...        ...        ...            ...       ...  ...     ...     ...
# 4434  0.020937   0.268774       0.268774  3.924434  ...       4       3
# 4435  0.024570   0.180872       0.180872  3.779084  ...       4       3
# 4436  0.054981   0.221145       0.221145  3.742518  ...       2       5
# 4437  0.059745   0.418658       0.418658  4.094972  ...       1       6
# 4438  0.008490   0.337102       0.337102  3.797957  ...       2       4
#
#       Jaro-Winkler_rit  KL_divergence  negT  verbT  negH  verbH  overlap_ent  \
# 0             0.857143       0.000000     0            0            0.800000
# 1             0.750000       0.000000     0            0            0.333333
# 2             1.000000       0.000000     0            0            0.400000
# 3             0.375000       0.530505     0            0            0.333333
# 4             0.375000       0.459976     0            0            0.166667
# ...                ...            ...   ...    ...   ...    ...          ...
# 4434          0.000000       0.083317     0            0            0.200000
# 4435          0.250000       0.000000     0            1   play     0.000000
# 4436          0.166667       0.210428     0            0            0.000000
# 4437          0.000000       0.207085     0            0            0.333333
# 4438          0.000000       0.072276     0            0            0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2        ENTAILMENT
# 3     CONTRADICTION
# 4     CONTRADICTION
# ...             ...
# 4434  CONTRADICTION
# 4435  CONTRADICTION
# 4436  CONTRADICTION
# 4437  CONTRADICTION
# 4438  CONTRADICTION
#
# [4439 rows x 33 columns]

# %%
train.boxplot(by="clases",column=["entropias","entropia_total"])
# Out:
# array([<Axes: title={'center': 'entropias'}, xlabel='clases'>,
#        <Axes: title={'center': 'entropia_total'}, xlabel='clases'>],
#       dtype=object)

# %% [markdown]
# ## Eliminar características

# %%
# Diferencia entre entropia total - entropias y dejar la columna
# Quitar max_info_p
# revisar scaler y/o normalización de shape con total
#
train=train.drop(["verbH","verbT"],axis=1)
#train=train.drop(["Match"],axis=1)
train
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       0.000000        2.096701   0.000000  0.000000  0.000000  0.000000
# 1       0.000000        1.912939   0.000000  0.000000  0.000000  0.000000
# 2       0.000000        2.176234   0.000000  0.000000  0.000000  0.000000
# 3       1.346348        1.909126   0.881291  3.841058  0.006909  0.093184
# 4       1.330037        2.183393   0.985228  3.850918  0.005862  0.115356
# ...          ...             ...        ...       ...       ...       ...
# 4434    1.352706        1.052941   0.811278  3.786475  0.006455  0.084316
# 4435    1.373320        1.384432   1.384432  3.779084  0.008525  0.056842
# 4436    1.263298        1.687640   1.370951  3.787387  0.006522  0.202038
# 4437    1.298727        1.410848   1.459148  3.685267  0.004270  0.156616
# 4438    1.380951        1.298795   1.061278  3.788780  0.005101  0.046050
#
#          sumas  semantics  nlp_semantics  mutinf_t  ...  entropia_relaciones  \
# 0     0.000000   1.000000       1.000000  4.584342  ...             0.000000
# 1     0.000000   1.000000       0.500000  4.385955  ...             0.543564
# 2     0.000000   1.000000       1.000000  4.551917  ...             0.000000
# 3     0.059185   0.346177       0.346177  4.168479  ...             1.500000
# 4     0.057777   0.444897       0.555103  4.060155  ...             1.836592
# ...        ...        ...            ...       ...  ...                  ...
# 4434  0.020937   0.268774       0.268774  3.924434  ...             0.918296
# 4435  0.024570   0.180872       0.180872  3.779084  ...             0.000000
# 4436  0.054981   0.221145       0.221145  3.742518  ...             0.918296
# 4437  0.059745   0.418658       0.418658  4.094972  ...             0.918296
# 4438  0.008490   0.337102       0.337102  3.797957  ...             1.500000
#
#       list_M  list_m  list_T  Jaro-Winkler_rit  KL_divergence  negT  negH  \
# 0          7       0       8          0.857143       0.000000     0     0
# 1          8       0       7          0.750000       0.000000     0     0
# 2          5       0       7          1.000000       0.000000     0     0
# 3          8       2       5          0.375000       0.530505     0     0
# 4          8       2       7          0.375000       0.459976     0     0
# ...      ...     ...     ...               ...            ...   ...   ...
# 4434       6       4       3          0.000000       0.083317     0     0
# 4435       4       4       3          0.250000       0.000000     0     1
# 4436       6       2       5          0.166667       0.210428     0     0
# 4437       3       1       6          0.000000       0.207085     0     0
# 4438       4       2       4          0.000000       0.072276     0     0
#
#       overlap_ent         clases
# 0        0.800000  CONTRADICTION
# 1        0.333333  CONTRADICTION
# 2        0.400000     ENTAILMENT
# 3        0.333333  CONTRADICTION
# 4        0.166667  CONTRADICTION
# ...           ...            ...
# 4434     0.200000  CONTRADICTION
# 4435     0.000000  CONTRADICTION
# 4436     0.000000  CONTRADICTION
# 4437     0.333333  CONTRADICTION
# 4438     0.000000  CONTRADICTION
#
# [4439 rows x 31 columns]

# %%
train.columns
# Out:
# Index(['distancias', 'entropia_total', 'entropias', 'mutinf', 'mearts',
#        'max_info', 'sumas', 'semantics', 'nlp_semantics', 'mutinf_t',
#        'mearts_t', 'max_info_t', 'sumas_t', 'entail', 'contra', 'neutral',
#        'no_match', 'rel_conceptuales', 'list_comp', 'diferencias',
#        'list_incomp', 'entropia_relaciones', 'list_M', 'list_m', 'list_T',
#        'Jaro-Winkler_rit', 'KL_divergence', 'negT', 'negH', 'overlap_ent',
#        'clases'],
#       dtype='object')

# %%
#train["mutinfx"]=train["mutinf"]/train["mutinf_t"]
train["mutinf"]=train["mutinf_t"]-train["mutinf"]
#train["max_infox"]=train["max_info"]/train["max_info_t"]
train["max_info"]=train["max_info_t"]-train["max_info"]
#train["mearts"]=train["mearts"]/train["mearts_t"]
#train["entropiasx"]=train["entropias"]/train["entropia_total"]
train["entropias"]=train["entropia_total"]-train["entropias"]
#train["sumasx"]=train["sumas"]/train["sumas_t"]
train["sumas"]=train["sumas_t"]-train["sumas"]
train["list_m"]=train["list_m"]/train["list_M"]
#train["list_mxx"]=train["list_M"]-train["list_m"]

# %%
train = train[['mutinf','max_info','list_comp', 'list_incomp', 'rel_conceptuales','negH','negT','diferencias','entropia_relaciones','nlp_semantics','overlap_ent','Jaro-Winkler_rit','clases']]

# %%
X = train.drop(['clases'],axis=1)
y_ = train['clases']

# %%
# Guardar un nuevo dataframe para la correlación de variables
train_m=train.drop(['clases'],axis=1).corr(method='pearson')

# %%
train_m
# Out:
#                        mutinf  max_info  list_comp  list_incomp  \
# mutinf               1.000000  0.874226  -0.261995    -0.041167
# max_info             0.874226  1.000000  -0.467505    -0.060792
# list_comp           -0.261995 -0.467505   1.000000    -0.058950
# list_incomp         -0.041167 -0.060792  -0.058950     1.000000
# rel_conceptuales    -0.196875 -0.315953   0.125284     0.352042
# negH                -0.206135 -0.073033  -0.049894    -0.029095
# negT                 0.061004  0.070387  -0.051987    -0.039938
# diferencias         -0.744176 -0.723932   0.130571     0.022452
# entropia_relaciones -0.757157 -0.735426   0.163656     0.436766
# nlp_semantics        0.709941  0.623802  -0.131913    -0.250476
# overlap_ent          0.596207  0.782574  -0.545804    -0.108835
# Jaro-Winkler_rit     0.611438  0.744702  -0.346026    -0.131131
#
#                      rel_conceptuales      negH      negT  diferencias  \
# mutinf                      -0.196875 -0.206135  0.061004    -0.744176
# max_info                    -0.315953 -0.073033  0.070387    -0.723932
# list_comp                    0.125284 -0.049894 -0.051987     0.130571
# list_incomp                  0.352042 -0.029095 -0.039938     0.022452
# rel_conceptuales             1.000000 -0.024796 -0.036775     0.089112
# negH                        -0.024796  1.000000 -0.047197     0.141121
# negT                        -0.036775 -0.047197  1.000000    -0.052912
# diferencias                  0.089112  0.141121 -0.052912     1.000000
# entropia_relaciones          0.657936  0.109432 -0.072941     0.538004
# nlp_semantics               -0.428616 -0.193858  0.084394    -0.500321
# overlap_ent                 -0.378039  0.003750  0.106775    -0.523238
# Jaro-Winkler_rit            -0.371746 -0.047157  0.036672    -0.574671
#
#                      entropia_relaciones  nlp_semantics  overlap_ent  \
# mutinf                         -0.757157       0.709941     0.596207
# max_info                       -0.735426       0.623802     0.782574
# list_comp                       0.163656      -0.131913    -0.545804
# list_incomp                     0.436766      -0.250476    -0.108835
# rel_conceptuales                0.657936      -0.428616    -0.378039
# negH                            0.109432      -0.193858     0.003750
# negT                           -0.072941       0.084394     0.106775
# diferencias                     0.538004      -0.500321    -0.523238
# entropia_relaciones             1.000000      -0.807105    -0.591437
# nlp_semantics                  -0.807105       1.000000     0.475023
# overlap_ent                    -0.591437       0.475023     1.000000
# Jaro-Winkler_rit               -0.626189       0.521917     0.669689
#
#                      Jaro-Winkler_rit
# mutinf                       0.611438
# max_info                     0.744702
# list_comp                   -0.346026
# list_incomp                 -0.131131
# rel_conceptuales            -0.371746
# negH                        -0.047157
# negT                         0.036672
# diferencias                 -0.574671
# entropia_relaciones         -0.626189
# nlp_semantics                0.521917
# overlap_ent                  0.669689
# Jaro-Winkler_rit             1.000000

# %%
sns.heatmap(train_m,vmin=-1,vmax=1)
# Out:
# <Axes: >

# %%
train_m.columns
# Out:
# Index(['mutinf', 'max_info', 'list_comp', 'list_incomp', 'rel_conceptuales',
#        'negH', 'negT', 'diferencias', 'entropia_relaciones', 'nlp_semantics',
#        'overlap_ent', 'Jaro-Winkler_rit'],
#       dtype='object')

# %%
train_m
# Out:
#                        mutinf  max_info  list_comp  list_incomp  \
# mutinf               1.000000  0.874226  -0.261995    -0.041167
# max_info             0.874226  1.000000  -0.467505    -0.060792
# list_comp           -0.261995 -0.467505   1.000000    -0.058950
# list_incomp         -0.041167 -0.060792  -0.058950     1.000000
# rel_conceptuales    -0.196875 -0.315953   0.125284     0.352042
# negH                -0.206135 -0.073033  -0.049894    -0.029095
# negT                 0.061004  0.070387  -0.051987    -0.039938
# diferencias         -0.744176 -0.723932   0.130571     0.022452
# entropia_relaciones -0.757157 -0.735426   0.163656     0.436766
# nlp_semantics        0.709941  0.623802  -0.131913    -0.250476
# overlap_ent          0.596207  0.782574  -0.545804    -0.108835
# Jaro-Winkler_rit     0.611438  0.744702  -0.346026    -0.131131
#
#                      rel_conceptuales      negH      negT  diferencias  \
# mutinf                      -0.196875 -0.206135  0.061004    -0.744176
# max_info                    -0.315953 -0.073033  0.070387    -0.723932
# list_comp                    0.125284 -0.049894 -0.051987     0.130571
# list_incomp                  0.352042 -0.029095 -0.039938     0.022452
# rel_conceptuales             1.000000 -0.024796 -0.036775     0.089112
# negH                        -0.024796  1.000000 -0.047197     0.141121
# negT                        -0.036775 -0.047197  1.000000    -0.052912
# diferencias                  0.089112  0.141121 -0.052912     1.000000
# entropia_relaciones          0.657936  0.109432 -0.072941     0.538004
# nlp_semantics               -0.428616 -0.193858  0.084394    -0.500321
# overlap_ent                 -0.378039  0.003750  0.106775    -0.523238
# Jaro-Winkler_rit            -0.371746 -0.047157  0.036672    -0.574671
#
#                      entropia_relaciones  nlp_semantics  overlap_ent  \
# mutinf                         -0.757157       0.709941     0.596207
# max_info                       -0.735426       0.623802     0.782574
# list_comp                       0.163656      -0.131913    -0.545804
# list_incomp                     0.436766      -0.250476    -0.108835
# rel_conceptuales                0.657936      -0.428616    -0.378039
# negH                            0.109432      -0.193858     0.003750
# negT                           -0.072941       0.084394     0.106775
# diferencias                     0.538004      -0.500321    -0.523238
# entropia_relaciones             1.000000      -0.807105    -0.591437
# nlp_semantics                  -0.807105       1.000000     0.475023
# overlap_ent                    -0.591437       0.475023     1.000000
# Jaro-Winkler_rit               -0.626189       0.521917     0.669689
#
#                      Jaro-Winkler_rit
# mutinf                       0.611438
# max_info                     0.744702
# list_comp                   -0.346026
# list_incomp                 -0.131131
# rel_conceptuales            -0.371746
# negH                        -0.047157
# negT                         0.036672
# diferencias                 -0.574671
# entropia_relaciones         -0.626189
# nlp_semantics                0.521917
# overlap_ent                  0.669689
# Jaro-Winkler_rit             1.000000

# %%
coor=pd.DataFrame(np.tril(train_m,-1),index=train_m.columns,columns=train_m.columns)
coor
# Out:
#                        mutinf  max_info  list_comp  list_incomp  \
# mutinf               0.000000  0.000000   0.000000     0.000000
# max_info             0.874226  0.000000   0.000000     0.000000
# list_comp           -0.261995 -0.467505   0.000000     0.000000
# list_incomp         -0.041167 -0.060792  -0.058950     0.000000
# rel_conceptuales    -0.196875 -0.315953   0.125284     0.352042
# negH                -0.206135 -0.073033  -0.049894    -0.029095
# negT                 0.061004  0.070387  -0.051987    -0.039938
# diferencias         -0.744176 -0.723932   0.130571     0.022452
# entropia_relaciones -0.757157 -0.735426   0.163656     0.436766
# nlp_semantics        0.709941  0.623802  -0.131913    -0.250476
# overlap_ent          0.596207  0.782574  -0.545804    -0.108835
# Jaro-Winkler_rit     0.611438  0.744702  -0.346026    -0.131131
#
#                      rel_conceptuales      negH      negT  diferencias  \
# mutinf                       0.000000  0.000000  0.000000     0.000000
# max_info                     0.000000  0.000000  0.000000     0.000000
# list_comp                    0.000000  0.000000  0.000000     0.000000
# list_incomp                  0.000000  0.000000  0.000000     0.000000
# rel_conceptuales             0.000000  0.000000  0.000000     0.000000
# negH                        -0.024796  0.000000  0.000000     0.000000
# negT                        -0.036775 -0.047197  0.000000     0.000000
# diferencias                  0.089112  0.141121 -0.052912     0.000000
# entropia_relaciones          0.657936  0.109432 -0.072941     0.538004
# nlp_semantics               -0.428616 -0.193858  0.084394    -0.500321
# overlap_ent                 -0.378039  0.003750  0.106775    -0.523238
# Jaro-Winkler_rit            -0.371746 -0.047157  0.036672    -0.574671
#
#                      entropia_relaciones  nlp_semantics  overlap_ent  \
# mutinf                          0.000000       0.000000     0.000000
# max_info                        0.000000       0.000000     0.000000
# list_comp                       0.000000       0.000000     0.000000
# list_incomp                     0.000000       0.000000     0.000000
# rel_conceptuales                0.000000       0.000000     0.000000
# negH                            0.000000       0.000000     0.000000
# negT                            0.000000       0.000000     0.000000
# diferencias                     0.000000       0.000000     0.000000
# entropia_relaciones             0.000000       0.000000     0.000000
# nlp_semantics                  -0.807105       0.000000     0.000000
# overlap_ent                    -0.591437       0.475023     0.000000
# Jaro-Winkler_rit               -0.626189       0.521917     0.669689
#
#                      Jaro-Winkler_rit
# mutinf                            0.0
# max_info                          0.0
# list_comp                         0.0
# list_incomp                       0.0
# rel_conceptuales                  0.0
# negH                              0.0
# negT                              0.0
# diferencias                       0.0
# entropia_relaciones               0.0
# nlp_semantics                     0.0
# overlap_ent                       0.0
# Jaro-Winkler_rit                  0.0

# %%
coor.idxmax()
# Out:
# mutinf                            max_info
# max_info                       overlap_ent
# list_comp              entropia_relaciones
# list_incomp            entropia_relaciones
# rel_conceptuales       entropia_relaciones
# negH                           diferencias
# negT                           overlap_ent
# diferencias            entropia_relaciones
# entropia_relaciones                 mutinf
# nlp_semantics             Jaro-Winkler_rit
# overlap_ent               Jaro-Winkler_rit
# Jaro-Winkler_rit                    mutinf
# dtype: object

# %%
coor.max()
# Out:
# mutinf                 0.874226
# max_info               0.782574
# list_comp              0.163656
# list_incomp            0.436766
# rel_conceptuales       0.657936
# negH                   0.141121
# negT                   0.106775
# diferencias            0.538004
# entropia_relaciones    0.000000
# nlp_semantics          0.521917
# overlap_ent            0.669689
# Jaro-Winkler_rit       0.000000
# dtype: float64

# %%
coor.idxmin()
# Out:
# mutinf                 entropia_relaciones
# max_info               entropia_relaciones
# list_comp                      overlap_ent
# list_incomp                  nlp_semantics
# rel_conceptuales             nlp_semantics
# negH                         nlp_semantics
# negT                   entropia_relaciones
# diferencias               Jaro-Winkler_rit
# entropia_relaciones          nlp_semantics
# nlp_semantics                       mutinf
# overlap_ent                         mutinf
# Jaro-Winkler_rit                    mutinf
# dtype: object

# %%
coor.min()
# Out:
# mutinf                -0.757157
# max_info              -0.735426
# list_comp             -0.545804
# list_incomp           -0.250476
# rel_conceptuales      -0.428616
# negH                  -0.193858
# negT                  -0.072941
# diferencias           -0.574671
# entropia_relaciones   -0.807105
# nlp_semantics          0.000000
# overlap_ent            0.000000
# Jaro-Winkler_rit       0.000000
# dtype: float64

# %%
cols=train_m.columns

# %%
cols=train_m.columns
temp=coor.copy()
for index, strings in temp.iterrows():
    for c in cols:
        if strings[c]>0.7:
            print(index,c,strings[c])
# Out:
# max_info mutinf 0.8742262127337924
# nlp_semantics mutinf 0.7099407928318059
# overlap_ent max_info 0.7825742344177541
# Jaro-Winkler_rit max_info 0.7447020348002222

# %%
temp=coor.copy()
for index, strings in temp.iterrows():
    for c in cols:
        if strings[c]<-0.7:
            print(index,c,strings[c])
# Out:
# diferencias mutinf -0.7441758890915071
# diferencias max_info -0.7239323380337926
# entropia_relaciones mutinf -0.7571569371595174
# entropia_relaciones max_info -0.7354260721824829
# nlp_semantics entropia_relaciones -0.8071052790075005

# %%
# Checar variables colineales
#sns.relplot(data=train_m, x="max_info", y="mutinf")

# %%
#X_dev = np.array(dev.drop(['CLASS'],axis=1))
#y_d = np.array(dev['CLASS'])

# %%
# SICK
y_train=[]
for i in y_:
    if i == "ENTAILMENT":
        y_train.append(1)
    else:
        y_train.append(0)

# %%
scaler = preprocessing.MaxAbsScaler().fit(X)
X_scaled = scaler.transform(X)
X = X_scaled
X_train=X

# %%
train.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# # TEST

# %%
for i in range(50):
    if i==0:
        test = pd.read_pickle('salida/nuevo4i/SICK/TEST_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4i/SICK/TEST_'+str(i+1)+'.csv_.pickle')
            test=pd.concat([test,temp])
        except:
            pass

# %%
test = test.reset_index(drop=True)
test
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       1.346791        2.089354   0.970951  3.821864  0.005862  0.092585
# 1       1.327605        2.017728   1.263809  3.855514  0.005729  0.118164
# 2       1.344318        1.950857   1.094914  3.814045  0.005747  0.096256
# 3       0.000000        1.881168   0.000000  0.000000  0.000000  0.000000
# 4       1.360140        1.610893   0.985228  3.978109  0.006914  0.074974
# ...          ...             ...        ...       ...       ...       ...
# 4901    1.289382        1.919241   1.370951  3.700165  0.004805  0.168716
# 4902    1.400464        1.578898   0.721928  3.681429  0.005584  0.019384
# 4903    1.283513        0.747585   0.543564  3.682235  0.006004  0.169726
# 4904    1.307751        1.392618   1.198892  3.814937  0.006552  0.144823
# 4905    1.303547        1.609470   1.494193  3.777189  0.006070  0.149566
#
#          sumas  semantics  nlp_semantics  mutinf_t  ...  list_m  list_T  \
# 0     0.058977   0.441771       0.441771  4.041253  ...       2       5
# 1     0.051589   0.249968       0.249968  4.217714  ...       2       7
# 2     0.052614   0.287868       0.287868  4.088408  ...       2       7
# 3     0.000000   1.000000       1.000000  4.683008  ...       0       8
# 4     0.029070   0.151607       0.151607  4.574526  ...       1       7
# ...        ...        ...            ...       ...  ...     ...     ...
# 4901  0.053054   0.283690       0.283690  4.076415  ...       1       5
# 4902 -0.027277   0.238630       0.238630  3.770053  ...       1       5
# 4903  0.043600   0.049110       0.049110  3.697886  ...       2       4
# 4904  0.081047   0.569738       0.569738  3.848196  ...       5       6
# 4905  0.021490   0.353780       0.353780  3.770119  ...       3       7
#
#       Jaro-Winkler_rit  KL_divergence  negT  verbT  negH  verbH  overlap_ent  \
# 0             0.375000       0.428036     0            0            0.000000
# 1             0.571429       0.249111     0            0            0.666667
# 2             0.285714       0.412795     0            0            0.333333
# 3             1.000000       0.000000     0            0            1.000000
# 4             0.857143       0.277387     0            0            0.833333
# ...                ...            ...   ...    ...   ...    ...          ...
# 4901          0.250000       0.475319     0            0            0.250000
# 4902          0.250000       0.439648     0            0            0.000000
# 4903          0.000000       0.201834     0            0            0.000000
# 4904          0.125000       0.080018     0            0            0.000000
# 4905          0.200000       0.026993     0            0            0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2     CONTRADICTION
# 3        ENTAILMENT
# 4     CONTRADICTION
# ...             ...
# 4901  CONTRADICTION
# 4902  CONTRADICTION
# 4903  CONTRADICTION
# 4904  CONTRADICTION
# 4905  CONTRADICTION
#
# [4906 rows x 33 columns]

# %%
test=test.drop(["verbH","verbT"],axis=1)
test
# Out:
#       distancias  entropia_total  entropias    mutinf    mearts  max_info  \
# 0       1.346791        2.089354   0.970951  3.821864  0.005862  0.092585
# 1       1.327605        2.017728   1.263809  3.855514  0.005729  0.118164
# 2       1.344318        1.950857   1.094914  3.814045  0.005747  0.096256
# 3       0.000000        1.881168   0.000000  0.000000  0.000000  0.000000
# 4       1.360140        1.610893   0.985228  3.978109  0.006914  0.074974
# ...          ...             ...        ...       ...       ...       ...
# 4901    1.289382        1.919241   1.370951  3.700165  0.004805  0.168716
# 4902    1.400464        1.578898   0.721928  3.681429  0.005584  0.019384
# 4903    1.283513        0.747585   0.543564  3.682235  0.006004  0.169726
# 4904    1.307751        1.392618   1.198892  3.814937  0.006552  0.144823
# 4905    1.303547        1.609470   1.494193  3.777189  0.006070  0.149566
#
#          sumas  semantics  nlp_semantics  mutinf_t  ...  entropia_relaciones  \
# 0     0.058977   0.441771       0.441771  4.041253  ...             1.500000
# 1     0.051589   0.249968       0.249968  4.217714  ...             0.863121
# 2     0.052614   0.287868       0.287868  4.088408  ...             0.863121
# 3     0.000000   1.000000       1.000000  4.683008  ...             0.000000
# 4     0.029070   0.151607       0.151607  4.574526  ...             0.591673
# ...        ...        ...            ...       ...  ...                  ...
# 4901  0.053054   0.283690       0.283690  4.076415  ...             1.500000
# 4902 -0.027277   0.238630       0.238630  3.770053  ...             1.500000
# 4903  0.043600   0.049110       0.049110  3.697886  ...             1.521928
# 4904  0.081047   0.569738       0.569738  3.848196  ...             1.298795
# 4905  0.021490   0.353780       0.353780  3.770119  ...             1.370951
#
#       list_M  list_m  list_T  Jaro-Winkler_rit  KL_divergence  negT  negH  \
# 0          8       2       5          0.375000       0.428036     0     0
# 1          7       2       7          0.571429       0.249111     0     0
# 2          7       2       7          0.285714       0.412795     0     0
# 3          7       0       8          1.000000       0.000000     0     0
# 4          7       1       7          0.857143       0.277387     0     0
# ...      ...     ...     ...               ...            ...   ...   ...
# 4901       4       1       5          0.250000       0.475319     0     0
# 4902       4       1       5          0.250000       0.439648     0     0
# 4903       5       2       4          0.000000       0.201834     0     0
# 4904       8       5       6          0.125000       0.080018     0     0
# 4905       5       3       7          0.200000       0.026993     0     0
#
#       overlap_ent         clases
# 0        0.000000  CONTRADICTION
# 1        0.666667  CONTRADICTION
# 2        0.333333  CONTRADICTION
# 3        1.000000     ENTAILMENT
# 4        0.833333  CONTRADICTION
# ...           ...            ...
# 4901     0.250000  CONTRADICTION
# 4902     0.000000  CONTRADICTION
# 4903     0.000000  CONTRADICTION
# 4904     0.000000  CONTRADICTION
# 4905     0.000000  CONTRADICTION
#
# [4906 rows x 31 columns]

# %%
#train["mutinfx"]=train["mutinf"]/train["mutinf_t"]
test["mutinf"]=test["mutinf_t"]-test["mutinf"]
#train["max_infox"]=train["max_info"]/train["max_info_t"]
test["max_info"]=test["max_info_t"]-test["max_info"]
#train["mearts"]=train["mearts"]/train["mearts_t"]
#train["entropiasx"]=train["entropias"]/train["entropia_total"]
test["entropias"]=test["entropia_total"]-test["entropias"]
#train["sumasx"]=train["sumas"]/train["sumas_t"]
test["sumas"]=test["sumas_t"]-test["sumas"]
test["list_m"]=test["list_m"]/test["list_M"]
#train["list_mxx"]=train["list_M"]-train["list_m"]

# %%
test = test[['mutinf','max_info','list_comp', 'list_incomp', 'rel_conceptuales','negH','negT','diferencias','entropia_relaciones','nlp_semantics','overlap_ent','Jaro-Winkler_rit','clases']]

# %%
#test=test.drop(["sumas","mutinf","list_comp","list_incomp","entidades","entropia_total","list_rel_con",'mearts', 'max_info', 'similitud_faltantes','list_rel_con', 'list_M', 'list_m', 'list_T', 'list_bigram','diferencias'],axis=1)
#test=test[['list_comp', 'list_incomp','list_m','negT', 'negH',"clases"]]
test
# Out:
#         mutinf  max_info  list_comp  list_incomp  rel_conceptuales  negH  \
# 0     0.219389  0.355494          2            0                 2     0
# 1     0.362200  0.460011          2            0                 0     0
# 2     0.274363  0.394510          3            0                 0     0
# 3     4.683008  1.000000          0            0                 0     0
# 4     0.596417  0.792880          0            0                 0     0
# ...        ...       ...        ...          ...               ...   ...
# 4901  0.376250  0.166853          0            0                 2     0
# 4902  0.088624  0.102756          2            0                 1     0
# 4903  0.015651 -0.068309          2            0                 1     0
# 4904  0.033260  0.001965          2            0                 1     0
# 4905 -0.007069  0.007314          1            0                 1     0
#
#       negT  diferencias  entropia_relaciones  nlp_semantics  overlap_ent  \
# 0        0     0.400000             1.500000       0.441771     0.000000
# 1        0     0.285714             0.863121       0.249968     0.666667
# 2        0     0.285714             0.863121       0.287868     0.333333
# 3        0     0.000000             0.000000       1.000000     1.000000
# 4        0     0.142857             0.591673       0.151607     0.833333
# ...    ...          ...                  ...            ...          ...
# 4901     0     0.200000             1.500000       0.283690     0.250000
# 4902     0     0.200000             1.500000       0.238630     0.000000
# 4903     0     0.500000             1.521928       0.049110     0.000000
# 4904     0     0.833333             1.298795       0.569738     0.000000
# 4905     0     0.428571             1.370951       0.353780     0.000000
#
#       Jaro-Winkler_rit         clases
# 0             0.375000  CONTRADICTION
# 1             0.571429  CONTRADICTION
# 2             0.285714  CONTRADICTION
# 3             1.000000     ENTAILMENT
# 4             0.857143  CONTRADICTION
# ...                ...            ...
# 4901          0.250000  CONTRADICTION
# 4902          0.250000  CONTRADICTION
# 4903          0.000000  CONTRADICTION
# 4904          0.125000  CONTRADICTION
# 4905          0.200000  CONTRADICTION
#
# [4906 rows x 13 columns]

# %%
X_t = test.drop(['clases'],axis=1)
y_t = test['clases']

# %%
# SICK
y_test=[]
for i in y_t:
    if i == "ENTAILMENT":
        y_test.append(1)
    else:
        y_test.append(0)

# %%
y_test.count(1)
# Out:
# 1404

# %%
y_test.count(0)
# Out:
# 3502

# %%
scaler = preprocessing.MaxAbsScaler().fit(X_t)
X_scaled = scaler.transform(X_t)
X_test = X_scaled

# %% [markdown]
# # MODELO DE REGRESIÓN LÓGISTICA

# %%
# grid={"C":np.logspace(-3,3,7), "penalty":["l2"]}# l1 lasso l2 ridge
# logreg=linear_model.LogisticRegression()
# logreg_cv=GridSearchCV(logreg,grid,cv=20)
# logreg_cv.fit(X_train,y_train)

# %%
# print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
# print("accuracy :",logreg_cv.best_score_)

# %%
#X_train = np.where(np.isnan(X_train), 0, X_train)
#X_train

# %%
X_train.shape
# Out:
# (4439, 12)

# %%
model = LogisticRegression(penalty="l2", C=1,max_iter=500)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1, max_iter=500)

# %%
model.get_params()
# Out:
# {'C': 1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 500,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.decision_function(X)
# Out:
# array([ 0.52205432, -1.55472753, -0.88430929, ..., -3.82953871,
#        -2.38417883, -4.331759  ])

# %%
labels=train.columns[:-1]
labels
# Out:
# Index(['mutinf', 'max_info', 'list_comp', 'list_incomp', 'rel_conceptuales',
#        'negH', 'negT', 'diferencias', 'entropia_relaciones', 'nlp_semantics',
#        'overlap_ent', 'Jaro-Winkler_rit'],
#       dtype='object')

# %%
model.classes_
# Out:
# array([0, 1])

# %%
model.coef_[0]
# Out:
# array([ 0.22219782,  1.25398863,  1.0960864 , -1.72413872, -0.0074546 ,
#        -2.19100169, -4.26481338, -1.98982598, -0.64278858,  0.80899394,
#         3.23552094, -0.63073734])

# %%
coeficientes=model.coef_[0]

# %%
coeficientes
# Out:
# array([ 0.22219782,  1.25398863,  1.0960864 , -1.72413872, -0.0074546 ,
#        -2.19100169, -4.26481338, -1.98982598, -0.64278858,  0.80899394,
#         3.23552094, -0.63073734])

# %%
print("Maximo,minimo ",np.argmax(coeficientes),labels[np.argmax(coeficientes)],np.argmin(coeficientes),labels[np.argmin(coeficientes)])
# Out:
# Maximo,minimo  10 overlap_ent 6 negT

# %%
n_columns=train.shape[1]-1

# %%
n_columns
# Out:
# 12

# %%
import matplotlib.pyplot as plt
import numpy as np

x_v = np.arange(0,n_columns,1)
y_v = coeficientes

plt.bar(x_v,y_v)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Coeficientes')
plt.show()

# %%
#X_test = np.where(np.isnan(X_test), 0, X_test)
#X_test

# %%
X_test.shape
# Out:
# (4906, 12)

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
test["predictions"]=predictions
test
# Out:
# /tmp/ipykernel_3520618/256854265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["predictions"]=predictions
#         mutinf  max_info  list_comp  list_incomp  rel_conceptuales  negH  \
# 0     0.219389  0.355494          2            0                 2     0
# 1     0.362200  0.460011          2            0                 0     0
# 2     0.274363  0.394510          3            0                 0     0
# 3     4.683008  1.000000          0            0                 0     0
# 4     0.596417  0.792880          0            0                 0     0
# ...        ...       ...        ...          ...               ...   ...
# 4901  0.376250  0.166853          0            0                 2     0
# 4902  0.088624  0.102756          2            0                 1     0
# 4903  0.015651 -0.068309          2            0                 1     0
# 4904  0.033260  0.001965          2            0                 1     0
# 4905 -0.007069  0.007314          1            0                 1     0
#
#       negT  diferencias  entropia_relaciones  nlp_semantics  overlap_ent  \
# 0        0     0.400000             1.500000       0.441771     0.000000
# 1        0     0.285714             0.863121       0.249968     0.666667
# 2        0     0.285714             0.863121       0.287868     0.333333
# 3        0     0.000000             0.000000       1.000000     1.000000
# 4        0     0.142857             0.591673       0.151607     0.833333
# ...    ...          ...                  ...            ...          ...
# 4901     0     0.200000             1.500000       0.283690     0.250000
# 4902     0     0.200000             1.500000       0.238630     0.000000
# 4903     0     0.500000             1.521928       0.049110     0.000000
# 4904     0     0.833333             1.298795       0.569738     0.000000
# 4905     0     0.428571             1.370951       0.353780     0.000000
#
#       Jaro-Winkler_rit         clases  predictions
# 0             0.375000  CONTRADICTION            0
# 1             0.571429  CONTRADICTION            0
# 2             0.285714  CONTRADICTION            0
# 3             1.000000     ENTAILMENT            1
# 4             0.857143  CONTRADICTION            0
# ...                ...            ...          ...
# 4901          0.250000  CONTRADICTION            0
# 4902          0.250000  CONTRADICTION            0
# 4903          0.000000  CONTRADICTION            0
# 4904          0.125000  CONTRADICTION            0
# 4905          0.200000  CONTRADICTION            0
#
# [4906 rows x 14 columns]

# %%
test[(test["clases"]=="ENTAILMENT") & (test["predictions"]==0)]
# Out:
#         mutinf  max_info  list_comp  list_incomp  rel_conceptuales  negH  \
# 17    4.682331  1.000000          0            0                 0     0
# 18    4.517777  0.930899          0            0                 1     0
# 39    4.532033  0.878170          1            0                 0     0
# 56    4.284227  0.681128          3            0                 0     0
# 59    4.017435  0.624202          2            0                 1     0
# ...        ...       ...        ...          ...               ...   ...
# 4760  4.240598  0.706449          2            0                 2     0
# 4763  4.463848  0.845575          1            0                 0     0
# 4769  4.569281  0.829745          1            0                 0     0
# 4772  4.144079  0.580522          2            0                 1     0
# 4774  4.144079  0.580522          2            0                 1     0
#
#       negT  diferencias  entropia_relaciones  nlp_semantics  overlap_ent  \
# 17       0          0.0             0.000000            1.0     0.400000
# 18       0          0.0             0.650022            0.5     0.666667
# 39       0          0.0             0.000000            1.0     0.400000
# 56       0          0.0             0.000000            1.0     0.500000
# 59       0          0.0             0.721928            0.5     0.000000
# ...    ...          ...                  ...            ...          ...
# 4760     0          0.0             0.811278            0.5     0.600000
# 4763     0          0.0             0.000000            1.0     0.500000
# 4769     0          0.0             0.000000            1.0     0.666667
# 4772     0          0.0             0.811278            0.5     0.333333
# 4774     0          0.0             0.811278            0.5     0.333333
#
#       Jaro-Winkler_rit      clases  predictions
# 17            1.000000  ENTAILMENT            0
# 18            0.833333  ENTAILMENT            0
# 39            1.000000  ENTAILMENT            0
# 56            0.833333  ENTAILMENT            0
# 59            0.600000  ENTAILMENT            0
# ...                ...         ...          ...
# 4760          0.625000  ENTAILMENT            0
# 4763          1.000000  ENTAILMENT            0
# 4769          0.750000  ENTAILMENT            0
# 4772          0.750000  ENTAILMENT            0
# 4774          0.750000  ENTAILMENT            0
#
# [515 rows x 14 columns]

# %%
#test.to_csv("predictions_SICK_DEV.csv")

# %%
print(confusion_matrix(y_test, predictions,labels=[1,0]))
# Out:
# [[ 889  515]
#  [ 426 3076]]

# %%
# [[ 770  634]
#  [ 461 3041]]
#  acccuracy:  0.78
# precision:  0.63
# recall 0.55
# f1_score:  0.58
# matthews_score:  0.43
# [[ 970  434]
#  [ 495 3007]]
# acccuracy:  0.81
# precision:  0.66
# recall 0.69
# f1_score:  0.68
# matthews_score:  0.54

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions),2))
print("recall",round(recall_score(y_test,predictions),2))
print("f1_score: ",round(f1_score(y_test,predictions),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.81
# precision:  0.68
# recall 0.63
# f1_score:  0.65
# matthews_score:  0.52

# %%
# [[1009  395]
#  [ 471 3031]]
#  acccuracy:  0.82
# precision:  0.68
# recall 0.72
# f1_score:  0.7
# matthews_score:  0.58

# %%
# [[1010  394]
#  [ 480 3022]]
# acccuracy:  0.82
# precision:  0.68
# recall 0.72
# f1_score:  0.7
# matthews_score:  0.57

# %%
X_train.shape
# Out:
# (4439, 12)

# %%
X_test.shape
# Out:
# (4906, 12)

# %%
X_cv=np.concatenate((X_train, X_test), axis=0)
Y_cv=np.concatenate((y_train, y_test), axis=0)

# %%
#validation_size = 0.20
#X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)
X_train_cv=X_cv
Y_train_cv=Y_cv

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name + " Acurracy:" , round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_weighted')
msg += "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_weighted')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_weighted')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Acurracy:: 0.800000 (0.015319)
# Logistic Regression Precision:: 0.800000 (0.019025)
# Logistic Regression Recall:: 0.800000 (0.015319)
# Logistic Regression F1-score:: 0.800000 (0.017439)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10,shuffle=True)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.670000 (0.024425)
# Logistic Regression Recall:: 0.630000 (0.030668)
# Logistic Regression F1-score:: 0.650000 (0.012903)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_macro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_macro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_macro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.760000 (0.022901)
# Logistic Regression Recall:: 0.750000 (0.027360)
# Logistic Regression F1-score:: 0.750000 (0.022691)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_micro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_micro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_micro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.800000 (0.015319)
# Logistic Regression Recall:: 0.800000 (0.015319)
# Logistic Regression F1-score:: 0.800000 (0.015319)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='matthews_corrcoef')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.510000 (0.045772)

# %%
import shap
import pandas as pd
import numpy as np
shap.initjs()
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
#linear_model

# %%
# model = LogisticRegression()
# model.fit(X_train,y_train)

# %%
y_predict = model.predict(X_test)
print(classification_report( y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      3502
#            1       0.68      0.63      0.65      1404
#
#     accuracy                           0.81      4906
#    macro avg       0.77      0.76      0.76      4906
# weighted avg       0.80      0.81      0.81      4906

# %%
#  precision    recall  f1-score   support

#            0       0.88      0.86      0.87      3502
#            1       0.68      0.72      0.70      1404

#     accuracy                           0.82      4906
#    macro avg       0.78      0.79      0.79      4906
# weighted avg       0.83      0.82      0.82      4906

#  precision    recall  f1-score   support

#            0       0.86      0.88      0.87      3502
#            1       0.68      0.64      0.66      1404

#     accuracy                           0.81      4906
#    macro avg       0.77      0.76      0.76      4906
# weighted avg       0.81      0.81      0.81      4906

# %%
explainer = shap.Explainer(model,X_train,feature_names=test.columns[:-2])
shap_values = explainer(X_test)

# %%
test.columns[:-2]
# Out:
# Index(['mutinf', 'max_info', 'list_comp', 'list_incomp', 'rel_conceptuales',
#        'negH', 'negT', 'diferencias', 'entropia_relaciones', 'nlp_semantics',
#        'overlap_ent', 'Jaro-Winkler_rit'],
#       dtype='object')

# %%
explainer.expected_value
# Out:
# -1.4378680582438075

# %%
X_test
# Out:
# array([[ 0.04514178,  0.3554943 ,  0.28571429, ...,  0.42298261,
#          0.        ,  0.375     ],
#        [ 0.07452676,  0.46001129,  0.28571429, ...,  0.23933687,
#          0.66666667,  0.57142857],
#        [ 0.05645325,  0.39451015,  0.42857143, ...,  0.27562527,
#          0.33333333,  0.28571429],
#        ...,
#        [ 0.00322046, -0.06830921,  0.28571429, ...,  0.04702184,
#          0.        ,  0.        ],
#        [ 0.00684355,  0.00196524,  0.28571429, ...,  0.54550719,
#          0.        ,  0.125     ],
#        [-0.00145462,  0.00731428,  0.14285714, ...,  0.33873372,
#          0.        ,  0.2       ]])

# %%
shap.plots.beeswarm(shap_values)

# %%
ind = 21
print(X_test[ind],y_test[ind],y_predict[ind])
shap.plots.force(shap_values[ind])
shap.plots.waterfall(shap_values[ind])
# Out:
# [0.         0.87556685 0.         0.         0.         0.
#  0.         0.8375496  0.21256247 0.58725685 0.305726   0.66666667
#  0.         0.33333333 0.         0.5        0.4        0.
#  0.         0.45914792 0.375      0.         0.4        0.66666667
#  0.         0.         0.         0.25      ] 0 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 3
#       1 ind = 21
#       2 print(X_test[ind],y_test[ind],y_predict[ind])
# ----> 3 shap.plots.force(shap_values[ind])
#       4 shap.plots.waterfall(shap_values[ind])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:195, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     183     instance = Instance(np.zeros((1, len(feature_names))), features)
#     184     e = AdditiveExplanation(
#     185         base_value,
#     186         np.sum(shap_values[0, :]) + base_value,
#    (...)
#     192         DenseData(np.zeros((1, len(feature_names))), list(feature_names))
#     193     )
# --> 195     return visualize(e,
#     196                      plot_cmap,
#     197                      matplotlib,
#     198                      figsize=figsize,
#     199                      show=show,
#     200                      text_rotation=text_rotation,
#     201                      min_perc=contribution_threshold)
#     203 else:
#     204     if matplotlib:
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:413, in visualize(e, plot_cmap, matplotlib, figsize, show, ordering_keys, ordering_keys_time_format, text_rotation, min_perc)
#     406         return AdditiveForceVisualizer(e, plot_cmap=plot_cmap).matplotlib(
#     407             figsize=figsize,
#     408             show=show,
#     409             text_rotation=text_rotation,
#     410             min_perc=min_perc,
#     411         )
#     412     else:
# --> 413         return AdditiveForceVisualizer(e, plot_cmap=plot_cmap)
#     414 elif isinstance(e, Explanation):
#     415     if matplotlib:
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:491, in AdditiveForceVisualizer.__init__(self, e, plot_cmap)
#     489 # build the json data
#     490 features = {}
# --> 491 for i in filter(lambda j: e.effects[j] != 0, range(len(e.data.group_names))):
#     492     features[i] = {
#     493         "effect": ensure_not_numpy(e.effects[i]),
#     494         "value": ensure_not_numpy(e.instance.group_display_values[i])
#     495     }
#     496 self.data = {
#     497     "outNames": e.model.out_names,
#     498     "baseValue": ensure_not_numpy(e.base_value),
#    (...)
#     503     "plot_cmap": plot_cmap,
#     504 }
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:491, in AdditiveForceVisualizer.__init__.<locals>.<lambda>(j)
#     489 # build the json data
#     490 features = {}
# --> 491 for i in filter(lambda j: e.effects[j] != 0, range(len(e.data.group_names))):
#     492     features[i] = {
#     493         "effect": ensure_not_numpy(e.effects[i]),
#     494         "value": ensure_not_numpy(e.instance.group_display_values[i])
#     495     }
#     496 self.data = {
#     497     "outNames": e.model.out_names,
#     498     "baseValue": ensure_not_numpy(e.base_value),
#    (...)
#     503     "plot_cmap": plot_cmap,
#     504 }
#
# IndexError: index 28 is out of bounds for axis 0 with size 28

# %%
ind = 6
print(X_test[ind])
# This amazing documentary gives us a glimpse into the lives of the brave
# women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
# tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
# languages and multiple legal precedents depending on the region of the country and
# the religious/ethnic background of the plaintiffs and defendants-- these brave,
# strong women are making a difference. [...]

shap.plots.waterfall(shap_values[ind,:,1])
# Out:
# [0.91739828 0.53761146 0.46688595 0.95367512 0.16914902 0.12700167
#  0.08835622 0.85470472 0.22051327 0.4067985  0.15215869 0.33333333
#  0.         0.         0.66666667 0.         0.         0.08163265
#  0.         0.45914792 0.1875     0.2        0.46666667 0.33333333
#  0.06419812 0.         0.         0.        ]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 10
#       2 print(X_test[ind])
#       3 # This amazing documentary gives us a glimpse into the lives of the brave
#       4 # women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
#       5 # tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
#       6 # languages and multiple legal precedents depending on the region of the country and
#       7 # the religious/ethnic background of the plaintiffs and defendants-- these brave,
#       8 # strong women are making a difference. [...]
# ---> 10 shap.plots.waterfall(shap_values[ind,:,1])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/_explanation.py:422, in Explanation.__getitem__(self, item)
#     420 if new_self is None:
#     421     new_self = copy.copy(self)
# --> 422 new_self._s = new_self._s.__getitem__(item)
#     423 new_self.op_history.append({
#     424     "name": "__getitem__",
#     425     "args": (item,),
#     426     "prev_shape": self.shape
#     427 })
#     429 return new_self
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer.py:112, in Slicer.__getitem__(self, item)
#     110 index_slicer = AtomicSlicer(index_tup, max_dim=1)
#     111 slicer_index = index_slicer[tracked.dim]
# --> 112 sliced_o = tracked[slicer_index]
#     113 sliced_dim = resolve_dim(index_tup, tracked.dim)
#     115 new_tracked = tracked.__class__(sliced_o, sliced_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:582, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     579 head_slice = cls.type_map[o_type].head_slice
#     580 tail_slice = cls.type_map[o_type].tail_slice
# --> 582 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
#     583 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     584 return out
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:418, in ArrayHandler.head_slice(cls, o, index_tup, max_dim)
#     416 cut_index = index_tup[:cut]
#     417 is_element = any([True if isinstance(x, int) else False for x in cut_index])
# --> 418 sliced_o = o[cut_index]
#     420 return is_element, sliced_o, cut
#
# IndexError: index 1 is out of bounds for axis 2 with size 1

# %%
shap.summary_plot(shap_values, X_test,plot_type="bar")

# %%
shap.summary_plot(shap_values[1:,], X_test[1:,])

# %%
shap.summary_plot(shap_values, X_test,feature_names=test.columns[:-1])

# %%
shap_values[2:,]
# Out:
# .values =
# array([[ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [-0.01299836, -0.11268555, -0.4045574 ,  0.04382668,  0.21114683],
#        ...,
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683]])
#
# .base_values =
# array([-0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388])
#
# .data =
# array([[-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [ 1.23549291,  0.39218921,  0.29047164,  0.24312215, -0.67101221],
#        ...,
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221]])

# %%
shap.summary_plot(shap_values[0:,], X_test,feature_names=test.columns[:-1])

# %%
explainer.expected_value
# Out:
# -0.7454438806409415

# %%
shap_values.shape
# Out:
# (800, 5)

# %% [markdown]
# # Árbol de decisión

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
clf = DecisionTreeClassifier(splitter="random")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print("acccuracy: ",round(accuracy_score(y_test,y_pred),2))
print("precision: ",round(precision_score(y_test,y_pred),2))
print("recall",round(recall_score(y_test,y_pred),2))
print("f1_score: ",round(f1_score(y_test,y_pred),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,y_pred),2))
# Out:
# acccuracy:  0.78
# precision:  0.61
# recall 0.69
# f1_score:  0.65
# matthews_score:  0.49

# %%
validation_size = 0.01
X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)

# %%
name='DecisionTree'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='precision')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='recall')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='f1')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# DecisionTree: 0.670000 (0.048836)
# DecisionTree: 0.660000 (0.035226)
# DecisionTree: 0.670000 (0.033797)

# %%
c=train.columns[:-1]
confusion_matrix(y_test,y_pred)
# Out:
# array([[2874,  628],
#        [ 434,  970]])

# %%
# Estructura del árbol creado
import matplotlib.pyplot as plt
# ------------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(20, 10))

print(f"Profundidad del árbol: {clf.get_depth()}")
print(f"Número de nodos terminales: {clf.get_n_leaves()}")

plot = plot_tree(
            decision_tree = clf,
            feature_names = c,
            class_names   = True,
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 29
# Número de nodos terminales: 1014
