# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV

# %%
for i in range(45):
    if i==0:
        train = pd.read_pickle('salida/nuevo4b/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4b/SICK/TRAIN_'+str(i+1)+'.csv_.pickle')
            train=pd.concat([train,temp])
        except:
            print(i+1)

# %%
train=train.reset_index(drop=True)
train
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.000000    0.000000           2.097      0.000  0.000000  0.000000
# 1     0.000000    0.000000           1.913      0.000  0.000000  0.000000
# 2     0.000000    0.000000           2.176      0.000  0.000000  0.000000
# 3     0.361657    4.241265           1.909      1.400  3.811703  0.006280
# 4     0.467000    4.242607           2.183      1.441  3.821563  0.005581
# ...        ...         ...             ...        ...       ...       ...
# 4434  0.062812    5.751723           1.053      0.811  3.786475  0.006455
# 4435  0.073710    5.698565           1.384      1.384  3.779084  0.008525
# 4436  0.274907    2.850390           1.688      1.371  3.787387  0.006522
# 4437  0.358468    1.437292           1.411      1.459  3.685267  0.004270
# 4438  0.033962    2.867165           1.299      1.061  3.788780  0.005101
#
#       max_info  list_comp  diferencias  list_incomp  ...  list_m  list_T  \
# 0     0.000000          1     0.000000            0  ...       0       8
# 1     0.000000          2     0.000000            0  ...       0       7
# 2     0.000000          1     0.000000            0  ...       0       7
# 3     0.140442          1     0.600000            0  ...       3       5
# 4     0.155224          2     0.428571            1  ...       3       7
# ...        ...        ...          ...          ...  ...     ...     ...
# 4434  0.084316          1     1.333333            0  ...       4       3
# 4435  0.056842          0     1.333333            0  ...       4       3
# 4436  0.202038          3     0.400000            1  ...       2       5
# 4437  0.156616          1     0.166667            0  ...       1       6
# 4438  0.046050          1     0.500000            0  ...       2       4
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  verbT negH  verbH overlap_ent  \
# 0             0.857143                 0     0           0           0.800000
# 1             0.875000                 1     0           0           0.333333
# 2             1.000000                 0     0           0           0.400000
# 3             0.375000                 1     0           0           0.333333
# 4             0.500000                 0     0           0           0.166667
# ...                ...               ...   ...    ...  ...    ...         ...
# 4434          0.333333                 0     0           0           0.200000
# 4435          0.250000                 0     0           1   play    0.000000
# 4436          0.000000                 0     0           0           0.000000
# 4437          0.333333                 0     0           0           0.333333
# 4438          0.000000                 1     0           0           0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2        ENTAILMENT
# 3     CONTRADICTION
# 4     CONTRADICTION
# ...             ...
# 4434  CONTRADICTION
# 4435  CONTRADICTION
# 4436  CONTRADICTION
# 4437  CONTRADICTION
# 4438  CONTRADICTION
#
# [4439 rows x 21 columns]

# %%
train.boxplot(by="clases",column="list_incomp")
# Out:
# <Axes: title={'center': 'list_incomp'}, xlabel='clases'>

# %% [markdown]
# ## Eliminar características

# %%
# Diferencia entre entropia total - entropias y dejar la columna
# Quitar max_info_p
# revisar scaler y/o normalización de shape con total
#
train=train.drop(["verbH","verbT"],axis=1)
#train=train.drop(["Match"],axis=1)
train
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.000000    0.000000           2.097      0.000  0.000000  0.000000
# 1     0.000000    0.000000           1.913      0.000  0.000000  0.000000
# 2     0.000000    0.000000           2.176      0.000  0.000000  0.000000
# 3     0.361657    4.241265           1.909      1.400  3.811703  0.006280
# 4     0.467000    4.242607           2.183      1.441  3.821563  0.005581
# ...        ...         ...             ...        ...       ...       ...
# 4434  0.062812    5.751723           1.053      0.811  3.786475  0.006455
# 4435  0.073710    5.698565           1.384      1.384  3.779084  0.008525
# 4436  0.274907    2.850390           1.688      1.371  3.787387  0.006522
# 4437  0.358468    1.437292           1.411      1.459  3.685267  0.004270
# 4438  0.033962    2.867165           1.299      1.061  3.788780  0.005101
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.000000          1     0.000000            0       7       0       8
# 1     0.000000          2     0.000000            0       8       0       7
# 2     0.000000          1     0.000000            0       5       0       7
# 3     0.140442          1     0.600000            0       8       3       5
# 4     0.155224          2     0.428571            1       8       3       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4434  0.084316          1     1.333333            0       6       4       3
# 4435  0.056842          0     1.333333            0       4       4       3
# 4436  0.202038          3     0.400000            1       6       2       5
# 4437  0.156616          1     0.166667            0       3       1       6
# 4438  0.046050          1     0.500000            0       4       2       4
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  negH  overlap_ent  \
# 0             0.857143                 0     0     0     0.800000
# 1             0.875000                 1     0     0     0.333333
# 2             1.000000                 0     0     0     0.400000
# 3             0.375000                 1     0     0     0.333333
# 4             0.500000                 0     0     0     0.166667
# ...                ...               ...   ...   ...          ...
# 4434          0.333333                 0     0     0     0.200000
# 4435          0.250000                 0     0     1     0.000000
# 4436          0.000000                 0     0     0     0.000000
# 4437          0.333333                 0     0     0     0.333333
# 4438          0.000000                 1     0     0     0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2        ENTAILMENT
# 3     CONTRADICTION
# 4     CONTRADICTION
# ...             ...
# 4434  CONTRADICTION
# 4435  CONTRADICTION
# 4436  CONTRADICTION
# 4437  CONTRADICTION
# 4438  CONTRADICTION
#
# [4439 rows x 19 columns]

# %%
train.columns
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'rel_conceptuales',
#        'negT', 'negH', 'overlap_ent', 'clases'],
#       dtype='object')

# %%
#train=train[['list_comp', 'list_incomp','list_m','negT', 'negH',"clases"]]

# %%
X = train.drop(['clases'],axis=1)
y_ = train['clases']

# %%
# Guardar un nuevo dataframe para la correlación de variables
train_m=train.drop(['clases'],axis=1).corr(method='pearson')

# %%
train_m
# Out:
#                      sumas  distancias  entropia_total  entropias    mutinf  \
# sumas             1.000000    0.381970        0.271520   0.761477  0.627366
# distancias        0.381970    1.000000       -0.087456   0.721175  0.728197
# entropia_total    0.271520   -0.087456        1.000000   0.178403 -0.009215
# entropias         0.761477    0.721175        0.178403   1.000000  0.879220
# mutinf            0.627366    0.728197       -0.009215   0.879220  1.000000
# mearts            0.400489    0.620341       -0.063634   0.674828  0.806756
# max_info          0.908849    0.418746        0.229660   0.796917  0.692025
# list_comp         0.103729    0.207714        0.151013   0.168034  0.169403
# diferencias       0.264650    0.897221       -0.162596   0.626223  0.688128
# list_incomp       0.006991    0.043721        0.086082   0.019042  0.018419
# list_M            0.181104    0.397097        0.251743   0.244050  0.190983
# list_m            0.385031    0.999771       -0.087949   0.720777  0.728578
# list_T            0.250516    0.076955        0.254476   0.141728  0.047244
# Jaro-Winkler_rit -0.253603   -0.623564        0.130767  -0.519357 -0.576078
# rel_conceptuales  0.050703    0.117211        0.100718   0.109366  0.115682
# negT             -0.042469   -0.045030       -0.024774  -0.053581 -0.072267
# negH             -0.003133    0.107674       -0.043260   0.079836  0.191083
# overlap_ent      -0.290725   -0.607092        0.050032  -0.520237 -0.566037
#
#                     mearts  max_info  list_comp  diferencias  list_incomp  \
# sumas             0.400489  0.908849   0.103729     0.264650     0.006991
# distancias        0.620341  0.418746   0.207714     0.897221     0.043721
# entropia_total   -0.063634  0.229660   0.151013    -0.162596     0.086082
# entropias         0.674828  0.796917   0.168034     0.626223     0.019042
# mutinf            0.806756  0.692025   0.169403     0.688128     0.018419
# mearts            1.000000  0.458671   0.129938     0.626758     0.003735
# max_info          0.458671  1.000000   0.094525     0.354131     0.000335
# list_comp         0.129938  0.094525   1.000000     0.128580    -0.019108
# diferencias       0.626758  0.354131   0.128580     1.000000     0.018049
# list_incomp       0.003735  0.000335  -0.019108     0.018049     1.000000
# list_M            0.129323  0.102934   0.250975     0.217922     0.080601
# list_m            0.625311  0.420748   0.206217     0.900394     0.042486
# list_T           -0.028936  0.109518   0.124348    -0.189356     0.065256
# Jaro-Winkler_rit -0.521810 -0.324453  -0.210503    -0.642089    -0.108674
# rel_conceptuales  0.127579  0.046077   0.098526     0.064973    -0.010873
# negT             -0.071334 -0.039522  -0.054427    -0.057291    -0.034915
# negH              0.124286  0.020868  -0.042616     0.112296    -0.031909
# overlap_ent      -0.505729 -0.339239  -0.466392    -0.592055    -0.214507
#
#                     list_M    list_m    list_T  Jaro-Winkler_rit  \
# sumas             0.181104  0.385031  0.250516         -0.253603
# distancias        0.397097  0.999771  0.076955         -0.623564
# entropia_total    0.251743 -0.087949  0.254476          0.130767
# entropias         0.244050  0.720777  0.141728         -0.519357
# mutinf            0.190983  0.728578  0.047244         -0.576078
# mearts            0.129323  0.625311 -0.028936         -0.521810
# max_info          0.102934  0.420748  0.109518         -0.324453
# list_comp         0.250975  0.206217  0.124348         -0.210503
# diferencias       0.217922  0.900394 -0.189356         -0.642089
# list_incomp       0.080601  0.042486  0.065256         -0.108674
# list_M            1.000000  0.395410  0.667383         -0.006067
# list_m            0.395410  1.000000  0.072834         -0.624327
# list_T            0.667383  0.072834  1.000000          0.151661
# Jaro-Winkler_rit -0.006067 -0.624327  0.151661          1.000000
# rel_conceptuales  0.187060  0.117183  0.086053         -0.228262
# negT             -0.040202 -0.045523  0.048223          0.077208
# negH              0.081634  0.107846 -0.030675         -0.031086
# overlap_ent      -0.015454 -0.607601  0.076854          0.654934
#
#                   rel_conceptuales      negT      negH  overlap_ent
# sumas                     0.050703 -0.042469 -0.003133    -0.290725
# distancias                0.117211 -0.045030  0.107674    -0.607092
# entropia_total            0.100718 -0.024774 -0.043260     0.050032
# entropias                 0.109366 -0.053581  0.079836    -0.520237
# mutinf                    0.115682 -0.072267  0.191083    -0.566037
# mearts                    0.127579 -0.071334  0.124286    -0.505729
# max_info                  0.046077 -0.039522  0.020868    -0.339239
# list_comp                 0.098526 -0.054427 -0.042616    -0.466392
# diferencias               0.064973 -0.057291  0.112296    -0.592055
# list_incomp              -0.010873 -0.034915 -0.031909    -0.214507
# list_M                    0.187060 -0.040202  0.081634    -0.015454
# list_m                    0.117183 -0.045523  0.107846    -0.607601
# list_T                    0.086053  0.048223 -0.030675     0.076854
# Jaro-Winkler_rit         -0.228262  0.077208 -0.031086     0.654934
# rel_conceptuales          1.000000 -0.015727 -0.025121    -0.245237
# negT                     -0.015727  1.000000 -0.047197     0.106775
# negH                     -0.025121 -0.047197  1.000000     0.003750
# overlap_ent              -0.245237  0.106775  0.003750     1.000000

# %%
sns.heatmap(train_m,vmin=-1,vmax=1)
# Out:
# <Axes: >

# %%
train_m.columns
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'rel_conceptuales',
#        'negT', 'negH', 'overlap_ent'],
#       dtype='object')

# %%
train_m
# Out:
#                      sumas  distancias  entropia_total  entropias    mutinf  \
# sumas             1.000000    0.381970        0.271520   0.761477  0.627366
# distancias        0.381970    1.000000       -0.087456   0.721175  0.728197
# entropia_total    0.271520   -0.087456        1.000000   0.178403 -0.009215
# entropias         0.761477    0.721175        0.178403   1.000000  0.879220
# mutinf            0.627366    0.728197       -0.009215   0.879220  1.000000
# mearts            0.400489    0.620341       -0.063634   0.674828  0.806756
# max_info          0.908849    0.418746        0.229660   0.796917  0.692025
# list_comp         0.103729    0.207714        0.151013   0.168034  0.169403
# diferencias       0.264650    0.897221       -0.162596   0.626223  0.688128
# list_incomp       0.006991    0.043721        0.086082   0.019042  0.018419
# list_M            0.181104    0.397097        0.251743   0.244050  0.190983
# list_m            0.385031    0.999771       -0.087949   0.720777  0.728578
# list_T            0.250516    0.076955        0.254476   0.141728  0.047244
# Jaro-Winkler_rit -0.253603   -0.623564        0.130767  -0.519357 -0.576078
# rel_conceptuales  0.050703    0.117211        0.100718   0.109366  0.115682
# negT             -0.042469   -0.045030       -0.024774  -0.053581 -0.072267
# negH             -0.003133    0.107674       -0.043260   0.079836  0.191083
# overlap_ent      -0.290725   -0.607092        0.050032  -0.520237 -0.566037
#
#                     mearts  max_info  list_comp  diferencias  list_incomp  \
# sumas             0.400489  0.908849   0.103729     0.264650     0.006991
# distancias        0.620341  0.418746   0.207714     0.897221     0.043721
# entropia_total   -0.063634  0.229660   0.151013    -0.162596     0.086082
# entropias         0.674828  0.796917   0.168034     0.626223     0.019042
# mutinf            0.806756  0.692025   0.169403     0.688128     0.018419
# mearts            1.000000  0.458671   0.129938     0.626758     0.003735
# max_info          0.458671  1.000000   0.094525     0.354131     0.000335
# list_comp         0.129938  0.094525   1.000000     0.128580    -0.019108
# diferencias       0.626758  0.354131   0.128580     1.000000     0.018049
# list_incomp       0.003735  0.000335  -0.019108     0.018049     1.000000
# list_M            0.129323  0.102934   0.250975     0.217922     0.080601
# list_m            0.625311  0.420748   0.206217     0.900394     0.042486
# list_T           -0.028936  0.109518   0.124348    -0.189356     0.065256
# Jaro-Winkler_rit -0.521810 -0.324453  -0.210503    -0.642089    -0.108674
# rel_conceptuales  0.127579  0.046077   0.098526     0.064973    -0.010873
# negT             -0.071334 -0.039522  -0.054427    -0.057291    -0.034915
# negH              0.124286  0.020868  -0.042616     0.112296    -0.031909
# overlap_ent      -0.505729 -0.339239  -0.466392    -0.592055    -0.214507
#
#                     list_M    list_m    list_T  Jaro-Winkler_rit  \
# sumas             0.181104  0.385031  0.250516         -0.253603
# distancias        0.397097  0.999771  0.076955         -0.623564
# entropia_total    0.251743 -0.087949  0.254476          0.130767
# entropias         0.244050  0.720777  0.141728         -0.519357
# mutinf            0.190983  0.728578  0.047244         -0.576078
# mearts            0.129323  0.625311 -0.028936         -0.521810
# max_info          0.102934  0.420748  0.109518         -0.324453
# list_comp         0.250975  0.206217  0.124348         -0.210503
# diferencias       0.217922  0.900394 -0.189356         -0.642089
# list_incomp       0.080601  0.042486  0.065256         -0.108674
# list_M            1.000000  0.395410  0.667383         -0.006067
# list_m            0.395410  1.000000  0.072834         -0.624327
# list_T            0.667383  0.072834  1.000000          0.151661
# Jaro-Winkler_rit -0.006067 -0.624327  0.151661          1.000000
# rel_conceptuales  0.187060  0.117183  0.086053         -0.228262
# negT             -0.040202 -0.045523  0.048223          0.077208
# negH              0.081634  0.107846 -0.030675         -0.031086
# overlap_ent      -0.015454 -0.607601  0.076854          0.654934
#
#                   rel_conceptuales      negT      negH  overlap_ent
# sumas                     0.050703 -0.042469 -0.003133    -0.290725
# distancias                0.117211 -0.045030  0.107674    -0.607092
# entropia_total            0.100718 -0.024774 -0.043260     0.050032
# entropias                 0.109366 -0.053581  0.079836    -0.520237
# mutinf                    0.115682 -0.072267  0.191083    -0.566037
# mearts                    0.127579 -0.071334  0.124286    -0.505729
# max_info                  0.046077 -0.039522  0.020868    -0.339239
# list_comp                 0.098526 -0.054427 -0.042616    -0.466392
# diferencias               0.064973 -0.057291  0.112296    -0.592055
# list_incomp              -0.010873 -0.034915 -0.031909    -0.214507
# list_M                    0.187060 -0.040202  0.081634    -0.015454
# list_m                    0.117183 -0.045523  0.107846    -0.607601
# list_T                    0.086053  0.048223 -0.030675     0.076854
# Jaro-Winkler_rit         -0.228262  0.077208 -0.031086     0.654934
# rel_conceptuales          1.000000 -0.015727 -0.025121    -0.245237
# negT                     -0.015727  1.000000 -0.047197     0.106775
# negH                     -0.025121 -0.047197  1.000000     0.003750
# overlap_ent              -0.245237  0.106775  0.003750     1.000000

# %%
coor=pd.DataFrame(np.tril(train_m,-1),index=train_m.columns,columns=train_m.columns)
coor
# Out:
#                      sumas  distancias  entropia_total  entropias    mutinf  \
# sumas             0.000000    0.000000        0.000000   0.000000  0.000000
# distancias        0.381970    0.000000        0.000000   0.000000  0.000000
# entropia_total    0.271520   -0.087456        0.000000   0.000000  0.000000
# entropias         0.761477    0.721175        0.178403   0.000000  0.000000
# mutinf            0.627366    0.728197       -0.009215   0.879220  0.000000
# mearts            0.400489    0.620341       -0.063634   0.674828  0.806756
# max_info          0.908849    0.418746        0.229660   0.796917  0.692025
# list_comp         0.103729    0.207714        0.151013   0.168034  0.169403
# diferencias       0.264650    0.897221       -0.162596   0.626223  0.688128
# list_incomp       0.006991    0.043721        0.086082   0.019042  0.018419
# list_M            0.181104    0.397097        0.251743   0.244050  0.190983
# list_m            0.385031    0.999771       -0.087949   0.720777  0.728578
# list_T            0.250516    0.076955        0.254476   0.141728  0.047244
# Jaro-Winkler_rit -0.253603   -0.623564        0.130767  -0.519357 -0.576078
# rel_conceptuales  0.050703    0.117211        0.100718   0.109366  0.115682
# negT             -0.042469   -0.045030       -0.024774  -0.053581 -0.072267
# negH             -0.003133    0.107674       -0.043260   0.079836  0.191083
# overlap_ent      -0.290725   -0.607092        0.050032  -0.520237 -0.566037
#
#                     mearts  max_info  list_comp  diferencias  list_incomp  \
# sumas             0.000000  0.000000   0.000000     0.000000     0.000000
# distancias        0.000000  0.000000   0.000000     0.000000     0.000000
# entropia_total    0.000000  0.000000   0.000000     0.000000     0.000000
# entropias         0.000000  0.000000   0.000000     0.000000     0.000000
# mutinf            0.000000  0.000000   0.000000     0.000000     0.000000
# mearts            0.000000  0.000000   0.000000     0.000000     0.000000
# max_info          0.458671  0.000000   0.000000     0.000000     0.000000
# list_comp         0.129938  0.094525   0.000000     0.000000     0.000000
# diferencias       0.626758  0.354131   0.128580     0.000000     0.000000
# list_incomp       0.003735  0.000335  -0.019108     0.018049     0.000000
# list_M            0.129323  0.102934   0.250975     0.217922     0.080601
# list_m            0.625311  0.420748   0.206217     0.900394     0.042486
# list_T           -0.028936  0.109518   0.124348    -0.189356     0.065256
# Jaro-Winkler_rit -0.521810 -0.324453  -0.210503    -0.642089    -0.108674
# rel_conceptuales  0.127579  0.046077   0.098526     0.064973    -0.010873
# negT             -0.071334 -0.039522  -0.054427    -0.057291    -0.034915
# negH              0.124286  0.020868  -0.042616     0.112296    -0.031909
# overlap_ent      -0.505729 -0.339239  -0.466392    -0.592055    -0.214507
#
#                     list_M    list_m    list_T  Jaro-Winkler_rit  \
# sumas             0.000000  0.000000  0.000000          0.000000
# distancias        0.000000  0.000000  0.000000          0.000000
# entropia_total    0.000000  0.000000  0.000000          0.000000
# entropias         0.000000  0.000000  0.000000          0.000000
# mutinf            0.000000  0.000000  0.000000          0.000000
# mearts            0.000000  0.000000  0.000000          0.000000
# max_info          0.000000  0.000000  0.000000          0.000000
# list_comp         0.000000  0.000000  0.000000          0.000000
# diferencias       0.000000  0.000000  0.000000          0.000000
# list_incomp       0.000000  0.000000  0.000000          0.000000
# list_M            0.000000  0.000000  0.000000          0.000000
# list_m            0.395410  0.000000  0.000000          0.000000
# list_T            0.667383  0.072834  0.000000          0.000000
# Jaro-Winkler_rit -0.006067 -0.624327  0.151661          0.000000
# rel_conceptuales  0.187060  0.117183  0.086053         -0.228262
# negT             -0.040202 -0.045523  0.048223          0.077208
# negH              0.081634  0.107846 -0.030675         -0.031086
# overlap_ent      -0.015454 -0.607601  0.076854          0.654934
#
#                   rel_conceptuales      negT     negH  overlap_ent
# sumas                     0.000000  0.000000  0.00000          0.0
# distancias                0.000000  0.000000  0.00000          0.0
# entropia_total            0.000000  0.000000  0.00000          0.0
# entropias                 0.000000  0.000000  0.00000          0.0
# mutinf                    0.000000  0.000000  0.00000          0.0
# mearts                    0.000000  0.000000  0.00000          0.0
# max_info                  0.000000  0.000000  0.00000          0.0
# list_comp                 0.000000  0.000000  0.00000          0.0
# diferencias               0.000000  0.000000  0.00000          0.0
# list_incomp               0.000000  0.000000  0.00000          0.0
# list_M                    0.000000  0.000000  0.00000          0.0
# list_m                    0.000000  0.000000  0.00000          0.0
# list_T                    0.000000  0.000000  0.00000          0.0
# Jaro-Winkler_rit          0.000000  0.000000  0.00000          0.0
# rel_conceptuales          0.000000  0.000000  0.00000          0.0
# negT                     -0.015727  0.000000  0.00000          0.0
# negH                     -0.025121 -0.047197  0.00000          0.0
# overlap_ent              -0.245237  0.106775  0.00375          0.0

# %%
coor.idxmax()
# Out:
# sumas                       max_info
# distancias                    list_m
# entropia_total                list_T
# entropias                     mutinf
# mutinf                        mearts
# mearts                   diferencias
# max_info                      list_m
# list_comp                     list_M
# diferencias                   list_m
# list_incomp                   list_M
# list_M                        list_T
# list_m              rel_conceptuales
# list_T              Jaro-Winkler_rit
# Jaro-Winkler_rit         overlap_ent
# rel_conceptuales               sumas
# negT                     overlap_ent
# negH                     overlap_ent
# overlap_ent                    sumas
# dtype: object

# %%
coor.max()
# Out:
# sumas               0.908849
# distancias          0.999771
# entropia_total      0.254476
# entropias           0.879220
# mutinf              0.806756
# mearts              0.626758
# max_info            0.420748
# list_comp           0.250975
# diferencias         0.900394
# list_incomp         0.080601
# list_M              0.667383
# list_m              0.117183
# list_T              0.151661
# Jaro-Winkler_rit    0.654934
# rel_conceptuales    0.000000
# negT                0.106775
# negH                0.003750
# overlap_ent         0.000000
# dtype: float64

# %%
coor.idxmin()
# Out:
# sumas                    overlap_ent
# distancias          Jaro-Winkler_rit
# entropia_total           diferencias
# entropias                overlap_ent
# mutinf              Jaro-Winkler_rit
# mearts              Jaro-Winkler_rit
# max_info                 overlap_ent
# list_comp                overlap_ent
# diferencias         Jaro-Winkler_rit
# list_incomp              overlap_ent
# list_M                          negT
# list_m              Jaro-Winkler_rit
# list_T                          negH
# Jaro-Winkler_rit    rel_conceptuales
# rel_conceptuales         overlap_ent
# negT                            negH
# negH                           sumas
# overlap_ent                    sumas
# dtype: object

# %%
coor.min()
# Out:
# sumas              -0.290725
# distancias         -0.623564
# entropia_total     -0.162596
# entropias          -0.520237
# mutinf             -0.576078
# mearts             -0.521810
# max_info           -0.339239
# list_comp          -0.466392
# diferencias        -0.642089
# list_incomp        -0.214507
# list_M             -0.040202
# list_m             -0.624327
# list_T             -0.030675
# Jaro-Winkler_rit   -0.228262
# rel_conceptuales   -0.245237
# negT               -0.047197
# negH                0.000000
# overlap_ent         0.000000
# dtype: float64

# %%
cols=train_m.columns

# %%
cols=train_m.columns
temp=coor.copy()
for index, strings in temp.iterrows():
    for c in cols:
        if strings[c]>0.7:
            print(index,c,strings[c])
# Out:
# entropias sumas 0.7614768491541996
# entropias distancias 0.7211748629837846
# mutinf distancias 0.7281974742860591
# mutinf entropias 0.8792195648337314
# mearts mutinf 0.8067557302255339
# max_info sumas 0.9088490429302324
# max_info entropias 0.7969169752427445
# diferencias distancias 0.8972205614991532
# list_m distancias 0.999771386243822
# list_m entropias 0.7207766834285437
# list_m mutinf 0.728578288879328
# list_m diferencias 0.9003935716593363

# %%
temp=coor.copy()
for index, strings in temp.iterrows():
    for c in cols:
        if strings[c]<-0.7:
            print(index,c,strings[c])

# %%
# Checar variables colineales
sns.relplot(data=train_m, x="max_info", y="mutinf")

# %%
#X_dev = np.array(dev.drop(['CLASS'],axis=1))
#y_d = np.array(dev['CLASS'])

# %%
# SICK
y_train=[]
for i in y_:
    if i == "ENTAILMENT":
        y_train.append(1)
    else:
        y_train.append(0)

# %%
scaler = preprocessing.MaxAbsScaler().fit(X)
X_scaled = scaler.transform(X)
X = X_scaled
X_train=X

# %%
train.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# # TEST

# %%
for i in range(50):
    if i==0:
        test = pd.read_pickle('salida/nuevo4b/SICK/TEST_'+str(i+1)+'.csv_.pickle')
    else:
        try:
            temp = pd.read_pickle('salida/nuevo4b/SICK/TEST_'+str(i+1)+'.csv_.pickle')
            test=pd.concat([test,temp])
        except:
            print(i+1)

# %%
test = test.reset_index(drop=True)
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.100575    4.322275           0.748      0.414  3.687710  0.006140
# 4904  0.486279    6.997520           1.393      1.199  3.814937  0.006552
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  ...  list_m  list_T  \
# 0     0.190288          2     0.800000            0  ...       4       5
# 1     0.118164          2     0.285714            0  ...       2       7
# 2     0.096256          3     0.285714            0  ...       2       7
# 3     0.000000          0     0.000000            0  ...       0       8
# 4     0.074974          0     0.142857            0  ...       1       7
# ...        ...        ...          ...          ...  ...     ...     ...
# 4901  0.114092          0     0.600000            0  ...       3       5
# 4902  0.063093          2     0.400000            0  ...       2       5
# 4903  0.116333          1     0.750000            0  ...       3       4
# 4904  0.144823          2     0.833333            0  ...       5       6
# 4905  0.156842          1     0.571429            0  ...       4       7
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  verbT negH  verbH overlap_ent  \
# 0             0.375000                 0     0           0           0.000000
# 1             0.714286                 0     0           0           0.666667
# 2             0.428571                 0     0           0           0.333333
# 3             1.000000                 0     0           0           1.000000
# 4             0.857143                 0     0           0           0.833333
# ...                ...               ...   ...    ...  ...    ...         ...
# 4901          0.250000                 0     0           0           0.250000
# 4902          0.250000                 0     0           0           0.000000
# 4903          0.000000                 1     0           0           0.000000
# 4904          0.375000                 1     0           0           0.000000
# 4905          0.200000                 0     0           0           0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2     CONTRADICTION
# 3        ENTAILMENT
# 4     CONTRADICTION
# ...             ...
# 4901  CONTRADICTION
# 4902  CONTRADICTION
# 4903  CONTRADICTION
# 4904  CONTRADICTION
# 4905  CONTRADICTION
#
# [4906 rows x 21 columns]

# %%
test=test.drop(["verbH","verbT"],axis=1)
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.100575    4.322275           0.748      0.414  3.687710  0.006140
# 4904  0.486279    6.997520           1.393      1.199  3.814937  0.006552
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.116333          1     0.750000            0       5       3       4
# 4904  0.144823          2     0.833333            0       8       5       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  negH  overlap_ent  \
# 0             0.375000                 0     0     0     0.000000
# 1             0.714286                 0     0     0     0.666667
# 2             0.428571                 0     0     0     0.333333
# 3             1.000000                 0     0     0     1.000000
# 4             0.857143                 0     0     0     0.833333
# ...                ...               ...   ...   ...          ...
# 4901          0.250000                 0     0     0     0.250000
# 4902          0.250000                 0     0     0     0.000000
# 4903          0.000000                 1     0     0     0.000000
# 4904          0.375000                 1     0     0     0.000000
# 4905          0.200000                 0     0     0     0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2     CONTRADICTION
# 3        ENTAILMENT
# 4     CONTRADICTION
# ...             ...
# 4901  CONTRADICTION
# 4902  CONTRADICTION
# 4903  CONTRADICTION
# 4904  CONTRADICTION
# 4905  CONTRADICTION
#
# [4906 rows x 19 columns]

# %%
#test=test.drop(["sumas","mutinf","list_comp","list_incomp","entidades","entropia_total","list_rel_con",'mearts', 'max_info', 'similitud_faltantes','list_rel_con', 'list_M', 'list_m', 'list_T', 'list_bigram','diferencias'],axis=1)
#test=test[['list_comp', 'list_incomp','list_m','negT', 'negH',"clases"]]
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.100575    4.322275           0.748      0.414  3.687710  0.006140
# 4904  0.486279    6.997520           1.393      1.199  3.814937  0.006552
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.116333          1     0.750000            0       5       3       4
# 4904  0.144823          2     0.833333            0       8       5       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  negH  overlap_ent  \
# 0             0.375000                 0     0     0     0.000000
# 1             0.714286                 0     0     0     0.666667
# 2             0.428571                 0     0     0     0.333333
# 3             1.000000                 0     0     0     1.000000
# 4             0.857143                 0     0     0     0.833333
# ...                ...               ...   ...   ...          ...
# 4901          0.250000                 0     0     0     0.250000
# 4902          0.250000                 0     0     0     0.000000
# 4903          0.000000                 1     0     0     0.000000
# 4904          0.375000                 1     0     0     0.000000
# 4905          0.200000                 0     0     0     0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2     CONTRADICTION
# 3        ENTAILMENT
# 4     CONTRADICTION
# ...             ...
# 4901  CONTRADICTION
# 4902  CONTRADICTION
# 4903  CONTRADICTION
# 4904  CONTRADICTION
# 4905  CONTRADICTION
#
# [4906 rows x 19 columns]

# %%
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.100575    4.322275           0.748      0.414  3.687710  0.006140
# 4904  0.486279    6.997520           1.393      1.199  3.814937  0.006552
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.116333          1     0.750000            0       5       3       4
# 4904  0.144823          2     0.833333            0       8       5       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  negH  overlap_ent  \
# 0             0.375000                 0     0     0     0.000000
# 1             0.714286                 0     0     0     0.666667
# 2             0.428571                 0     0     0     0.333333
# 3             1.000000                 0     0     0     1.000000
# 4             0.857143                 0     0     0     0.833333
# ...                ...               ...   ...   ...          ...
# 4901          0.250000                 0     0     0     0.250000
# 4902          0.250000                 0     0     0     0.000000
# 4903          0.000000                 1     0     0     0.000000
# 4904          0.375000                 1     0     0     0.000000
# 4905          0.200000                 0     0     0     0.000000
#
#              clases
# 0     CONTRADICTION
# 1     CONTRADICTION
# 2     CONTRADICTION
# 3        ENTAILMENT
# 4     CONTRADICTION
# ...             ...
# 4901  CONTRADICTION
# 4902  CONTRADICTION
# 4903  CONTRADICTION
# 4904  CONTRADICTION
# 4905  CONTRADICTION
#
# [4906 rows x 19 columns]

# %%
X_t = test.drop(['clases'],axis=1)
y_t = test['clases']

# %%
# SICK
y_test=[]
for i in y_t:
    if i == "ENTAILMENT":
        y_test.append(1)
    else:
        y_test.append(0)

# %%
y_test.count(1)
# Out:
# 1404

# %%
y_test.count(0)
# Out:
# 3502

# %%
scaler = preprocessing.MaxAbsScaler().fit(X_t)
X_scaled = scaler.transform(X_t)
X_test = X_scaled

# %% [markdown]
# # MODELO DE REGRESIÓN LÓGISTICA

# %%
# grid={"C":np.logspace(-3,3,7), "penalty":["l2"]}# l1 lasso l2 ridge
# logreg=linear_model.LogisticRegression()
# logreg_cv=GridSearchCV(logreg,grid,cv=20)
# logreg_cv.fit(X_train,y_train)

# %%
# print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
# print("accuracy :",logreg_cv.best_score_)

# %%
#X_train = np.where(np.isnan(X_train), 0, X_train)
#X_train

# %%
X_train.shape
# Out:
# (4439, 18)

# %%
model = LogisticRegression(penalty="l2", C=1)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1)

# %%
model.get_params()
# Out:
# {'C': 1,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.decision_function(X)
# Out:
# array([ 0.54966905, -1.17658879, -0.62156876, ..., -4.03287132,
#        -2.11792144, -4.40837321])

# %%
labels=train.columns[:-1]
labels
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'rel_conceptuales',
#        'negT', 'negH', 'overlap_ent'],
#       dtype='object')

# %%
model.classes_
# Out:
# array([0, 1])

# %%
model.coef_[0]
# Out:
# array([ 1.71818117e+00, -9.13563520e-01,  1.19781958e+00,  1.64379671e-01,
#        -1.50605258e+00,  2.42644535e-02,  2.96150495e-01,  1.94640530e+00,
#        -8.37948804e-01, -1.91426679e+00, -2.73405727e+00, -8.26319673e-01,
#         1.19263120e+00,  2.57838832e-03, -2.54593539e-01, -4.28049983e+00,
#        -1.93893474e+00,  3.67334774e+00])

# %%
coeficientes=model.coef_[0]

# %%
coeficientes
# Out:
# array([ 1.71818117e+00, -9.13563520e-01,  1.19781958e+00,  1.64379671e-01,
#        -1.50605258e+00,  2.42644535e-02,  2.96150495e-01,  1.94640530e+00,
#        -8.37948804e-01, -1.91426679e+00, -2.73405727e+00, -8.26319673e-01,
#         1.19263120e+00,  2.57838832e-03, -2.54593539e-01, -4.28049983e+00,
#        -1.93893474e+00,  3.67334774e+00])

# %%
print("Maximo,minimo ",np.argmax(coeficientes),labels[np.argmax(coeficientes)],np.argmin(coeficientes),labels[np.argmin(coeficientes)])
# Out:
# Maximo,minimo  17 overlap_ent 15 negT

# %%
n_columns=train.shape[1]-1

# %%
n_columns
# Out:
# 18

# %%
import matplotlib.pyplot as plt
import numpy as np

x_v = np.arange(0,n_columns,1)
y_v = coeficientes

plt.bar(x_v,y_v)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Coeficientes')
plt.show()

# %%
#X_test = np.where(np.isnan(X_test), 0, X_test)
#X_test

# %%
X_test.shape
# Out:
# (4906, 18)

# %%
predictions = model.predict(X_test)

# %%
test["predictions"]=predictions
test
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 0     0.423790    5.644226           2.089      1.685  3.811686  0.005501
# 1     0.361121    2.850177           2.018      1.264  3.855514  0.005729
# 2     0.368295    2.836368           1.951      1.095  3.814045  0.005747
# 3     0.000000    0.000000           1.881      0.000  0.000000  0.000000
# 4     0.203490    1.437611           1.611      0.985  3.978109  0.006914
# ...        ...         ...             ...        ...       ...       ...
# 4901  0.165464    4.327404           1.919      1.472  3.803848  0.005847
# 4902 -0.007229    2.913927           1.579      1.157  3.769402  0.005909
# 4903  0.100575    4.322275           0.748      0.414  3.687710  0.006140
# 4904  0.486279    6.997520           1.393      1.199  3.814937  0.006552
# 4905  0.224067    5.809023           1.609      1.531  3.756346  0.005486
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 0     0.190288          2     0.800000            0       8       4       5
# 1     0.118164          2     0.285714            0       7       2       7
# 2     0.096256          3     0.285714            0       7       2       7
# 3     0.000000          0     0.000000            0       7       0       8
# 4     0.074974          0     0.142857            0       7       1       7
# ...        ...        ...          ...          ...     ...     ...     ...
# 4901  0.114092          0     0.600000            0       4       3       5
# 4902  0.063093          2     0.400000            0       4       2       5
# 4903  0.116333          1     0.750000            0       5       3       4
# 4904  0.144823          2     0.833333            0       8       5       6
# 4905  0.156842          1     0.571429            0       5       4       7
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  negH  overlap_ent  \
# 0             0.375000                 0     0     0     0.000000
# 1             0.714286                 0     0     0     0.666667
# 2             0.428571                 0     0     0     0.333333
# 3             1.000000                 0     0     0     1.000000
# 4             0.857143                 0     0     0     0.833333
# ...                ...               ...   ...   ...          ...
# 4901          0.250000                 0     0     0     0.250000
# 4902          0.250000                 0     0     0     0.000000
# 4903          0.000000                 1     0     0     0.000000
# 4904          0.375000                 1     0     0     0.000000
# 4905          0.200000                 0     0     0     0.000000
#
#              clases  predictions
# 0     CONTRADICTION            0
# 1     CONTRADICTION            0
# 2     CONTRADICTION            0
# 3        ENTAILMENT            1
# 4     CONTRADICTION            0
# ...             ...          ...
# 4901  CONTRADICTION            0
# 4902  CONTRADICTION            0
# 4903  CONTRADICTION            0
# 4904  CONTRADICTION            0
# 4905  CONTRADICTION            0
#
# [4906 rows x 20 columns]

# %%
test[(test["clases"]=="ENTAILMENT") & (test["predictions"]==0)]
# Out:
#          sumas  distancias  entropia_total  entropias    mutinf    mearts  \
# 9     0.000000    0.000000           2.423      0.000  0.000000  0.000000
# 17    0.000000    0.000000           2.797      0.000  0.000000  0.000000
# 18    1.763844    1.357598           2.501      1.842  3.696841  0.003618
# 24    0.219207    1.394025           1.889      0.971  3.885459  0.004431
# 39    0.366803    1.447200           1.943      1.000  3.785758  0.006490
# ...        ...         ...             ...        ...       ...       ...
# 4742  0.000000    0.000000           2.009      0.000  0.000000  0.000000
# 4760  1.163709    1.456037           2.480      2.128  3.737296  0.004204
# 4763  0.000000    0.000000           1.224      0.000  0.000000  0.000000
# 4772  0.000000    0.000000           2.356      0.000  0.000000  0.000000
# 4774  0.000000    0.000000           2.356      0.000  0.000000  0.000000
#
#       max_info  list_comp  diferencias  list_incomp  list_M  list_m  list_T  \
# 9     0.000000          0     0.000000            1       6       0       6
# 17    0.000000          0     0.000000            0       6       0       7
# 18    0.585392          0     0.142857            0       6       1       7
# 24    0.087943          0     0.200000            0       5       1       5
# 39    0.147189          0     0.125000            0       8       1       8
# ...        ...        ...          ...          ...     ...     ...     ...
# 4742  0.000000          1     0.000000            0       6       0       7
# 4760  0.470228          2     0.142857            0       8       1       7
# 4763  0.000000          1     0.000000            0       3       0       3
# 4772  0.000000          2     0.000000            0       4       0       9
# 4774  0.000000          2     0.000000            0       4       0       9
#
#       Jaro-Winkler_rit  rel_conceptuales  negT  negH  overlap_ent      clases  \
# 9             1.000000                 0     0     0     0.800000  ENTAILMENT
# 17            0.500000                 0     0     0     0.400000  ENTAILMENT
# 18            0.833333                 0     0     0     0.666667  ENTAILMENT
# 24            0.800000                 0     0     0     1.000000  ENTAILMENT
# 39            0.875000                 0     0     0     0.400000  ENTAILMENT
# ...                ...               ...   ...   ...          ...         ...
# 4742          0.833333                 0     0     0     0.600000  ENTAILMENT
# 4760          0.750000                 1     0     0     0.600000  ENTAILMENT
# 4763          1.000000                 0     0     0     0.500000  ENTAILMENT
# 4772          0.750000                 1     0     0     0.333333  ENTAILMENT
# 4774          0.750000                 1     0     0     0.333333  ENTAILMENT
#
#       predictions
# 9               0
# 17              0
# 18              0
# 24              0
# 39              0
# ...           ...
# 4742            0
# 4760            0
# 4763            0
# 4772            0
# 4774            0
#
# [485 rows x 20 columns]

# %%
#test.to_csv("predictions_SICK_DEV.csv")

# %%
print(confusion_matrix(y_test, predictions,labels=[1,0]))
# Out:
# [[ 919  485]
#  [ 404 3098]]

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions),2))
print("recall",round(recall_score(y_test,predictions),2))
print("f1_score: ",round(f1_score(y_test,predictions),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.82
# precision:  0.69
# recall 0.65
# f1_score:  0.67
# matthews_score:  0.55

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions,average="micro"),2))
print("recall",round(recall_score(y_test,predictions,average="micro"),2))
print("f1_score: ",round(f1_score(y_test,predictions,average="micro"),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.82
# precision:  0.82
# recall 0.82
# f1_score:  0.82
# matthews_score:  0.55

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions,average="macro"),2))
print("recall",round(recall_score(y_test,predictions,average="macro"),2))
print("f1_score: ",round(f1_score(y_test,predictions,average="macro"),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.82
# precision:  0.78
# recall 0.77
# f1_score:  0.77
# matthews_score:  0.55

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions,average="weighted"),2))
print("recall",round(recall_score(y_test,predictions,average="weighted"),2))
print("f1_score: ",round(f1_score(y_test,predictions,average="weighted"),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.82
# precision:  0.82
# recall 0.82
# f1_score:  0.82
# matthews_score:  0.55

# %%
print("acccuracy: ",round(accuracy_score(y_test,predictions),2))
print("precision: ",round(precision_score(y_test,predictions,average="binary"),2))
print("recall",round(recall_score(y_test,predictions,average="binary"),2))
print("f1_score: ",round(f1_score(y_test,predictions,average="binary"),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,predictions),2))
# Out:
# acccuracy:  0.82
# precision:  0.69
# recall 0.65
# f1_score:  0.67
# matthews_score:  0.55

# %%
X_train.shape
# Out:
# (4439, 18)

# %%
X_test.shape
# Out:
# (4906, 18)

# %%
X_cv=np.concatenate((X_train, X_test), axis=0)
Y_cv=np.concatenate((y_train, y_test), axis=0)

# %%
#validation_size = 0.20
#X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)
X_train_cv=X_cv
Y_train_cv=Y_cv

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name + " Acurracy:" , round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision')
msg += "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Acurracy:: 0.810000 (0.015491)
# Logistic Regression Precision:: 0.670000 (0.054822)
# Logistic Regression Recall:: 0.630000 (0.065295)
# Logistic Regression F1-score:: 0.650000 (0.050856)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_weighted')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_weighted')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_weighted')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.810000 (0.016839)
# Logistic Regression Recall:: 0.810000 (0.015491)
# Logistic Regression F1-score:: 0.810000 (0.016212)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_macro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_macro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_macro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.770000 (0.022865)
# Logistic Regression Recall:: 0.750000 (0.026505)
# Logistic Regression F1-score:: 0.760000 (0.023248)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='precision_micro')
msg = "\n%s: %f (%f)" % (name+ " Precision:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='recall_micro')
msg += "\n%s: %f (%f)" % (name+ " Recall:", round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='f1_micro')
msg += "\n%s: %f (%f)" % (name+ " F1-score:", round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression Precision:: 0.810000 (0.015491)
# Logistic Regression Recall:: 0.810000 (0.015491)
# Logistic Regression F1-score:: 0.810000 (0.015491)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(model, X_train_cv, Y_train_cv, cv=kfold, scoring='matthews_corrcoef')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# Logistic Regression: 0.520000 (0.060145)

# %%
import shap
import pandas as pd
import numpy as np
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
#linear_model

# %%
# model = LogisticRegression()
# model.fit(X_train,y_train)

# %%
y_predict = model.predict(X_test)
print(classification_report( y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      3502
#            1       0.69      0.65      0.67      1404
#
#     accuracy                           0.82      4906
#    macro avg       0.78      0.77      0.77      4906
# weighted avg       0.82      0.82      0.82      4906

# %%
explainer = shap.Explainer(model,X_train,feature_names=test.columns[:-1])
shap_values = explainer(X_test)

# %%
test.columns[:-1]
# Out:
# Index(['sumas', 'distancias', 'entropia_total', 'entropias', 'mutinf',
#        'mearts', 'max_info', 'list_comp', 'diferencias', 'list_incomp',
#        'list_M', 'list_m', 'list_T', 'Jaro-Winkler_rit', 'negT', 'negH',
#        'overlap_ent', 'clases'],
#       dtype='object')

# %%
explainer.expected_value
# Out:
# -1.418466723434778

# %%
X_test
# Out:
# array([[0.13135032, 0.24632658, 0.68290291, ..., 0.        , 0.        ,
#         0.        ],
#        [0.15260756, 0.24806094, 0.65969271, ..., 0.        , 0.        ,
#         0.66666667],
#        [0.15563953, 0.24685911, 0.63779013, ..., 0.        , 0.        ,
#         0.33333333],
#        ...,
#        [0.04250252, 0.3761828 , 0.24452435, ..., 0.        , 0.        ,
#         0.        ],
#        [0.20882912, 0.36514151, 0.45537757, ..., 0.        , 0.        ,
#         0.        ],
#        [0.09468945, 0.50557974, 0.52598889, ..., 0.        , 0.        ,
#         0.        ]])

# %%
shap.plots.beeswarm(shap_values)

# %%
ind = 21
print(X_test[ind],y_test[ind],y_predict[ind])
shap.plots.force(shap_values[ind])
shap.plots.waterfall(shap_values[ind])
# Out:
# [0.4751967  0.24555819 0.87544949 0.78537126 0.93112685 0.10731264
#  0.47481402 0.25       0.0952381  0.         0.375      0.25
#  0.4        0.83333333 0.         0.         0.25      ] 0 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[133], line 3
#       1 ind = 21
#       2 print(X_test[ind],y_test[ind],y_predict[ind])
# ----> 3 shap.plots.force(shap_values[ind])
#       4 shap.plots.waterfall(shap_values[ind])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:195, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     183     instance = Instance(np.zeros((1, len(feature_names))), features)
#     184     e = AdditiveExplanation(
#     185         base_value,
#     186         np.sum(shap_values[0, :]) + base_value,
#    (...)
#     192         DenseData(np.zeros((1, len(feature_names))), list(feature_names))
#     193     )
# --> 195     return visualize(e,
#     196                      plot_cmap,
#     197                      matplotlib,
#     198                      figsize=figsize,
#     199                      show=show,
#     200                      text_rotation=text_rotation,
#     201                      min_perc=contribution_threshold)
#     203 else:
#     204     if matplotlib:
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:413, in visualize(e, plot_cmap, matplotlib, figsize, show, ordering_keys, ordering_keys_time_format, text_rotation, min_perc)
#     406         return AdditiveForceVisualizer(e, plot_cmap=plot_cmap).matplotlib(
#     407             figsize=figsize,
#     408             show=show,
#     409             text_rotation=text_rotation,
#     410             min_perc=min_perc,
#     411         )
#     412     else:
# --> 413         return AdditiveForceVisualizer(e, plot_cmap=plot_cmap)
#     414 elif isinstance(e, Explanation):
#     415     if matplotlib:
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:491, in AdditiveForceVisualizer.__init__(self, e, plot_cmap)
#     489 # build the json data
#     490 features = {}
# --> 491 for i in filter(lambda j: e.effects[j] != 0, range(len(e.data.group_names))):
#     492     features[i] = {
#     493         "effect": ensure_not_numpy(e.effects[i]),
#     494         "value": ensure_not_numpy(e.instance.group_display_values[i])
#     495     }
#     496 self.data = {
#     497     "outNames": e.model.out_names,
#     498     "baseValue": ensure_not_numpy(e.base_value),
#    (...)
#     503     "plot_cmap": plot_cmap,
#     504 }
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/plots/_force.py:491, in AdditiveForceVisualizer.__init__.<locals>.<lambda>(j)
#     489 # build the json data
#     490 features = {}
# --> 491 for i in filter(lambda j: e.effects[j] != 0, range(len(e.data.group_names))):
#     492     features[i] = {
#     493         "effect": ensure_not_numpy(e.effects[i]),
#     494         "value": ensure_not_numpy(e.instance.group_display_values[i])
#     495     }
#     496 self.data = {
#     497     "outNames": e.model.out_names,
#     498     "baseValue": ensure_not_numpy(e.base_value),
#    (...)
#     503     "plot_cmap": plot_cmap,
#     504 }
#
# IndexError: index 17 is out of bounds for axis 0 with size 17

# %%
ind = 6
print(X_test[ind])
# This amazing documentary gives us a glimpse into the lives of the brave
# women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
# tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
# languages and multiple legal precedents depending on the region of the country and
# the religious/ethnic background of the plaintiffs and defendants-- these brave,
# strong women are making a difference. [...]

shap.plots.waterfall(shap_values[ind,:,1])
# Out:
# [0.12572709 0.25258803 0.53743053 0.46693757 0.95367512 0.16914902
#  0.12524514 0.         0.08163265 0.         0.1875     0.25
#  0.46666667 0.33333333 0.         0.         0.        ]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[134], line 10
#       2 print(X_test[ind])
#       3 # This amazing documentary gives us a glimpse into the lives of the brave
#       4 # women in Cameroun's judicial system-- policewomen, lawyers and judges. Despite
#       5 # tremendous difficulties-- lack of means, the desperate poverty of the people, multiple
#       6 # languages and multiple legal precedents depending on the region of the country and
#       7 # the religious/ethnic background of the plaintiffs and defendants-- these brave,
#       8 # strong women are making a difference. [...]
# ---> 10 shap.plots.waterfall(shap_values[ind,:,1])
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/shap/_explanation.py:422, in Explanation.__getitem__(self, item)
#     420 if new_self is None:
#     421     new_self = copy.copy(self)
# --> 422 new_self._s = new_self._s.__getitem__(item)
#     423 new_self.op_history.append({
#     424     "name": "__getitem__",
#     425     "args": (item,),
#     426     "prev_shape": self.shape
#     427 })
#     429 return new_self
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer.py:112, in Slicer.__getitem__(self, item)
#     110 index_slicer = AtomicSlicer(index_tup, max_dim=1)
#     111 slicer_index = index_slicer[tracked.dim]
# --> 112 sliced_o = tracked[slicer_index]
#     113 sliced_dim = resolve_dim(index_tup, tracked.dim)
#     115 new_tracked = tracked.__class__(sliced_o, sliced_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:582, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     579 head_slice = cls.type_map[o_type].head_slice
#     580 tail_slice = cls.type_map[o_type].tail_slice
# --> 582 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
#     583 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     584 return out
#
# File ~/anaconda3/envs/rit/lib/python3.9/site-packages/slicer/slicer_internal.py:418, in ArrayHandler.head_slice(cls, o, index_tup, max_dim)
#     416 cut_index = index_tup[:cut]
#     417 is_element = any([True if isinstance(x, int) else False for x in cut_index])
# --> 418 sliced_o = o[cut_index]
#     420 return is_element, sliced_o, cut
#
# IndexError: index 1 is out of bounds for axis 2 with size 1

# %%
shap.summary_plot(shap_values, X_test,plot_type="bar")

# %%
shap.summary_plot(shap_values[1:,], X_test[1:,])

# %%
shap.summary_plot(shap_values, X_test,feature_names=test.columns[:-1])

# %%
shap_values[2:,]
# Out:
# .values =
# array([[ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683],
#        [-0.01299836, -0.11268555, -0.4045574 ,  0.04382668,  0.21114683],
#        ...,
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.03866018],
#        [ 0.00911714,  0.30959951,  0.55679351, -0.20535715,  0.21114683]])
#
# .base_values =
# array([-0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388, -0.74544388, -0.74544388,
#        -0.74544388, -0.74544388, -0.74544388])
#
# .data =
# array([[-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221],
#        [ 1.23549291,  0.39218921,  0.29047164,  0.24312215, -0.67101221],
#        ...,
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.03498168],
#        [-0.79898427, -0.62125842, -0.46729669, -0.61105676, -0.67101221]])

# %%
shap.summary_plot(shap_values[0:,], X_test,feature_names=test.columns[:-1])

# %%
explainer.expected_value
# Out:
# -0.7454438806409415

# %%
shap_values.shape
# Out:
# (800, 5)

# %% [markdown]
# # Árbol de decisión

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
clf = DecisionTreeClassifier(splitter="random")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print("acccuracy: ",round(accuracy_score(y_test,y_pred),2))
print("precision: ",round(precision_score(y_test,y_pred),2))
print("recall",round(recall_score(y_test,y_pred),2))
print("f1_score: ",round(f1_score(y_test,y_pred),2))
print("matthews_score: ",round(matthews_corrcoef(y_test,y_pred),2))
# Out:
# acccuracy:  0.58
# precision:  0.63
# recall 0.42
# f1_score:  0.51
# matthews_score:  0.17

# %%
validation_size = 0.01
X_train_cv, X_validation_cv, Y_train_cv, Y_validation_cv = model_selection.train_test_split(X_cv, Y_cv, test_size=validation_size)

# %%
name='DecisionTree'
kfold = model_selection.KFold(n_splits=20)
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='precision')
msg = "%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='recall')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
cv_results = model_selection.cross_val_score(clf, X_train_cv, Y_train_cv, cv=kfold, scoring='f1')
msg += "\n%s: %f (%f)" % (name, round(cv_results.mean(),2), cv_results.std())
print(msg)
# Out:
# DecisionTree: 0.550000 (0.081558)
# DecisionTree: 0.670000 (0.067294)
# DecisionTree: 0.580000 (0.060962)

# %%
c=train.columns[:-1]
confusion_matrix(y_test,y_pred)
# Out:
# array([[287, 103],
#        [236, 174]])

# %%
# Estructura del árbol creado
import matplotlib.pyplot as plt
# ------------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(20, 10))

print(f"Profundidad del árbol: {clf.get_depth()}")
print(f"Número de nodos terminales: {clf.get_n_leaves()}")

plot = plot_tree(
            decision_tree = clf,
            feature_names = c,
            class_names   = True,
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 23
# Número de nodos terminales: 152
